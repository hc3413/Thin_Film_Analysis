# %% [markdown]
# ## Set Up

# %%
#source TFAvenv/bin/activate (launching and exiting the virtual environment containing the required modules, stored in the working directory)
#TFAvenv/bin/python your_script.py - for running a script in the virtual environment
#source deactivate

#import all the libraries needed
from import_dep import *

# import my functions stored in the file 'functions' which can then be called with functions.function_name()
from ttw_functions import *
from ttw import ttw
from ttw_models import * # Import new modularized models
from ttw_models import run_xrd_fitting, find_peak

# import custom plot style and colorbar functions
from plot_style import set_plot_style, add_colorbar, generate_colormaps_and_normalizers


# Define the path to the root directory containing all the XRD data
root_XRD = '/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD'


### Plotting and Output Variables 
export_data = True # set to True to export the data to a powerpoint presentation and as svg files and export to path_out
fig_format = 'tiff' # format of the figure to be saved

powerpoint_string = 'EM011' # string to be added to the powerpoint file name

plot_transparency = True # set to True to make the data plots transparent



# Custom Scence style settings for figures
fig_size = set_plot_style(export_data = export_data, use_tex=True)
#plt.style.use(['science', 'grid', 'nature'])

# %% [markdown]
# ## Import Data

# %%
#ttw_JT071 = ttw(root_XRD, folder_name = 'JT071')
ttw_JT082 = ttw(root_XRD, folder_name = 'JT082')
ttw_JT090 = ttw(root_XRD, folder_name = 'JT090')
ttw_JT129 = ttw(root_XRD, folder_name = 'JT129')
ttw_JT143 = ttw(root_XRD, folder_name = 'JT143')

ttw_SR001 = ttw(root_XRD, folder_name = 'SR00123/SR001')
ttw_SR002 = ttw(root_XRD, folder_name = 'SR00123/SR002')
ttw_SR003 = ttw(root_XRD, folder_name = 'SR00123/SR003')
ttw_SR001tw = ttw(root_XRD, folder_name = 'SR00123')

ttw_HC007 = ttw(root_XRD, folder_name = 'HC007')
ttw_HC011 = ttw(root_XRD, folder_name = 'HC011')
ttw_HC013 = ttw(root_XRD, folder_name = 'HC013')
ttw_HC015 = ttw(root_XRD, folder_name = 'HC015')
#ttw_HC016 = ttw(root_XRD, folder_name = 'HC016')
ttw_HC017 = ttw(root_XRD, folder_name = 'HC017')
ttw_HC018 = ttw(root_XRD, folder_name = 'HC018')
ttw_HC019 = ttw(root_XRD, folder_name = 'HC019')
ttw_HC020 = ttw(root_XRD, folder_name = 'HC020')
ttw_HC021 = ttw(root_XRD, folder_name = 'HC021')

ttw_DR001 = ttw(root_XRD, folder_name = 'DR001')
ttw_DR002 = ttw(root_XRD, folder_name = 'DR002')
ttw_DR008 = ttw(root_XRD, folder_name = 'DR008')
ttw_DR012 = ttw(root_XRD, folder_name = 'DR012')


ttw_EM001 = ttw(root_XRD, folder_name = 'EM001')
ttw_EM002 = ttw(root_XRD, folder_name = 'EM002')
ttw_EM003 = ttw(root_XRD, folder_name = 'EM003')
ttw_EM004 = ttw(root_XRD, folder_name = 'EM004')
ttw_EM005 = ttw(root_XRD, folder_name = 'EM005')
ttw_EM006 = ttw(root_XRD, folder_name = 'EM006')
ttw_EM007 = ttw(root_XRD, folder_name = 'EM007')
ttw_EM008 = ttw(root_XRD, folder_name = 'EM008')
ttw_EM009 = ttw(root_XRD, folder_name = 'EM009')
ttw_EM010 = ttw(root_XRD, folder_name = 'EM010')
ttw_EM011 = ttw(root_XRD, folder_name = 'EM011')
ttw_EM012 = ttw(root_XRD, folder_name = 'EM012')
ttw_EM013 = ttw(root_XRD, folder_name = 'EM013')
ttw_EM014 = ttw(root_XRD, folder_name = 'EM014')
ttw_EM015 = ttw(root_XRD, folder_name = 'EM015')
ttw_EM016 = ttw(root_XRD, folder_name = 'EM016')
ttw_EM017 = ttw(root_XRD, folder_name = 'EM017')
ttw_EM018 = ttw(root_XRD, folder_name = 'EM018')
ttw_EM019 = ttw(root_XRD, folder_name = 'EM019')
ttw_EM020 = ttw(root_XRD, folder_name = 'EM020')
ttw_EM021 = ttw(root_XRD, folder_name = 'EM021')
ttw_EM022 = ttw(root_XRD, folder_name = 'EM022')
ttw_EM023 = ttw(root_XRD, folder_name = 'EM023')
ttw_EM024 = ttw(root_XRD, folder_name = 'EM024')
ttw_EM027 = ttw(root_XRD, folder_name = 'EM027')
# Out:
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/JT082/JT082_BSO_BTO_LaSSTO(0.55)_T_STO_2tw_(002)_1.csv')]
# 32
#      Angle  TimePerStep  Intensity     ESD
# 0    40.01         2.64        6.0  2.4495
# 1    40.03         2.64       10.0  3.1623
# 2    40.05         2.64       15.0  3.8730
# 3    40.07         2.64       14.0  3.7417
# 4    40.09         2.64       13.0  3.6056
# ..     ...          ...        ...     ...
# 495  49.91         2.64        5.0  2.2361
# 496  49.93         2.64        7.0  2.6458
# 497  49.95         2.64        9.0  3.0000
# 498  49.97         2.64       14.0  3.7417
# 499  49.99         2.64        6.0  2.4495
#
# [500 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/JT090/JT090_LSO_BTO_SSO_T_STO_2tw.csv')]
# 32
#       Angle  TimePerStep  Intensity     ESD
# 0     20.01         2.64       10.0  3.1623
# 1     20.03         2.64       18.0  4.2426
# 2     20.05         2.64       14.0  3.7417
# 3     20.07         2.64       15.0  3.8730
# 4     20.09         2.64       11.0  3.3166
# ...     ...          ...        ...     ...
# 2995  79.91         2.64       11.0  3.3166
# 2996  79.93         2.64        6.0  2.4495
# 2997  79.95         2.64        8.0  2.8284
# 2998  79.97         2.64        7.0  2.6458
# 2999  79.99         2.64       14.0  3.7417
#
# [3000 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/JT129/JT129_BTO_La0.003Ba0.97SnO3_Ba0.4Sr0.6SnO3_SrSnO3_on_T-STO_2tw_formal_40-50 degree_(002)_1.csv')]
# 32
#      Angle  TimePerStep  Intensity     ESD
# 0    40.01         2.64       15.0  3.8730
# 1    40.03         2.64       12.0  3.4641
# 2    40.05         2.64       17.0  4.1231
# 3    40.07         2.64       17.0  4.1231
# 4    40.09         2.64       18.0  4.2426
# ..     ...          ...        ...     ...
# 495  49.91         2.64       16.0  4.0000
# 496  49.93         2.64       16.0  4.0000
# 497  49.95         2.64       19.0  4.3589
# 498  49.97         2.64       16.0  4.0000
# 499  49.99         2.64       14.0  3.7417
#
# [500 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/JT143/JT143_BTO(60nm)_La0.002Ba0.98SnO3(5nm)_Ba0.4Sr0.6SnO3_SrSnO3_on_T-STO_2tw_002_highres_1.csv')]
# 31
#      Angle  TimePerStep  Intensity     ESD
# 0    40.01         2.64       26.0  5.0990
# 1    40.03         2.64       18.0  4.2426
# 2    40.05         2.64       20.0  4.4721
# 3    40.07         2.64       24.0  4.8990
# 4    40.09         2.64       26.0  5.0990
# ..     ...          ...        ...     ...
# 495  49.91         2.64       24.0  4.8990
# 496  49.93         2.64       17.0  4.1231
# 497  49.95         2.64       23.0  4.7958
# 498  49.97         2.64       16.0  4.0000
# 499  49.99         2.64       26.0  5.0990
#
# [500 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/SR00123/SR001/SR001_O_WO3_SiO2_Si_GIXRD_1D.csv')]
# 31
#           Angle  TimePerStep  Intensity      ESD
# 0     20.004924      448.545      627.0  25.0400
# 1     20.014772      448.545      638.0  25.2587
# 2     20.024619      448.545      648.0  25.4558
# 3     20.034467      448.545      586.0  24.2074
# 4     20.044315      448.545      602.0  24.5357
# ...         ...          ...        ...      ...
# 2026  39.956388      448.545      115.0  10.7238
# 2027  39.966236      448.545      122.0  11.0454
# 2028  39.976084      448.545      130.0  11.4018
# 2029  39.985932      448.545      122.0  11.0454
# 2030  39.995779      448.545      132.0  11.4891
#
# [2031 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/SR00123/SR002/SR002_M_WO3_SiO2_Si_GIXRD_1D.csv')]
# 31
#           Angle  TimePerStep  Intensity      ESD
# 0     20.004924      448.545      686.0  26.1916
# 1     20.014772      448.545      679.0  26.0576
# 2     20.024619      448.545      688.0  26.2298
# 3     20.034467      448.545      647.0  25.4362
# 4     20.044315      448.545      681.0  26.0960
# ...         ...          ...        ...      ...
# 2026  39.956388      448.545      126.0  11.2250
# 2027  39.966236      448.545      112.0  10.5830
# 2028  39.976084      448.545      137.0  11.7047
# 2029  39.985932      448.545      136.0  11.6619
# 2030  39.995779      448.545      132.0  11.4891
#
# [2031 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/SR00123/SR003/SR003_S_WO3_SiO2_Si_GIXRD_1D.csv')]
# 31
#           Angle  TimePerStep  Intensity      ESD
# 0     20.004924      448.545      634.0  25.1794
# 1     20.014772      448.545      698.0  26.4197
# 2     20.024619      448.545      660.0  25.6905
# 3     20.034467      448.545      644.0  25.3772
# 4     20.044315      448.545      641.0  25.3180
# ...         ...          ...        ...      ...
# 2026  39.956388      448.545      114.0  10.6771
# 2027  39.966236      448.545      132.0  11.4891
# 2028  39.976084      448.545      143.0  11.9583
# 2029  39.985932      448.545      109.0  10.4403
# 2030  39.995779      448.545      120.0  10.9545
#
# [2031 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/SR00123/SR001_O_WO3_SiO2_Si_2tw_1D.csv')]
# 31
#           Angle  TimePerStep  Intensity      ESD
# 0     10.001848      197.115      759.0  27.5500
# 1     10.021543      197.115      744.0  27.2764
# 2     10.041239      197.115      750.0  27.3861
# 3     10.060934      197.115      782.0  27.9643
# 4     10.080629      197.115      727.0  26.9629
# ...         ...          ...        ...      ...
# 4565  99.911459      197.115      223.0  14.9332
# 4566  99.931154      197.115      210.0  14.4914
# 4567  99.950849      197.115      242.0  15.5563
# 4568  99.970545      197.115      241.0  15.5242
# 4569  99.990240      197.115      214.0  14.6287
#
# [4570 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/HC007/HC007_SSO_STO_2tw_0D.csv'), PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/HC007/HC007_SSO_STO_2tw_1D.csv')]
# 31
#        Angle  TimePerStep  Intensity     ESD
# 0    40.0023          4.4       28.0  5.2915
# 1    40.0173          4.4       24.0  4.8990
# 2    40.0323          4.4       18.0  4.2426
# 3    40.0473          4.4       25.0  5.0000
# 4    40.0623          4.4       37.0  6.0828
# ..       ...          ...        ...     ...
# 662  49.9323          4.4       30.0  5.4772
# 663  49.9473          4.4       29.0  5.3852
# 664  49.9623          4.4       21.0  4.5826
# 665  49.9773          4.4       29.0  5.3852
# 666  49.9923          4.4       30.0  5.4772
#
# [667 rows x 4 columns]
# 31
#           Angle  TimePerStep  Intensity     ESD
# 0     20.009848        96.39       99.0  9.9499
# 1     20.029543        96.39       86.0  9.2736
# 2     20.049239        96.39       84.0  9.1652
# 3     20.068934        96.39       98.0  9.8995
# 4     20.088629        96.39       74.0  8.6023
# ...         ...          ...        ...     ...
# 3041  79.903632        96.39       21.0  4.5826
# 3042  79.923328        96.39       22.0  4.6904
# 3043  79.943023        96.39       28.0  5.2915
# 3044  79.962719        96.39       33.0  5.7446
# 3045  79.982414        96.39       27.0  5.1962
#
# [3046 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/HC011/HC011_BSO_LSO_LaSSO_STO_2tw_0D_001.csv'), PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/HC011/HC011_BSO_LSO_LaSSO_STO_2tw_0D_002.csv'), PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/HC011/HC011_BSO_LSO_LaSSO_STO_2tw_1D.csv')]
# 31
#        Angle  TimePerStep  Intensity     ESD
# 0    18.0025          4.4       36.0  6.0000
# 1    18.0175          4.4       27.0  5.1962
# 2    18.0325          4.4       25.0  5.0000
# 3    18.0475          4.4       28.0  5.2915
# 4    18.0625          4.4       25.0  5.0000
# ..       ...          ...        ...     ...
# 662  27.9325          4.4       17.0  4.1231
# 663  27.9475          4.4       18.0  4.2426
# 664  27.9625          4.4       21.0  4.5826
# 665  27.9775          4.4       18.0  4.2426
# 666  27.9925          4.4       19.0  4.3589
#
# [667 rows x 4 columns]
# 31
#        Angle  TimePerStep  Intensity     ESD
# 0    40.0075          4.4       18.0  4.2426
# 1    40.0225          4.4       27.0  5.1962
# 2    40.0375          4.4       36.0  6.0000
# 3    40.0525          4.4       18.0  4.2426
# 4    40.0675          4.4       26.0  5.0990
# ..       ...          ...        ...     ...
# 662  49.9375          4.4       24.0  4.8990
# 663  49.9525          4.4       21.0  4.5826
# 664  49.9675          4.4       15.0  3.8730
# 665  49.9825          4.4       24.0  4.8990
# 666  49.9975          4.4       25.0  5.0000
#
# [667 rows x 4 columns]
# 31
#           Angle  TimePerStep  Intensity      ESD
# 0     20.009848        96.39       99.0   9.9499
# 1     20.029543        96.39       96.0   9.7980
# 2     20.049239        96.39       73.0   8.5440
# 3     20.068934        96.39       86.0   9.2736
# 4     20.088629        96.39      108.0  10.3923
# ...         ...          ...        ...      ...
# 3041  79.903632        96.39       36.0   6.0000
# 3042  79.923328        96.39       22.0   4.6904
# 3043  79.943023        96.39       24.0   4.8990
# 3044  79.962719        96.39       25.0   5.0000
# 3045  79.982414        96.39       23.0   4.7958
#
# [3046 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/HC013/HC013_LSO_BSO_LaSSO_STO_2tw_0D_001.csv'), PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/HC013/HC013_LSO_BSO_LaSSO_STO_2tw_0D_002.csv')]
# 32
#        Angle  TimePerStep  Intensity     ESD
# 0    19.0125          4.4       32.0  5.6569
# 1    19.0275          4.4       38.0  6.1644
# 2    19.0425          4.4       36.0  6.0000
# 3    19.0575          4.4       42.0  6.4807
# 4    19.0725          4.4       39.0  6.2450
# ..       ...          ...        ...     ...
# 528  26.9325          4.4       25.0  5.0000
# 529  26.9475          4.4       28.0  5.2915
# 530  26.9625          4.4       15.0  3.8730
# 531  26.9775          4.4       19.0  4.3589
# 532  26.9925          4.4       13.0  3.6056
#
# [533 rows x 4 columns]
# 32
#        Angle  TimePerStep  Intensity     ESD
# 0    40.0075          4.4       27.0  5.1962
# 1    40.0225          4.4       14.0  3.7417
# 2    40.0375          4.4       11.0  3.3166
# 3    40.0525          4.4       20.0  4.4721
# 4    40.0675          4.4       12.0  3.4641
# ..       ...          ...        ...     ...
# 528  47.9275          4.4       15.0  3.8730
# 529  47.9425          4.4       20.0  4.4721
# 530  47.9575          4.4       15.0  3.8730
# 531  47.9725          4.4       25.0  5.0000
# 532  47.9875          4.4       25.0  5.0000
#
# [533 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/HC015/HC015_LSO_BSO_STO_2tw_0D_001.csv'), PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/HC015/HC015_LSO_BSO_STO_2tw_0D_002.csv')]
# 32
#        Angle  TimePerStep  Intensity     ESD
# 0    19.0125          4.4       21.0  4.5826
# 1    19.0275          4.4       47.0  6.8557
# 2    19.0425          4.4       38.0  6.1644
# 3    19.0575          4.4       28.0  5.2915
# 4    19.0725          4.4       23.0  4.7958
# ..       ...          ...        ...     ...
# 528  26.9325          4.4       40.0  6.3246
# 529  26.9475          4.4       36.0  6.0000
# 530  26.9625          4.4       19.0  4.3589
# 531  26.9775          4.4       28.0  5.2915
# 532  26.9925          4.4       23.0  4.7958
#
# [533 rows x 4 columns]
# 32
#        Angle  TimePerStep  Intensity     ESD
# 0    40.0075          4.4       21.0  4.5826
# 1    40.0225          4.4       19.0  4.3589
# 2    40.0375          4.4       17.0  4.1231
# 3    40.0525          4.4       29.0  5.3852
# 4    40.0675          4.4       19.0  4.3589
# ..       ...          ...        ...     ...
# 528  47.9275          4.4       30.0  5.4772
# 529  47.9425          4.4       20.0  4.4721
# 530  47.9575          4.4       18.0  4.2426
# 531  47.9725          4.4       27.0  5.1962
# 532  47.9875          4.4       23.0  4.7958
#
# [533 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/HC017/HC017_BSO_LSO_SSO_STO_2tw_0D_001.csv'), PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/HC017/HC017_BSO_LSO_SSO_STO_2tw_0D_002.csv'), PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/HC017/HC017_BSO_LSO_SSO_STO_2tw_1D.csv')]
# 31
#        Angle  TimePerStep  Intensity     ESD
# 0    19.0125          4.4       48.0  6.9282
# 1    19.0275          4.4       42.0  6.4807
# 2    19.0425          4.4       37.0  6.0828
# 3    19.0575          4.4       37.0  6.0828
# 4    19.0725          4.4       45.0  6.7082
# ..       ...          ...        ...     ...
# 528  26.9325          4.4       22.0  4.6904
# 529  26.9475          4.4       17.0  4.1231
# 530  26.9625          4.4       18.0  4.2426
# 531  26.9775          4.4       25.0  5.0000
# 532  26.9925          4.4       28.0  5.2915
#
# [533 rows x 4 columns]
# 31
#        Angle  TimePerStep  Intensity     ESD
# 0    40.0075          4.4       20.0  4.4721
# 1    40.0225          4.4       24.0  4.8990
# 2    40.0375          4.4       11.0  3.3166
# 3    40.0525          4.4       10.0  3.1623
# 4    40.0675          4.4       24.0  4.8990
# ..       ...          ...        ...     ...
# 528  47.9275          4.4       26.0  5.0990
# 529  47.9425          4.4       24.0  4.8990
# 530  47.9575          4.4       23.0  4.7958
# 531  47.9725          4.4       23.0  4.7958
# 532  47.9875          4.4       19.0  4.3589
#
# [533 rows x 4 columns]
# 31
#           Angle  TimePerStep  Intensity      ESD
# 0     20.017648        96.39      139.0  11.7898
# 1     20.037343        96.39      131.0  11.4455
# 2     20.057039        96.39      136.0  11.6619
# 3     20.076734        96.39      124.0  11.1355
# 4     20.096429        96.39      136.0  11.6619
# ...         ...          ...        ...      ...
# 3041  79.911432        96.39       40.0   6.3246
# 3042  79.931128        96.39       28.0   5.2915
# 3043  79.950823        96.39       32.0   5.6569
# 3044  79.970519        96.39       35.0   5.9161
# 3045  79.990214        96.39       32.0   5.6569
#
# [3046 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/HC018/HC018_BSO_LSO_SSO_STO_2tw_0D_001.csv'), PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/HC018/HC018_BSO_LSO_SSO_STO_2tw_0D_002.csv'), PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/HC018/HC018_BSO_LSO_SSO_STO_2tw_1D.csv')]
# 31
#        Angle  TimePerStep  Intensity     ESD
# 0    19.0125          4.4       45.0  6.7082
# 1    19.0275          4.4       56.0  7.4833
# 2    19.0425          4.4       63.0  7.9373
# 3    19.0575          4.4       55.0  7.4162
# 4    19.0725          4.4       55.0  7.4162
# ..       ...          ...        ...     ...
# 528  26.9325          4.4       32.0  5.6569
# 529  26.9475          4.4       26.0  5.0990
# 530  26.9625          4.4       34.0  5.8310
# 531  26.9775          4.4       30.0  5.4772
# 532  26.9925          4.4       41.0  6.4031
#
# [533 rows x 4 columns]
# 31
#        Angle  TimePerStep  Intensity     ESD
# 0    40.0075          4.4       24.0  4.8990
# 1    40.0225          4.4       22.0  4.6904
# 2    40.0375          4.4       30.0  5.4772
# 3    40.0525          4.4       17.0  4.1231
# 4    40.0675          4.4       34.0  5.8310
# ..       ...          ...        ...     ...
# 528  47.9275          4.4       31.0  5.5678
# 529  47.9425          4.4       25.0  5.0000
# 530  47.9575          4.4       36.0  6.0000
# 531  47.9725          4.4       20.0  4.4721
# 532  47.9875          4.4       26.0  5.0990
#
# [533 rows x 4 columns]
# 31
#           Angle  TimePerStep  Intensity      ESD
# 0     20.017648        96.39      134.0  11.5758
# 1     20.037343        96.39      168.0  12.9615
# 2     20.057039        96.39      141.0  11.8743
# 3     20.076734        96.39      145.0  12.0416
# 4     20.096429        96.39      156.0  12.4900
# ...         ...          ...        ...      ...
# 3041  79.911432        96.39       55.0   7.4162
# 3042  79.931128        96.39       48.0   6.9282
# 3043  79.950823        96.39       63.0   7.9373
# 3044  79.970519        96.39       47.0   6.8557
# 3045  79.990214        96.39       46.0   6.7823
#
# [3046 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/HC019/HC019_LSO_BSO_B.40S.60SO_SSO_STO_Treated_2thetaomega_0D_002_1.csv')]
# 32
#      Angle  TimePerStep  Intensity      ESD
# 0    41.01        10.56       93.0   9.6437
# 1    41.03        10.56       64.0   8.0000
# 2    41.05        10.56       98.0   9.8995
# 3    41.07        10.56       94.0   9.6954
# 4    41.09        10.56       80.0   8.9443
# ..     ...          ...        ...      ...
# 320  47.41        10.56       98.0   9.8995
# 321  47.43        10.56      114.0  10.6771
# 322  47.45        10.56      126.0  11.2250
# 323  47.47        10.56      105.0  10.2470
# 324  47.49        10.56       95.0   9.7468
#
# [325 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/HC020/HC020_LSO_BSO_B.40S.60SO_SSO_STO_Treated_2thetaomega_0D_002_1.csv')]
# 32
#      Angle  TimePerStep  Intensity     ESD
# 0    41.01        10.56       48.0  6.9282
# 1    41.03        10.56       63.0  7.9373
# 2    41.05        10.56       55.0  7.4162
# 3    41.07        10.56       53.0  7.2801
# 4    41.09        10.56       52.0  7.2111
# ..     ...          ...        ...     ...
# 320  47.41        10.56       74.0  8.6023
# 321  47.43        10.56       93.0  9.6437
# 322  47.45        10.56       58.0  7.6158
# 323  47.47        10.56       83.0  9.1104
# 324  47.49        10.56       62.0  7.8740
#
# [325 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/HC021/HC021_LSO_L.03B.97SO_B.40S.60SO_SSO_STO_Treated_2thetaomega_0D_002_1.csv')]
# 32
#      Angle  TimePerStep  Intensity      ESD
# 0    41.01        10.56       96.0   9.7980
# 1    41.03        10.56       93.0   9.6437
# 2    41.05        10.56       98.0   9.8995
# 3    41.07        10.56       76.0   8.7178
# 4    41.09        10.56      101.0  10.0499
# ..     ...          ...        ...      ...
# 320  47.41        10.56      122.0  11.0454
# 321  47.43        10.56      127.0  11.2694
# 322  47.45        10.56      110.0  10.4881
# 323  47.47        10.56       98.0   9.8995
# 324  47.49        10.56      102.0  10.0995
#
# [325 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/DR001/BSO-LSO1_2tw_0D_002_1..csv')]
# 30
#       Angle  TimePerStep  Intensity     ESD
# 0     17.01         6.16        8.0  2.8284
# 1     17.03         6.16       20.0  4.4721
# 2     17.05         6.16       23.0  4.7958
# 3     17.07         6.16       20.0  4.4721
# 4     17.09         6.16       12.0  3.4641
# ...     ...          ...        ...     ...
# 1645  49.91         6.16       22.0  4.6904
# 1646  49.93         6.16       18.0  4.2426
# 1647  49.95         6.16       16.0  4.0000
# 1648  49.97         6.16       20.0  4.4721
# 1649  49.99         6.16       22.0  4.6904
#
# [1650 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/DR002/BSO-LSO2_braggbrentano_2tw.csv')]
# 30
#       Angle  TimePerStep  Intensity     ESD
# 0     17.01         6.16       17.0  4.1231
# 1     17.03         6.16       23.0  4.7958
# 2     17.05         6.16       29.0  5.3852
# 3     17.07         6.16       29.0  5.3852
# 4     17.09         6.16       45.0  6.7082
# ...     ...          ...        ...     ...
# 1645  49.91         6.16       21.0  4.5826
# 1646  49.93         6.16       31.0  5.5678
# 1647  49.95         6.16       27.0  5.1962
# 1648  49.97         6.16       17.0  4.1231
# 1649  49.99         6.16       12.0  3.4641
#
# [1650 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/DR008/dr008_LSO_BSO_STO_2tw_0D_002.csv'), PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/DR008/dr008tt1_LSO_BSO_STO_2tw_0D_002.csv'), PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/DR008/dr008tt2_LSO_BSO_STO_2tw_0D_002.csv')]
# 31
#      Angle  TimePerStep  Intensity     ESD
# 0    42.51          8.8       53.0  7.2801
# 1    42.53          8.8       60.0  7.7460
# 2    42.55          8.8       56.0  7.4833
# 3    42.57          8.8       44.0  6.6332
# 4    42.59          8.8       69.0  8.3066
# ..     ...          ...        ...     ...
# 270  47.91          8.8       37.0  6.0828
# 271  47.93          8.8       36.0  6.0000
# 272  47.95          8.8       43.0  6.5574
# 273  47.97          8.8       38.0  6.1644
# 274  47.99          8.8       46.0  6.7823
#
# [275 rows x 4 columns]
# 31
#      Angle  TimePerStep  Intensity      ESD
# 0    42.51          8.8       88.0   9.3808
# 1    42.53          8.8       61.0   7.8102
# 2    42.55          8.8      106.0  10.2956
# 3    42.57          8.8       88.0   9.3808
# 4    42.59          8.8       80.0   8.9443
# ..     ...          ...        ...      ...
# 270  47.91          8.8       27.0   5.1962
# 271  47.93          8.8       22.0   4.6904
# 272  47.95          8.8       31.0   5.5678
# 273  47.97          8.8       22.0   4.6904
# 274  47.99          8.8       29.0   5.3852
#
# [275 rows x 4 columns]
# 31
#        Angle  TimePerStep  Intensity     ESD
# 0    40.0075          4.4       25.0  5.0000
# 1    40.0225          4.4       23.0  4.7958
# 2    40.0375          4.4       17.0  4.1231
# 3    40.0525          4.4       14.0  3.7417
# 4    40.0675          4.4       22.0  4.6904
# ..       ...          ...        ...     ...
# 528  47.9275          4.4       14.0  3.7417
# 529  47.9425          4.4       23.0  4.7958
# 530  47.9575          4.4       22.0  4.6904
# 531  47.9725          4.4       14.0  3.7417
# 532  47.9875          4.4       23.0  4.7958
#
# [533 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/DR012/DR012_LSO_BSO_BSO_STO_2tw_0D_002.csv')]
# 31
#      Angle  TimePerStep  Intensity     ESD
# 0    40.01          4.4       20.0  4.4721
# 1    40.03          4.4       21.0  4.5826
# 2    40.05          4.4       24.0  4.8990
# 3    40.07          4.4       16.0  4.0000
# 4    40.09          4.4       32.0  5.6569
# ..     ...          ...        ...     ...
# 395  47.91          4.4       23.0  4.7958
# 396  47.93          4.4       47.0  6.8557
# 397  47.95          4.4       45.0  6.7082
# 398  47.97          4.4       41.0  6.4031
# 399  47.99          4.4       45.0  6.7082
#
# [400 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM001/EM001_BSO_STO_Treated_2thetaomega_1D_1.csv'), PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM001/EM001_BSO_STO_Treated_2tw_0D_002.csv')]
# 31
#            Angle  TimePerStep  Intensity      ESD
# 0      20.016248      197.115      185.0  13.6015
# 1      20.035943      197.115      201.0  14.1774
# 2      20.055639      197.115      202.0  14.2127
# 3      20.075334      197.115      185.0  13.6015
# 4      20.095029      197.115      171.0  13.0767
# ...          ...          ...        ...      ...
# 5072  119.911439      197.115      135.0  11.6190
# 5073  119.931134      197.115      151.0  12.2882
# 5074  119.950829      197.115      139.0  11.7898
# 5075  119.970525      197.115      142.0  11.9164
# 5076  119.990220      197.115      114.0  10.6771
#
# [5077 rows x 4 columns]
# 31
#        Angle  TimePerStep  Intensity     ESD
# 0    43.0075          4.4       21.0  4.5826
# 1    43.0225          4.4       32.0  5.6569
# 2    43.0375          4.4       30.0  5.4772
# 3    43.0525          4.4       26.0  5.0990
# 4    43.0675          4.4       30.0  5.4772
# ..       ...          ...        ...     ...
# 295  47.4325          4.4       20.0  4.4721
# 296  47.4475          4.4       22.0  4.6904
# 297  47.4625          4.4       30.0  5.4772
# 298  47.4775          4.4       22.0  4.6904
# 299  47.4925          4.4       25.0  5.0000
#
# [300 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM002/EM002_BSO_STO_Treated_2tw_0D_002.csv')]
# 31
#        Angle  TimePerStep  Intensity     ESD
# 0    40.0075          4.4       11.0  3.3166
# 1    40.0225          4.4       12.0  3.4641
# 2    40.0375          4.4       12.0  3.4641
# 3    40.0525          4.4       20.0  4.4721
# 4    40.0675          4.4        9.0  3.0000
# ..       ...          ...        ...     ...
# 528  47.9275          4.4       18.0  4.2426
# 529  47.9425          4.4       30.0  5.4772
# 530  47.9575          4.4       17.0  4.1231
# 531  47.9725          4.4       19.0  4.3589
# 532  47.9875          4.4       19.0  4.3589
#
# [533 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM003/EM003_SSO_STO_Treated_2thetaomega_0D_001_1.csv'), PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM003/EM003_SSO_STO_Treated_2tw_002_1.csv')]
# 31
#       Angle  TimePerStep  Intensity     ESD
# 0    20.015          4.4       46.0  6.7823
# 1    20.035          4.4       50.0  7.0711
# 2    20.055          4.4       51.0  7.1414
# 3    20.075          4.4       51.0  7.1414
# 4    20.095          4.4       45.0  6.7082
# ..      ...          ...        ...     ...
# 245  24.915          4.4       57.0  7.5498
# 246  24.935          4.4       43.0  6.5574
# 247  24.955          4.4       45.0  6.7082
# 248  24.975          4.4       32.0  5.6569
# 249  24.995          4.4       41.0  6.4031
#
# [250 rows x 4 columns]
# 31
#      Angle  TimePerStep  Intensity     ESD
# 0    40.01          4.4       24.0  4.8990
# 1    40.03          4.4       20.0  4.4721
# 2    40.05          4.4       21.0  4.5826
# 3    40.07          4.4       18.0  4.2426
# 4    40.09          4.4       24.0  4.8990
# ..     ...          ...        ...     ...
# 395  47.91          4.4       32.0  5.6569
# 396  47.93          4.4       33.0  5.7446
# 397  47.95          4.4       20.0  4.4721
# 398  47.97          4.4       33.0  5.7446
# 399  47.99          4.4       21.0  4.5826
#
# [400 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM004/EM004_SSO_STO_Treated_2tw_0D_001_1.csv'), PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM004/EM004_SSO_STO_Treated_2tw_0D_002_1.csv')]
# 31
#        Angle  TimePerStep  Intensity     ESD
# 0    19.0125          4.4       25.0  5.0000
# 1    19.0275          4.4       28.0  5.2915
# 2    19.0425          4.4       27.0  5.1962
# 3    19.0575          4.4       26.0  5.0990
# 4    19.0725          4.4       29.0  5.3852
# ..       ...          ...        ...     ...
# 528  26.9325          4.4       29.0  5.3852
# 529  26.9475          4.4       19.0  4.3589
# 530  26.9625          4.4       25.0  5.0000
# 531  26.9775          4.4       25.0  5.0000
# 532  26.9925          4.4       22.0  4.6904
#
# [533 rows x 4 columns]
# 31
#      Angle  TimePerStep  Intensity     ESD
# 0    40.01          4.4       29.0  5.3852
# 1    40.03          4.4       20.0  4.4721
# 2    40.05          4.4       30.0  5.4772
# 3    40.07          4.4       24.0  4.8990
# 4    40.09          4.4       18.0  4.2426
# ..     ...          ...        ...     ...
# 395  47.91          4.4       14.0  3.7417
# 396  47.93          4.4       18.0  4.2426
# 397  47.95          4.4       21.0  4.5826
# 398  47.97          4.4       27.0  5.1962
# 399  47.99          4.4       20.0  4.4721
#
# [400 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM005/EM005_SSO_STO_Treated_2tw_0D_002_1.csv')]
# 31
#      Angle  TimePerStep  Intensity     ESD
# 0    40.01          4.4       16.0  4.0000
# 1    40.03          4.4       18.0  4.2426
# 2    40.05          4.4       17.0  4.1231
# 3    40.07          4.4       10.0  3.1623
# 4    40.09          4.4       20.0  4.4721
# ..     ...          ...        ...     ...
# 395  47.91          4.4       17.0  4.1231
# 396  47.93          4.4       16.0  4.0000
# 397  47.95          4.4       11.0  3.3166
# 398  47.97          4.4       17.0  4.1231
# 399  47.99          4.4       13.0  3.6056
#
# [400 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM006/EM006_SSO_STO_Treated_2tw_0D_002_1.csv')]
# 31
#      Angle  TimePerStep  Intensity     ESD
# 0    40.01          4.4       30.0  5.4772
# 1    40.03          4.4       33.0  5.7446
# 2    40.05          4.4       44.0  6.6332
# 3    40.07          4.4       20.0  4.4721
# 4    40.09          4.4       24.0  4.8990
# ..     ...          ...        ...     ...
# 395  47.91          4.4       31.0  5.5678
# 396  47.93          4.4       30.0  5.4772
# 397  47.95          4.4       26.0  5.0990
# 398  47.97          4.4       34.0  5.8310
# 399  47.99          4.4       24.0  4.8990
#
# [400 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM007/EM007_BSO_STO_Treated_2thetaomega_0D_002_1.csv')]
# 31
#      Angle  TimePerStep  Intensity     ESD
# 0    40.01          4.4       32.0  5.6569
# 1    40.03          4.4       30.0  5.4772
# 2    40.05          4.4       42.0  6.4807
# 3    40.07          4.4       28.0  5.2915
# 4    40.09          4.4       34.0  5.8310
# ..     ...          ...        ...     ...
# 395  47.91          4.4       26.0  5.0990
# 396  47.93          4.4       31.0  5.5678
# 397  47.95          4.4       37.0  6.0828
# 398  47.97          4.4       43.0  6.5574
# 399  47.99          4.4       52.0  7.2111
#
# [400 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM008/EM008_B.55S.45SO_SSO_STO_Treated_2tw_1D_1.csv')]
# 31
#           Angle  TimePerStep  Intensity     ESD
# 0     20.017648        96.39       59.0  7.6811
# 1     20.037343        96.39       57.0  7.5498
# 2     20.057039        96.39       59.0  7.6811
# 3     20.076734        96.39       66.0  8.1240
# 4     20.096429        96.39       53.0  7.2801
# ...         ...          ...        ...     ...
# 3041  79.911432        96.39       29.0  5.3852
# 3042  79.931128        96.39       25.0  5.0000
# 3043  79.950823        96.39       17.0  4.1231
# 3044  79.970519        96.39       28.0  5.2915
# 3045  79.990214        96.39       16.0  4.0000
#
# [3046 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM009/EM009_B.40S.60SO_SSO_STO_Treated_2thetaomega_0D_002_1_2.0_.csv')]
# 31
#       Angle  TimePerStep  Intensity     ESD
# 0    40.005          4.4       19.0  4.3589
# 1    40.015          4.4       21.0  4.5826
# 2    40.025          4.4       30.0  5.4772
# 3    40.035          4.4       18.0  4.2426
# 4    40.045          4.4       41.0  6.4031
# ..      ...          ...        ...     ...
# 795  47.955          4.4       20.0  4.4721
# 796  47.965          4.4       27.0  5.1962
# 797  47.975          4.4       29.0  5.3852
# 798  47.985          4.4       21.0  4.5826
# 799  47.995          4.4       28.0  5.2915
#
# [800 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM010/EM010_BSO_B.4S.6SO_SSO_STO_Treated_2thetaomega_0D_002_1.csv')]
# 31
#      Angle  TimePerStep  Intensity     ESD
# 0    40.01          4.4       28.0  5.2915
# 1    40.03          4.4       24.0  4.8990
# 2    40.05          4.4       33.0  5.7446
# 3    40.07          4.4       19.0  4.3589
# 4    40.09          4.4       19.0  4.3589
# ..     ...          ...        ...     ...
# 395  47.91          4.4       31.0  5.5678
# 396  47.93          4.4       31.0  5.5678
# 397  47.95          4.4       40.0  6.3246
# 398  47.97          4.4       29.0  5.3852
# 399  47.99          4.4       21.0  4.5826
#
# [400 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM011/EM011_B70S.30SO_SSO_STO_Treated_2thetaomega_0D_002_1.csv')]
# 31
#      Angle  TimePerStep  Intensity      ESD
# 0    41.01        10.56       91.0   9.5394
# 1    41.03        10.56       89.0   9.4340
# 2    41.05        10.56       78.0   8.8318
# 3    41.07        10.56      116.0  10.7703
# 4    41.09        10.56       93.0   9.6437
# ..     ...          ...        ...      ...
# 320  47.41        10.56      119.0  10.9087
# 321  47.43        10.56      112.0  10.5830
# 322  47.45        10.56      108.0  10.3923
# 323  47.47        10.56      106.0  10.2956
# 324  47.49        10.56      123.0  11.0905
#
# [325 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM012/EM012_L.03B.97SO_B.70S.30SO_SSO_STO_Treated_2thetaomega_0D_002_1.csv')]
# 31
#      Angle  TimePerStep  Intensity      ESD
# 0    41.01        10.56       82.0   9.0554
# 1    41.03        10.56       75.0   8.6603
# 2    41.05        10.56       65.0   8.0623
# 3    41.07        10.56       84.0   9.1652
# 4    41.09        10.56       63.0   7.9373
# ..     ...          ...        ...      ...
# 320  47.41        10.56      102.0  10.0995
# 321  47.43        10.56      102.0  10.0995
# 322  47.45        10.56      100.0  10.0000
# 323  47.47        10.56       90.0   9.4868
# 324  47.49        10.56       92.0   9.5917
#
# [325 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM013/EM013_L.05B.95SO_B.40S.60SO_SSO_STO_Treated_2thetaomega_0D_002_1.csv')]
# 32
#      Angle  TimePerStep  Intensity      ESD
# 0    41.01        10.56       94.0   9.6954
# 1    41.03        10.56       86.0   9.2736
# 2    41.05        10.56       96.0   9.7980
# 3    41.07        10.56      107.0  10.3441
# 4    41.09        10.56      113.0  10.6301
# ..     ...          ...        ...      ...
# 320  47.41        10.56       98.0   9.8995
# 321  47.43        10.56      112.0  10.5830
# 322  47.45        10.56      102.0  10.0995
# 323  47.47        10.56      100.0  10.0000
# 324  47.49        10.56       98.0   9.8995
#
# [325 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM014/EM014_L.05B.95SO_B.55S.45SO_SSO_STO_Treated_2thetaomega_0D_002_1.csv')]
# 32
#      Angle  TimePerStep  Intensity      ESD
# 0    41.01        10.56      106.0  10.2956
# 1    41.03        10.56       80.0   8.9443
# 2    41.05        10.56      104.0  10.1980
# 3    41.07        10.56      107.0  10.3441
# 4    41.09        10.56      130.0  11.4018
# ..     ...          ...        ...      ...
# 320  47.41        10.56      109.0  10.4403
# 321  47.43        10.56       93.0   9.6437
# 322  47.45        10.56      112.0  10.5830
# 323  47.47        10.56       87.0   9.3274
# 324  47.49        10.56       86.0   9.2736
#
# [325 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM015/EM015_L.05B.95SO_B.70S.30SO_SSO_STO_Treated_2thetaomega_0D_002_1.csv')]
# 32
#      Angle  TimePerStep  Intensity      ESD
# 0    41.01        10.56      116.0  10.7703
# 1    41.03        10.56       79.0   8.8882
# 2    41.05        10.56       96.0   9.7980
# 3    41.07        10.56       71.0   8.4261
# 4    41.09        10.56      112.0  10.5830
# ..     ...          ...        ...      ...
# 320  47.41        10.56      111.0  10.5357
# 321  47.43        10.56       87.0   9.3274
# 322  47.45        10.56      114.0  10.6771
# 323  47.47        10.56      109.0  10.4403
# 324  47.49        10.56      111.0  10.5357
#
# [325 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM016/EM016_L.05B.95SO_B.40S.60SO_SSO_STO_Treated_2thetaomega_0D_002_1.csv')]
# 31
#      Angle  TimePerStep  Intensity     ESD
# 0    41.01        10.56       59.0  7.6811
# 1    41.03        10.56       67.0  8.1854
# 2    41.05        10.56       75.0  8.6603
# 3    41.07        10.56       77.0  8.7750
# 4    41.09        10.56       72.0  8.4853
# ..     ...          ...        ...     ...
# 320  47.41        10.56       61.0  7.8102
# 321  47.43        10.56       83.0  9.1104
# 322  47.45        10.56       78.0  8.8318
# 323  47.47        10.56       56.0  7.4833
# 324  47.49        10.56       59.0  7.6811
#
# [325 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM017/EM017_L.05B.95SO_STO_Treated_2thetaomega_0D_002_1.csv')]
# 31
#      Angle  TimePerStep  Intensity      ESD
# 0    41.01        10.56       66.0   8.1240
# 1    41.03        10.56       62.0   7.8740
# 2    41.05        10.56       67.0   8.1854
# 3    41.07        10.56       70.0   8.3666
# 4    41.09        10.56       69.0   8.3066
# ..     ...          ...        ...      ...
# 320  47.41        10.56      129.0  11.3578
# 321  47.43        10.56      101.0  10.0499
# 322  47.45        10.56      100.0  10.0000
# 323  47.47        10.56       95.0   9.7468
# 324  47.49        10.56       97.0   9.8489
#
# [325 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM018/EM018_L.05B.95SO_B.25S.75SO_SSO_STO_Treated_2thetaomega_0D_002_1.csv')]
# 31
#      Angle  TimePerStep  Intensity     ESD
# 0    41.01        10.56       59.0  7.6811
# 1    41.03        10.56       66.0  8.1240
# 2    41.05        10.56       71.0  8.4261
# 3    41.07        10.56       62.0  7.8740
# 4    41.09        10.56       71.0  8.4261
# ..     ...          ...        ...     ...
# 320  47.41        10.56       84.0  9.1652
# 321  47.43        10.56       73.0  8.5440
# 322  47.45        10.56       61.0  7.8102
# 323  47.47        10.56       76.0  8.7178
# 324  47.49        10.56       50.0  7.0711
#
# [325 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM019/EM019_L.05B.95SO_B.40S.60SO_SSO_STO_Treated_2thetaomega_0D_002_1.csv')]
# 31
#      Angle  TimePerStep  Intensity      ESD
# 0    41.01        10.56       91.0   9.5394
# 1    41.03        10.56       73.0   8.5440
# 2    41.05        10.56       79.0   8.8882
# 3    41.07        10.56      121.0  11.0000
# 4    41.09        10.56       95.0   9.7468
# ..     ...          ...        ...      ...
# 320  47.41        10.56      124.0  11.1355
# 321  47.43        10.56      157.0  12.5300
# 322  47.45        10.56      130.0  11.4018
# 323  47.47        10.56      110.0  10.4881
# 324  47.49        10.56      101.0  10.0499
#
# [325 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM020/EM020_L.05B.95SO_B.40S.60SO_SSO_STO_Treated_2thetaomega_0D_002_1.csv')]
# 31
#      Angle  TimePerStep  Intensity     ESD
# 0    41.01        10.56       82.0  9.0554
# 1    41.03        10.56       66.0  8.1240
# 2    41.05        10.56       68.0  8.2462
# 3    41.07        10.56       96.0  9.7980
# 4    41.09        10.56       67.0  8.1854
# ..     ...          ...        ...     ...
# 320  47.41        10.56       52.0  7.2111
# 321  47.43        10.56       61.0  7.8102
# 322  47.45        10.56       65.0  8.0623
# 323  47.47        10.56       54.0  7.3485
# 324  47.49        10.56       71.0  8.4261
#
# [325 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM021/EM021_L.002B.998SO_B.40S.60SO_SSO_STO_Treated_2thetaomega_0D_002_1.csv')]
# 31
#      Angle  TimePerStep  Intensity      ESD
# 0    41.01        10.56       73.0   8.5440
# 1    41.03        10.56       83.0   9.1104
# 2    41.05        10.56      101.0  10.0499
# 3    41.07        10.56       86.0   9.2736
# 4    41.09        10.56       81.0   9.0000
# ..     ...          ...        ...      ...
# 320  47.41        10.56       70.0   8.3666
# 321  47.43        10.56       70.0   8.3666
# 322  47.45        10.56       76.0   8.7178
# 323  47.47        10.56       81.0   9.0000
# 324  47.49        10.56       85.0   9.2195
#
# [325 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM022/EM022_L.07B.93SO_B.40S.60SO_SSO_STO_Treated_2thetaomega_0D_002_1.csv')]
# 31
#      Angle  TimePerStep  Intensity     ESD
# 0    41.01        10.56       83.0  9.1104
# 1    41.03        10.56       84.0  9.1652
# 2    41.05        10.56       74.0  8.6023
# 3    41.07        10.56       73.0  8.5440
# 4    41.09        10.56       94.0  9.6954
# ..     ...          ...        ...     ...
# 320  47.41        10.56       88.0  9.3808
# 321  47.43        10.56       79.0  8.8882
# 322  47.45        10.56       65.0  8.0623
# 323  47.47        10.56       76.0  8.7178
# 324  47.49        10.56       89.0  9.4340
#
# [325 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM023/EM023_L.03B.97SO_B.40S.60SO_SSO_STO_Treated_2thetaomega_0D_002_1.csv')]
# 32
#      Angle  TimePerStep  Intensity      ESD
# 0    41.01        10.56      129.0  11.3578
# 1    41.03        10.56      121.0  11.0000
# 2    41.05        10.56      124.0  11.1355
# 3    41.07        10.56      113.0  10.6301
# 4    41.09        10.56      134.0  11.5758
# ..     ...          ...        ...      ...
# 320  47.41        10.56      116.0  10.7703
# 321  47.43        10.56      145.0  12.0416
# 322  47.45        10.56      129.0  11.3578
# 323  47.47        10.56      114.0  10.6771
# 324  47.49        10.56      138.0  11.7473
#
# [325 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM024/EM024_LSO_BSO_B.40S.60SO_SSO_STO_Treated_2thetaomega_0D_002_1.csv')]
# 32
#      Angle  TimePerStep  Intensity      ESD
# 0    41.01        10.56      110.0  10.4881
# 1    41.03        10.56       85.0   9.2195
# 2    41.05        10.56       81.0   9.0000
# 3    41.07        10.56       75.0   8.6603
# 4    41.09        10.56      107.0  10.3441
# ..     ...          ...        ...      ...
# 320  47.41        10.56       93.0   9.6437
# 321  47.43        10.56       74.0   8.6023
# 322  47.45        10.56       92.0   9.5917
# 323  47.47        10.56       80.0   8.9443
# 324  47.49        10.56       95.0   9.7468
#
# [325 rows x 4 columns]
# [PosixPath('/Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM027/EM027_LSO_BSO_STO_Treated_2thetaomega_0D_002_1.csv')]
# 32
#      Angle  TimePerStep  Intensity      ESD
# 0    41.01        10.56       87.0   9.3274
# 1    41.03        10.56       90.0   9.4868
# 2    41.05        10.56      103.0  10.1489
# 3    41.07        10.56       84.0   9.1652
# 4    41.09        10.56      105.0  10.2470
# ..     ...          ...        ...      ...
# 320  47.41        10.56      128.0  11.3137
# 321  47.43        10.56      123.0  11.0905
# 322  47.45        10.56      101.0  10.0499
# 323  47.47        10.56      101.0  10.0499
# 324  47.49        10.56      109.0  10.4403
#
# [325 rows x 4 columns]

# %% [markdown]
# ## Select Plotting Data and Rename for Export

# %%
# List all available measurements in ttw_HC007
ttw_DR001.list_measurements()

# Select specific measurements (example: indices 0 and 2)
ttw_HC015_selected = ttw_HC015.select_measurements([0, 2])

# Or select a single measurement (example: index 1)
ttw_HC015_selected = ttw_HC015.select_measurements([1])

print(ttw_HC015_selected.list_measurements())
# Out:
# Available measurements in DR001:
# --------------------------------------------------
# Index 0: /Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/DR001/BSO-LSO1_2tw_0D_002_1..csv
#   Plot string: BSO-LSO1_2tw_0D_002_1.
#   Data points: 1650
#
# Invalid indices: [2]. Available indices: 0-1
# Available measurements in HC015:
# --------------------------------------------------
# Index 0: /Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/HC015/HC015_LSO_BSO_STO_2tw_0D_002.csv
#   Plot string: HC015_LSO_BSO_STO_2tw_0D_002
#   Data points: 533
#
# None

# %%
single_dat = [ttw_JT143]
multi_dat = [ttw_EM023, ttw_JT129, ttw_JT143, ]#[ttw_HC011, ttw_HC013, ttw_HC015]
#multi_dat = [ttw_SR001, ttw_SR002, ttw_SR003]

# If exporting the data this ensures th2at the labels are updated by the user to be correct from their original "filename" assignement
if export_data == True: 
    multi_dat = update_plot_string(multi_dat) #EM011_$Ba_{0.7}Sr_{0.3}SnO_3$
# Out:
# New plot string for /Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/EM023/EM023_L.03B.97SO_B.40S.60SO_SSO_STO_Treated_2thetaomega_0D_002_1.csv: EM023
# New plot string for /Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/JT129/JT129_BTO_La0.003Ba0.97SnO3_Ba0.4Sr0.6SnO3_SrSnO3_on_T-STO_2tw_formal_40-50 degree_(002)_1.csv: JT129
# New plot string for /Users/horatiocox/Desktop/RUG_Postdoc/Experiments/XRD/JT143/JT143_BTO(60nm)_La0.002Ba0.98SnO3(5nm)_Ba0.4Sr0.6SnO3_SrSnO3_on_T-STO_2tw_002_highres_1.csv: JT143

# %% [markdown]
# ## Plot the Data

# %%
fig1 = ttw_plot_same( single_dat, x_lim=[40,48], norm_plot = True, linear_subtraction=False, log_plot=True, med_filt=0 )

if export_data == True:
    fig1.savefig(single_dat[0].folder_path.joinpath(f'{powerpoint_string}_single_ttw.{fig_format}'), dpi=600, bbox_inches='tight', transparent=plot_transparency)

# %%
#export_data = True
fig1 = ttw_plot_same(multi_dat , x_lim=[42,47.5], norm_plot = True, 
                     STO_align=True, STO_align_showfit=False,
                     linear_subtraction=False, log_plot=True, med_filt=0,
                     bulk_params = ['BSO', 'BTO_tetragonal'])

if export_data == True:
    fig1.savefig(multi_dat[0].folder_path.joinpath(f'{powerpoint_string}_multi_ttw.{fig_format}'), dpi=600, bbox_inches='tight', transparent=plot_transparency)
# Out:
# Pseudo-Voigt failed: Optimal parameters not found: The maximum number of function evaluations is exceeded.. Retrying with Lorentzian fallback.

# %%
import sys, importlib
import ttw_functions
importlib.reload(ttw_functions)
from ttw_functions import *

# %% [markdown]
# ### Offset Examples for Log Scale
#
# **How to use the `offset` parameter:**
#
# - `offset=None` (default): No offset, plots overlay directly
# - `offset=10`: Each successive plot is 1 decade (10x) higher - gives nice visual separation
# - `offset=100`: Each successive plot is 2 decades (100x) higher - more separation
# - `offset=5`: Each successive plot is ~0.7 decades higher - moderate separation
#
# **Why multiplicative offsets work in log scale:**
# - In log scale: log(y × 10) = log(y) + 1, so multiplying by 10 shifts up by 1 unit
# - This gives uniform visual spacing regardless of the intensity values
# - Both your weak film peaks and strong STO peaks remain clearly visible

# %% [markdown]
# ### Y-Axis Labeling Convention
#
# **Standard practice in XRD literature:**
# - Y-axis: "Intensity (a.u.)" regardless of log or linear scale
# - When log scale is used, the scale is evident from the axis tick formatting (10¹, 10², 10³, etc.)
# - This follows standard scientific publication conventions
#
# **When offset is applied:**
# - Log scale with offset: "Log Intensity (a.u., offset)"
#   - Tick marks are removed, so "Log" makes it explicit
# - Linear scale with offset: "Intensity (a.u., offset)"
# - In both cases, absolute values are meaningless - focus is on relative peak positions and shapes

# %%
# Example 2: With offset=10 (1 decade spacing) - RECOMMENDED for thin films on STO
# Each plot is shifted up by 10x (1 decade in log scale)
# This keeps both substrate and film peaks visible with clear separation
fig_offset = ttw_plot_same(
    multi_dat, 
    x_lim=[42, 47], 
    norm_plot=True,  # Use raw intensities for meaningful comparison
    linear_subtraction=False, 
    log_plot=True, 
    med_filt=0,
    offset=5000  # 1 decade spacing between plots
)
#export_data = True
if export_data == True:
    fig_offset.savefig(multi_dat[0].folder_path.joinpath(f'{powerpoint_string}_ttw_offset.{fig_format}'), 
                       dpi=600, bbox_inches='tight', transparent=plot_transparency)

# %%
len(multi_dat[0].plot_string)
# Out:
# 1

# %%
ttw_SR001

# %%
# Convert from Omega and 2Theta angles to lattice parameters a and c
# Using the same method as in the RSM class

# Data from the table above
data = {
    'No.': [1, 2, 3, 4],
    'Omega (°)': [17.44430, 17.64430, 18.32430, 20.16430],
    '2Theta (°)': [72.37334, 72.90512, 74.00806, 77.31689],
    'Qx (rlu)': [0.246243, 0.248642, 0.250210, 0.257202],
    'Qy (rlu)': [0.725725, 0.730035, 0.740077, 0.768956],
    'FWHMx (rlu)': [0.008749, 0.010051, 0.004130, 0.000483],
    'FWHMy (rlu)': [0.000000, 0.000000, 0.000000, 0.000000],
    'd-spacing': [1.304667, 1.296457, 1.279840, 1.233117],
    'Intensity': [28.0, 24.1, 42.3, 23643.9],
    'Label': ['', '', '', '']
}

df_qspace = pd.DataFrame(data)

# X-ray wavelength (Cu Kα)
wavelength = 1.5405980  # Å

# Convert angles to radians
two_theta = np.radians(df_qspace['2Theta (°)'])
omega = np.radians(df_qspace['Omega (°)'])

# Calculate q_x and q_z for reciprocal space coordinates (same as RSM class)
q_x = ((4 * np.pi) / wavelength) * (np.sin(two_theta / 2) * np.sin((two_theta / 2) - omega))
q_z = ((4 * np.pi) / wavelength) * (np.sin(two_theta / 2) * np.cos((two_theta / 2) - omega))

# Store the calculated Qx and Qz values
df_qspace['Qx (Å⁻¹)'] = q_x
df_qspace['Qz (Å⁻¹)'] = q_z

# Define the conversion functions (from RSM class)
def Qx_to_a(Qx):
    return (2 * np.pi) / Qx  # a = 2π/Qx

def Qz_to_c(Qz):
    return (6 * np.pi) / Qz  # c = 6π/Qz (from l=3 for 103 reflection)

# Calculate a and c lattice parameters from q_x and q_z based on this being the 103 peak
df_qspace['a (Å)'] = Qx_to_a(q_x)
df_qspace['c (Å)'] = Qz_to_c(q_z)

# Display the results
print("Converted to Lattice Parameters:")
print("="*110)
display(df_qspace[['No.', 'Omega (°)', '2Theta (°)', 'Qx (Å⁻¹)', 'Qz (Å⁻¹)', 
                    'a (Å)', 'c (Å)', 'Intensity']])

print("\n" + "="*110)
print(f"\nAverage lattice parameters (weighted by intensity):")
total_intensity = df_qspace['Intensity'].sum()
a_weighted = (df_qspace['a (Å)'] * df_qspace['Intensity']).sum() / total_intensity
c_weighted = (df_qspace['c (Å)'] * df_qspace['Intensity']).sum() / total_intensity
print(f"a = {a_weighted:.4f} Å")
print(f"c = {c_weighted:.4f} Å")
print(f"c/a ratio = {c_weighted/a_weighted:.4f}")

print(f"\nSimple average lattice parameters:")
print(f"a = {df_qspace['a (Å)'].mean():.4f} Å (std: {df_qspace['a (Å)'].std():.4f} Å)")
print(f"c = {df_qspace['c (Å)'].mean():.4f} Å (std: {df_qspace['c (Å)'].std():.4f} Å)")
print(f"c/a ratio = {(df_qspace['c (Å)']/df_qspace['a (Å)']).mean():.4f}")

print("\n" + "="*110)
print("\nReference materials:")
print("BaSnO3 bulk:        a = 4.116 Å, c = 4.116 Å  (cubic, c/a = 1.000)")
print("SrSnO3 bulk:        a = 4.036 Å, c = 4.036 Å  (cubic, c/a = 1.000)") 
print("LaScO3 bulk:        a = 4.052 Å, c = 4.052 Å  (cubic, c/a = 1.000)")
print("SrTiO3 (substrate): a = 3.905 Å, c = 3.905 Å  (cubic, c/a = 1.000)")
print("\nNote: Peak 4 has ~1000x higher intensity - likely the dominant phase")
# Out:
# Converted to Lattice Parameters:
# ==============================================================================================================
#    No.  Omega (°)  2Theta (°)  Qx (Å⁻¹)  Qz (Å⁻¹)     a (Å)     c (Å)  \
# 0    1    17.4443    72.37334  1.547422  4.560554  4.060421  4.133172
# 1    2    17.6443    72.90512  1.562499  4.587642  4.021242  4.108768
# 2    3    18.3243    74.00806  1.572357  4.650744  3.996031  4.053019
# 3    4    20.1643    77.31689  1.616291  4.832225  3.887411  3.900803
#
#    Intensity
# 0       28.0
# 1       24.1
# 2       42.3
# 3    23643.9
# ==============================================================================================================
#
# Average lattice parameters (weighted by intensity):
# a = 3.8879 Å
# c = 3.9016 Å
# c/a ratio = 1.0035
#
# Simple average lattice parameters:
# a = 3.9913 Å (std: 0.0741 Å)
# c = 4.0489 Å (std: 0.1043 Å)
# c/a ratio = 1.0143
#
# ==============================================================================================================
#
# Reference materials:
# BaSnO3 bulk:        a = 4.116 Å, c = 4.116 Å  (cubic, c/a = 1.000)
# SrSnO3 bulk:        a = 4.036 Å, c = 4.036 Å  (cubic, c/a = 1.000)
# LaScO3 bulk:        a = 4.052 Å, c = 4.052 Å  (cubic, c/a = 1.000)
# SrTiO3 (substrate): a = 3.905 Å, c = 3.905 Å  (cubic, c/a = 1.000)
#
# Note: Peak 4 has ~1000x higher intensity - likely the dominant phase

# %% [markdown]
# ## XRD Simulation: Complete Physical Model of Crystal Imperfections
#
# ### Critical Fix to Previous Model ❗
#
# **The Problem with the Old Model:**
# ```python
# # OLD (WRONG):
# N_array = thickness_A / lattice_array  # N was same for all crystallites!
# laue = np.sin(N_array * Q_array * c_array / 2)**2 / (np.sin(Q_array * c_array / 2)**2)
# # This incorrectly averaged out the lattice parameter in the Laue function
# ```
#
# **Why This Was Wrong:**
# - The Laue function depends on the **phase difference**: N × Q × c
# - If N and c both depend on lattice parameter 'a', but you use a constant thickness, the variations cancel out
# - Result: Laue oscillations didn't respond properly to lattice parameter distributions
#
# **The Fix:**
# ```python
# # NEW (CORRECT):
# thickness_array = [individual thickness for each crystallite]
# lattice_array = [individual lattice parameter for each crystallite]
# N_array = thickness_array / lattice_array  # DIFFERENT N for each!
# c_array = lattice_array                     # DIFFERENT c for each!
# laue = np.sin(N_array * Q_array * c_array / 2)**2 / (np.sin(Q_array * c_array / 2)**2)
# ```
#
# Now each crystallite truly has its own thickness, lattice parameter, and orientation!
#
# ---
#
# ### Three Independent Sources of Disorder
#
# #### 1. **Thickness Variation** (Surface Roughness)
# - **Distribution Type**: Gaussian
# - **Parameter**: `thickness_sigma_percent` (% of mean)
# - **Physical Origin**: Non-uniform growth, surface roughness
# - **Effect**:
#   - Changes N (number of unit cells) for each crystallite
#   - Laue oscillations go out of phase → damping
#   - Each crystallite has different interference pattern
#
# #### 2. **Lattice Parameter Gradient** (Relaxation)
# - **Distribution Type**: Linear gradient
# - **Parameters**: `lattice_gradient = [bottom, top]` (Å)
# - **Physical Origin**: Strain relaxation through film thickness, composition gradients
# - **Effect**:
#   - Shifts Bragg peak position (different d-spacing)
#   - Changes c parameter → affects Laue phase
#   - Creates asymmetric peak broadening
#
# #### 3. **Mosaicity** (Crystallite Tilt)
# - **Distribution Type**: Gaussian
# - **Parameter**: `mosaicity_fwhm_deg` (degrees FWHM)
# - **Physical Origin**: Grain boundaries, threading dislocations, growth defects
# - **Effect**:
#   - Tilted crystallites scatter at slightly different 2θ
#   - Broadens peaks symmetrically
#   - Does NOT affect Laue oscillations (same N and c, just rotated)
#
# ---
#
# ### Five Comparison Cases
#
# | Case | Thickness | Lattice | Mosaicity | Color | Line |
# |------|-----------|---------|-----------|-------|------|
# | **Perfect** | Fixed | Fixed | 0° | Green | Solid |
# | **Thickness Only** | Variable | Fixed | 0° | Blue | Dashed |
# | **Lattice Only** | Fixed | Gradient | 0° | Orange | Dash-dot |
# | **Mosaicity Only** | Fixed | Fixed | Variable | Purple | Dotted |
# | **All Combined** | Variable | Gradient | Variable | Red | Solid |
#
# ---
#
# ### Key Physics Insights
#
# 1. **Each disorder source has a unique signature**:
#    - Thickness → Laue damping, symmetric
#    - Lattice gradient → Peak broadening + Laue damping
#    - Mosaicity → Peak broadening only
#
# 2. **Laue oscillations now respond correctly**:
#    - Thickness variation: Different N for each crystallite → phase mismatch
#    - Lattice variation: Different c for each crystallite → phase mismatch
#    - Both create destructive interference → fringes vanish
#
# 3. **The "All Combined" case is most realistic**:
#    - Real films have all three effects
#    - Shows how they compound to suppress Laue fringes
#    - Matches experimental data much better
#
# ---
#
# ### Adjustable Parameters
#
# ```python
# # USER CONTROLS:
# thickness_sigma_percent = 5.0       # % roughness
# lattice_gradient = [4.110, 4.122]   # Å [bottom, top]
# mosaicity_fwhm_deg = 0.3            # degrees
# n_crystallites = 10000              # statistics quality
# ```
#
# **Typical Values:**
# - **High-quality epitaxy**: thickness_σ ~ 2%, lattice gradient ~ 0.002 Å, mosaicity ~ 0.1°
# - **Moderate quality**: thickness_σ ~ 5%, lattice gradient ~ 0.012 Å, mosaicity ~ 0.3°
# - **Poor quality**: thickness_σ ~ 10%, lattice gradient ~ 0.05 Å, mosaicity ~ 1.0°

# %%
# ========== XRD Simulation: Layer-by-Layer Model ==========
# Uses the new vectorized functions from ttw_models.py

import numpy as np
import matplotlib.pyplot as plt
import time
# Ensure functions are imported (if not already from Cell 1)
from ttw_models import create_crystal_system, calculate_xrd_vectorized

# ========== Film Parameters ==========
lattice_BSO_mean = 4.116  # Å (BaSnO3 - mean value)
thickness_nm_mean = 20    # nm (mean thickness)
wavelength = 1.5405980    # Å (Cu Kα)

# Derived parameters
nz_mean = int((thickness_nm_mean * 10) / lattice_BSO_mean)
nx_sim, ny_sim = 10, 10 # 10,000 crystallites (columns)

# ========== Distribution Parameters (USER ADJUSTABLE) ==========
roughness_nm = 1.0        # Surface roughness (nm)
lattice_gradient = [4.07, 4.11] # [Interface, Surface]
mosaicity_fwhm_deg = 0.5  # Mosaicity FWHM (degrees)
relaxation_length = 15    # Layers for exponential relaxation
spatial_var_percent = 0.1 # Spatial variation of lattice (%)

# Convert roughness to layers
roughness_layers = (roughness_nm * 10) / lattice_BSO_mean

print(f"========== Simulation Parameters ==========")
print(f"Grid size: {nx_sim}x{ny_sim} ({nx_sim*ny_sim} columns)")
print(f"Mean thickness: {thickness_nm_mean} nm (~{nz_mean} layers)")
print(f"Lattice gradient: {lattice_gradient[0]} -> {lattice_gradient[1]} Å (Exponential)")

# ========== Define Cases ==========
cases = [
    {'name': 'Perfect Crystal', 'color': 'green', 'line_type': '-',
     'params': {'mode': 'perfect', 'roughness_layers': 0, 'mosaicity_fwhm': 0, 'lattice_gradient': [lattice_BSO_mean, lattice_BSO_mean]}},
    
    {'name': 'Thickness Only', 'color': 'blue', 'line_type': '--',
     'params': {'mode': 'perfect', 'roughness_layers': roughness_layers, 'mosaicity_fwhm': 0, 'lattice_gradient': [lattice_BSO_mean, lattice_BSO_mean]}},
    
    {'name': 'Lattice Only', 'color': 'orange', 'line_type': '-.',
     'params': {'mode': 'gradient', 'gradient_type': 'exponential', 'relaxation_length': relaxation_length,
                'roughness_layers': 0, 'mosaicity_fwhm': 0, 'lattice_gradient': lattice_gradient}},
    
    {'name': 'Mosaicity Only', 'color': 'purple', 'line_type': ':',
     'params': {'mode': 'perfect', 'roughness_layers': 0, 'mosaicity_fwhm': mosaicity_fwhm_deg, 'lattice_gradient': [lattice_BSO_mean, lattice_BSO_mean]}},
    
    {'name': 'All Combined', 'color': 'red', 'line_type': '-',
     'params': {'mode': 'full', 'gradient_type': 'exponential', 'relaxation_length': relaxation_length,
                'roughness_layers': roughness_layers, 'mosaicity_fwhm': mosaicity_fwhm_deg, 
                'lattice_gradient': lattice_gradient, 'spatial_var_percent': spatial_var_percent}}
]

# ========== Run Simulations ==========
results = []
print(f"\nRunning simulations...")
start_time = time.time()

for i, case in enumerate(cases):
    t0 = time.time()
    
    # Create system
    lat_arr, h_map, t_arr = create_crystal_system(
        nx_sim, ny_sim, nz_mean,
        lattice_perfect=lattice_BSO_mean,
        **case['params']
    )
    
    # Calculate XRD
    tt, intensity = calculate_xrd_vectorized(
        lat_arr, h_map, t_arr,
        two_theta_range=(40, 46), # Focused on the peak
        wavelength=wavelength,
        instrumental_broadening=0.05,
        n_points=3000
    )
    
    results.append({
        'name': case['name'],
        'color': case['color'],
        'line_type': case['line_type'],
        'two_theta': tt,
        'intensity': intensity
    })
    
    print(f"Case {i+1}/{len(cases)} - {case['name']}: {time.time()-t0:.2f}s")

print(f"Total time: {time.time()-start_time:.2f}s")

# ========== Plot Results ==========
plt.figure(figsize=(10, 7))

# Plot experimental data (EM007) if available
try:
    two_theta_exp = ttw_EM007.ttw_df[0]['Angle'].values
    intensity_exp = ttw_EM007.ttw_df[0]['Intensity'].values
    mask = (two_theta_exp >= 40) & (two_theta_exp <= 46)
    plt.plot(two_theta_exp[mask], intensity_exp[mask]/intensity_exp[mask].max(), 
             'k-', alpha=0.3, linewidth=3, label='Experiment (EM007)')
except NameError:
    print("Experimental data (ttw_EM007) not found, skipping plot.")

for res in results:
    plt.plot(res['two_theta'], res['intensity'], 
             color=res['color'], linestyle=res['line_type'], 
             label=res['name'], linewidth=2, alpha=0.8)

plt.xlabel(r'$2\theta$ (degrees)')
plt.ylabel('Normalized Intensity')
plt.title('XRD Simulation: Layer-by-Layer Model')
plt.legend()
plt.yscale('log')
plt.ylim(1e-4, 1.5)
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# ========== Simulation Parameters ==========
# Grid size: 10x10 (100 columns)
# Mean thickness: 20 nm (~48 layers)
# Lattice gradient: 4.07 -> 4.11 Å (Exponential)
#
# Running simulations...
# Case 1/5 - Perfect Crystal: 0.44s
# Case 2/5 - Thickness Only: 0.28s
# Case 3/5 - Lattice Only: 0.28s
# Case 4/5 - Mosaicity Only: 0.28s
# Case 5/5 - All Combined: 0.28s
# Total time: 1.57s

# %% [markdown]
# ## Real-Space XRD Simulation: Layer-by-Layer Dynamical Diffraction
#
# ### Concept: Discrete Laue Function in Real Space
#
# Instead of analytically computing the Laue function, we explicitly model the film atom-by-atom (or unit-cell-by-unit-cell) in real space.
#
# ### 1. How Roughness Works (The "Mask" Method)
# You asked: *"Does the roughness change the max z value? Is the array square?"*
#
# *   **The Array is a Box:** To use vectorized math (which is fast), we must define a fixed 3D grid ($N_x \times N_y \times N_z$). This is a "perfect box" in computer memory.
# *   **The Height Map:** We generate a 2D map `height_map[x,y]` that defines the actual thickness at each spot (e.g., Column A is 48 layers, Column B is 50 layers).
# *   **The Mask:** We create a boolean mask (True/False).
#     *   If layer index $k < \text{height}$, `Mask = True` (Atom exists).
#     *   If layer index $k \ge \text{height}$, `Mask = False` (Atom is missing).
# *   **The Calculation:** We calculate waves for *every* point in the box, but then multiply by the mask.
#     *   `Wave_Actual = Wave_Calculated * Mask`
#     *   Missing atoms become **0**. They contribute nothing to the sum. This correctly simulates a rough surface.
#
# ### 2. How Interference is Calculated (Phase Accumulation)
# You asked: *"Is the key thing the phase relative to z=0? Accumulating lattice parameter?"*
#
# **Yes, exactly.** This is the "Cumulative Sum" method:
#
# 1.  **True Z-Position ($z_k$):**
#     We don't just say $z = k \times c$. That would assume a perfect lattice.
#     Instead, we sum the specific lattice parameters of all layers below:
#     $$ z_k = \sum_{i=0}^{k} c_i $$
#     *   If there is a strain gradient, $c_i$ changes, and $z_k$ captures the exact physical position of that unit cell.
#
# 2.  **Phase ($\phi_k$):**
#     The phase of the X-ray scattered by layer $k$ depends on the total path difference ($Q \cdot z$):
#     $$ \phi_k = Q \cdot z_k \cdot \cos(\text{tilt}) $$
#     *   The $\cos(\text{tilt})$ term accounts for mosaicity (projection of Q).
#
# 3.  **Coherent Sum (Structure Factor $F$):**
#     We sum the complex amplitudes of all layers in one column:
#     $$ F_{\text{column}} = \sum_{k=0}^{N_z} \text{Mask}_k \cdot e^{i \phi_k} $$
#     *   This is **Constructive/Destructive Interference**.
#     *   If $c$ varies (gradient), the phases shift, and peaks broaden.
#     *   If $N$ varies (roughness), the "Laue condition" ($N \cdot Q \cdot c$) breaks down, damping oscillations.
#
# 4.  **Incoherent Sum (Total Intensity):**
#     We assume columns don't interfere with each other (lateral coherence length is small). We sum their intensities:
#     $$ I_{\text{total}} = \sum_{\text{columns}} |F_{\text{column}}|^2 $$
#
# ### Advantages Over Analytical Approach
#
# 1.  **Physical intuition**: Real unit cells in real space
# 2.  **Flexibility**: Easy to add composition gradients, defects, etc.
# 3.  **Generality**: Can extend to RSM (off-specular) with same framework
# 4.  **Validation**: Can compare with analytical Laue function for perfect crystal

# %% [markdown]
# ## Parameter Impact Visualization
#
# The following cells demonstrate how each physical parameter affects XRD patterns:
#
# 1. **Surface Roughness** - Thickness variation dampens Laue oscillations
# 2. **Lattice Gradient** - Strain relaxation causes peak broadening and asymmetry
# 3. **Mosaicity** - Crystallite tilt spreads peak symmetrically
# 4. **Spatial Variation** - Lateral lattice parameter variation
#
# Each plot compares low/medium/high values against experimental data (ttw_EM007).

# %%
# ========== Setup: Prepare Experimental Data for Comparison ==========
from ttw_models import find_peak

# Use EM007 (BSO film) as reference
exp_data_viz = ttw_EM007
wavelength_viz = exp_data_viz.wavelength

# Find BSO peak position and intensity
peak_search_range = (42.0, 45.0)
peak_pos_BSO, peak_int_BSO = find_peak(exp_data_viz, peak_search_range)
print(f"EM007 BSO Peak: {peak_pos_BSO:.3f}° with intensity {peak_int_BSO:.0f}")

# Calculate lattice parameter from peak position
theta_rad = np.radians(peak_pos_BSO / 2)
d_spacing = wavelength_viz / (2 * np.sin(theta_rad))
c_BSO_exp = d_spacing * 2  # Assuming 002 reflection
print(f"Experimental c-parameter: {c_BSO_exp:.4f} Å")

# Extract and normalize experimental data
x_exp = exp_data_viz.ttw_df[0]['Angle'].values
y_exp = exp_data_viz.ttw_df[0]['Intensity'].values
y_exp_norm = y_exp / peak_int_BSO  # Normalize to peak = 1

# Plot range (focus on BSO peak)
plot_range = (41.5, 45.5)
mask_exp = (x_exp >= plot_range[0]) & (x_exp <= plot_range[1])

# Simulation parameters (reasonable defaults)
thickness_base = 20.0  # nm
nx_viz, ny_viz = 6, 6  # Grid size (balance speed vs quality)
nz_viz = int((thickness_base * 10) / c_BSO_exp)

# Instrumental parameters (typical values)
attenuation_viz = 20000  # nm
instrumental_viz = 0.05  # deg

print(f"\nSimulation grid: {nx_viz}x{ny_viz} columns, ~{nz_viz} layers")
print(f"Ready for parameter variation studies...")
# Out:
# EM007 BSO Peak: 43.910° with intensity 30246
# Experimental c-parameter: 4.1206 Å
#
# Simulation grid: 6x6 columns, ~48 layers
# Ready for parameter variation studies...

# %% [markdown]
# ### 1. Surface Roughness Impact
#
# Surface roughness causes thickness variation across the film. Different crystallites have different numbers of unit cells (N), causing Laue oscillations to go out of phase and dampen.

# %%
# ========== Impact of Surface Roughness ==========
import time

# Test three levels: Low, Medium, High
roughness_levels = [
    {'value': 0.1, 'color': 'blue', 'linestyle': '-'},
    {'value': 1, 'color': 'orange', 'linestyle': '--'},
    {'value': 3.0, 'color': 'red', 'linestyle': '-.'}
]

print("Simulating Surface Roughness Effects...")
start_time = time.time()
roughness_results = []

for level in roughness_levels:
    t0 = time.time()
    roughness_nm = level['value']
    roughness_layers = (roughness_nm * 10) / c_BSO_exp
    label = f'Roughness {roughness_nm:.1f} nm'
    
    # Create crystal system with ONLY roughness variation (all other parameters perfect)
    lat_arr, h_map, t_arr = create_crystal_system(
        nx_viz, ny_viz, nz_viz,
        lattice_perfect=c_BSO_exp,
        lattice_gradient=[c_BSO_exp, c_BSO_exp],  # No gradient
        mode='perfect',  # Use perfect mode with only roughness
        roughness_layers=roughness_layers,
        mosaicity_fwhm=0.0,  # No mosaicity
        spatial_var_percent=0.0  # No spatial variation
    )
    
    # Calculate XRD
    tt, intensity = calculate_xrd_vectorized(
        lat_arr, h_map, t_arr,
        two_theta_range=plot_range,
        wavelength=wavelength_viz,
        attenuation_length_nm=attenuation_viz,
        instrumental_broadening=instrumental_viz,
        n_points=2000,
        normalize=True
    )
    
    roughness_results.append({
        'name': label,
        'color': level['color'],
        'linestyle': level['linestyle'],
        'two_theta': tt,
        'intensity': intensity
    })
    
    print(f"  {label}: {time.time()-t0:.1f}s")

print(f"Total time: {time.time()-start_time:.1f}s\n")

# Plot
fig, ax = plt.subplots(figsize=(12, 7))

# Experimental data
ax.plot(x_exp[mask_exp], y_exp_norm[mask_exp], 'k-', 
        label='Experiment (EM007)', linewidth=2.5, alpha=0.6)

# Simulations
for res in roughness_results:
    ax.plot(res['two_theta'], res['intensity'], 
            color=res['color'], linestyle=res['linestyle'],
            label=res['name'], linewidth=2, alpha=0.8)

ax.set_xlabel(r'$2\theta$ (degrees)', fontsize=12)
ax.set_ylabel('Normalized Intensity', fontsize=12)
ax.set_title('Impact of Surface Roughness on XRD Pattern', fontsize=14, fontweight='bold')
ax.legend(fontsize=10)
ax.set_yscale('log')
ax.set_ylim(1e-4, 2)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("Key Observation: Higher roughness → More damped Laue oscillations")
print("Physical Reason: Thickness variation creates phase mismatch between crystallites")
# Out:
# Simulating Surface Roughness Effects...
#   Roughness 0.1 nm: 0.1s
#   Roughness 1.0 nm: 0.1s
#   Roughness 3.0 nm: 0.1s
# Total time: 0.2s
# Key Observation: Higher roughness → More damped Laue oscillations
# Physical Reason: Thickness variation creates phase mismatch between crystallites

# %% [markdown]
# ### 2. Lattice Gradient Impact (Strain Relaxation)
#
# Lattice parameter gradient from interface to surface. Causes peak broadening and shifts Laue oscillation phases. Typical in strained epitaxial films.

# %%
# ========== Impact of Lattice Gradient (Strain Relaxation) ==========

# Test three levels: Small, Medium, Large gradient
# Gradient is defined as [c_interface, c_surface]
gradient_levels = [
    {'gradient': [c_BSO_exp, c_BSO_exp + 0.005], 'relax_len': 20, 'color': 'blue', 'linestyle': '-'},
    {'gradient': [c_BSO_exp, c_BSO_exp + 0.03], 'relax_len': 15, 'color': 'orange', 'linestyle': '--'},
    {'gradient': [c_BSO_exp, c_BSO_exp + 0.1], 'relax_len': 10, 'color': 'red', 'linestyle': '-.'}
]

print("Simulating Lattice Gradient Effects...")
start_time = time.time()
gradient_results = []

for level in gradient_levels:
    t0 = time.time()
    gradient_range = level['gradient'][1] - level['gradient'][0]
    label = f'Gradient {gradient_range:.3f} Å'
    
    # Create crystal system with ONLY lattice gradient (exponential relaxation)
    lat_arr, h_map, t_arr = create_crystal_system(
        nx_viz, ny_viz, nz_viz,
        lattice_perfect=level['gradient'][1],  # Surface value
        lattice_gradient=level['gradient'],
        mode='gradient',  # Use gradient mode
        gradient_type='exponential',
        relaxation_length=level['relax_len'],
        roughness_layers=0.0,  # No roughness
        mosaicity_fwhm=0.0,  # No mosaicity
        spatial_var_percent=0.0  # No spatial variation
    )
    
    # Calculate XRD
    tt, intensity = calculate_xrd_vectorized(
        lat_arr, h_map, t_arr,
        two_theta_range=plot_range,
        wavelength=wavelength_viz,
        attenuation_length_nm=attenuation_viz,
        instrumental_broadening=instrumental_viz,
        n_points=2000,
        normalize=True
    )
    
    gradient_results.append({
        'name': label,
        'color': level['color'],
        'linestyle': level['linestyle'],
        'two_theta': tt,
        'intensity': intensity
    })
    
    print(f"  {label}: {time.time()-t0:.1f}s")

print(f"Total time: {time.time()-start_time:.1f}s\n")

# Plot
fig, ax = plt.subplots(figsize=(12, 7))

# Experimental data
ax.plot(x_exp[mask_exp], y_exp_norm[mask_exp], 'k-', 
        label='Experiment (EM007)', linewidth=2.5, alpha=0.6)

# Simulations
for res in gradient_results:
    ax.plot(res['two_theta'], res['intensity'], 
            color=res['color'], linestyle=res['linestyle'],
            label=res['name'], linewidth=2, alpha=0.8)

ax.set_xlabel(r'$2\theta$ (degrees)', fontsize=12)
ax.set_ylabel('Normalized Intensity', fontsize=12)
ax.set_title('Impact of Lattice Parameter Gradient on XRD Pattern', fontsize=14, fontweight='bold')
ax.legend(fontsize=10)
ax.set_yscale('log')
ax.set_ylim(1e-4, 2)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("Key Observation: Larger gradient → Peak broadening + Laue damping + potential asymmetry")
print("Physical Reason: Different layers have different d-spacing → phase variation")
# Out:
# Simulating Lattice Gradient Effects...
#   Gradient 0.005 Å: 0.1s
#   Gradient 0.030 Å: 0.1s
#   Gradient 0.100 Å: 0.1s
# Total time: 0.2s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 76
#      74 ax.set_ylim(1e-4, 2)
#      75 ax.grid(True, alpha=0.3)
# ---> 76 plt.tight_layout()
#      77 plt.show()
#      79 print("Key Observation: Larger gradient → Peak broadening + Laue damping + potential asymmetry")
#
# File ~/Desktop/Thin_Film_Analysis/TFAvenv/lib/python3.12/site-packages/matplotlib/pyplot.py:2835, in tight_layout(pad, h_pad, w_pad, rect)
#    2827 @_copy_docstring_and_deprecators(Figure.tight_layout)
#    2828 def tight_layout(
#    2829     *,
#    (...)
#    2833     rect: tuple[float, float, float, float] | None = None,
#    2834 ) -> None:
# -> 2835     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#
# File ~/Desktop/Thin_Film_Analysis/TFAvenv/lib/python3.12/site-packages/matplotlib/figure.py:3640, in Figure.tight_layout(self, pad, h_pad, w_pad, rect)
#    3638 previous_engine = self.get_layout_engine()
#    3639 self.set_layout_engine(engine)
# -> 3640 engine.execute(self)
#    3641 if previous_engine is not None and not isinstance(
#    3642     previous_engine, (TightLayoutEngine, PlaceHolderLayoutEngine)
#    3643 ):
#    3644     _api.warn_external('The figure layout has changed to tight')
#
# File ~/Desktop/Thin_Film_Analysis/TFAvenv/lib/python3.12/site-packages/matplotlib/layout_engine.py:183, in TightLayoutEngine.execute(self, fig)
#     181 renderer = fig._get_renderer()
#     182 with getattr(renderer, "_draw_disabled", nullcontext)():
# --> 183     kwargs = get_tight_layout_figure(
#     184         fig, fig.axes, get_subplotspec_list(fig.axes), renderer,
#     185         pad=info['pad'], h_pad=info['h_pad'], w_pad=info['w_pad'],
#     186         rect=info['rect'])
#     187 if kwargs:
#     188     fig.subplots_adjust(**kwargs)
#
# File ~/Desktop/Thin_Film_Analysis/TFAvenv/lib/python3.12/site-packages/matplotlib/_tight_layout.py:266, in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     261         return {}
#     262     span_pairs.append((
#     263         slice(ss.rowspan.start * div_row, ss.rowspan.stop * div_row),
#     264         slice(ss.colspan.start * div_col, ss.colspan.stop * div_col)))
# --> 266 kwargs = _auto_adjust_subplotpars(fig, renderer,
#     267                                   shape=(max_nrows, max_ncols),
#     268                                   span_pairs=span_pairs,
#     269                                   subplot_list=subplot_list,
#     270                                   ax_bbox_list=ax_bbox_list,
#     271                                   pad=pad, h_pad=h_pad, w_pad=w_pad)
#     273 # kwargs can be none if tight_layout fails...
#     274 if rect is not None and kwargs is not None:
#     275     # if rect is given, the whole subplots area (including
#     276     # labels) will fit into the rect instead of the
#    (...)
#     280     # auto_adjust_subplotpars twice, where the second run
#     281     # with adjusted rect parameters.
#
# File ~/Desktop/Thin_Film_Analysis/TFAvenv/lib/python3.12/site-packages/matplotlib/_tight_layout.py:82, in _auto_adjust_subplotpars(fig, renderer, shape, span_pairs, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      80 for ax in subplots:
#      81     if ax.get_visible():
# ---> 82         bb += [martist._get_tightbbox_for_layout_only(ax, renderer)]
#      84 tight_bbox_raw = Bbox.union(bb)
#      85 tight_bbox = fig.transFigure.inverted().transform_bbox(tight_bbox_raw)
#
# File ~/Desktop/Thin_Film_Analysis/TFAvenv/lib/python3.12/site-packages/matplotlib/artist.py:1402, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1396 """
#    1397 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1398 *for_layout_only* kwarg; this helper tries to use the kwarg but skips it
#    1399 when encountering third-party subclasses that do not support it.
#    1400 """
#    1401 try:
# -> 1402     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1403 except TypeError:
#    1404     return obj.get_tightbbox(*args, **kwargs)
#
# File ~/Desktop/Thin_Film_Analysis/TFAvenv/lib/python3.12/site-packages/matplotlib/axes/_base.py:4519, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4517 for axis in self._axis_map.values():
#    4518     if self.axison and axis.get_visible():
# -> 4519         ba = martist._get_tightbbox_for_layout_only(axis, renderer)
#    4520         if ba:
#    4521             bb.append(ba)
#
# File ~/Desktop/Thin_Film_Analysis/TFAvenv/lib/python3.12/site-packages/matplotlib/artist.py:1402, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1396 """
#    1397 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1398 *for_layout_only* kwarg; this helper tries to use the kwarg but skips it
#    1399 when encountering third-party subclasses that do not support it.
#    1400 """
#    1401 try:
# -> 1402     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1403 except TypeError:
#    1404     return obj.get_tightbbox(*args, **kwargs)
#
# File ~/Desktop/Thin_Film_Analysis/TFAvenv/lib/python3.12/site-packages/matplotlib/axis.py:1362, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1360 if renderer is None:
#    1361     renderer = self.get_figure(root=True)._get_renderer()
# -> 1362 ticks_to_draw = self._update_ticks()
#    1364 self._update_label_position(renderer)
#    1366 # go back to just this axis's tick labels
#
# File ~/Desktop/Thin_Film_Analysis/TFAvenv/lib/python3.12/site-packages/matplotlib/axis.py:1301, in Axis._update_ticks(self)
#    1299 minor_locs = self.get_minorticklocs()
#    1300 minor_labels = self.minor.formatter.format_ticks(minor_locs)
# -> 1301 minor_ticks = self.get_minor_ticks(len(minor_locs))
#    1302 for tick, loc, label in zip(minor_ticks, minor_locs, minor_labels):
#    1303     tick.update_position(loc)
#
# File ~/Desktop/Thin_Film_Analysis/TFAvenv/lib/python3.12/site-packages/matplotlib/axis.py:1701, in Axis.get_minor_ticks(self, numticks)
#    1697     numticks = len(self.get_minorticklocs())
#    1699 while len(self.minorTicks) < numticks:
#    1700     # Update the new tick label properties from the old.
# -> 1701     tick = self._get_tick(major=False)
#    1702     self.minorTicks.append(tick)
#    1703     self._copy_tick_props(self.minorTicks[0], tick)
#
# File ~/Desktop/Thin_Film_Analysis/TFAvenv/lib/python3.12/site-packages/matplotlib/axis.py:1603, in Axis._get_tick(self, major)
#    1599     raise NotImplementedError(
#    1600         f"The Axis subclass {self.__class__.__name__} must define "
#    1601         "_tick_class or reimplement _get_tick()")
#    1602 tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1603 return self._tick_class(self.axes, 0, major=major, **tick_kw)
#
# File ~/Desktop/Thin_Film_Analysis/TFAvenv/lib/python3.12/site-packages/matplotlib/axis.py:371, in XTick.__init__(self, *args, **kwargs)
#     369 # x in data coords, y in axes coords
#     370 ax = self.axes
# --> 371 self.tick1line.set(
#     372     data=([0], [0]), transform=ax.get_xaxis_transform("tick1"))
#     373 self.tick2line.set(
#     374     data=([0], [1]), transform=ax.get_xaxis_transform("tick2"))
#     375 self.gridline.set(
#     376     data=([0, 0], [0, 1]), transform=ax.get_xaxis_transform("grid"))
#
# File ~/Desktop/Thin_Film_Analysis/TFAvenv/lib/python3.12/site-packages/matplotlib/artist.py:146, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     138 if not hasattr(cls.set, '_autogenerated_signature'):
#     139     # Don't overwrite cls.set if the subclass or one of its parents
#     140     # has defined a set method set itself.
#     141     # If there was no explicit definition, cls.set is inherited from
#     142     # the hierarchy of auto-generated set methods, which hold the
#     143     # flag _autogenerated_signature.
#     144     return
# --> 146 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     147 cls.set.__name__ = "set"
#     148 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File ~/Desktop/Thin_Film_Analysis/TFAvenv/lib/python3.12/site-packages/matplotlib/artist.py:1241, in Artist.set(self, **kwargs)
#    1237 def set(self, **kwargs):
#    1238     # docstring and signature are auto-generated via
#    1239     # Artist._update_set_signature_and_docstring() at the end of the
#    1240     # module.
# -> 1241     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File ~/Desktop/Thin_Film_Analysis/TFAvenv/lib/python3.12/site-packages/matplotlib/artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File ~/Desktop/Thin_Film_Analysis/TFAvenv/lib/python3.12/site-packages/matplotlib/artist.py:1209, in Artist._update_props(self, props, errfmt)
#    1205             if not callable(func):
#    1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
# -> 1209             ret.append(func(v))
#    1210 if ret:
#    1211     self.pchanged()
#
# File ~/Desktop/Thin_Film_Analysis/TFAvenv/lib/python3.12/site-packages/matplotlib/lines.py:667, in Line2D.set_data(self, *args)
#     664     x, y = args
#     666 self.set_xdata(x)
# --> 667 self.set_ydata(y)
#
# File ~/Desktop/Thin_Film_Analysis/TFAvenv/lib/python3.12/site-packages/matplotlib/lines.py:1308, in Line2D.set_ydata(self, y)
#    1295 def set_ydata(self, y):
#    1296     """
#    1297     Set the data array for y.
#    1298
#    (...)
#    1306     set_xdata
#    1307     """
# -> 1308     if not np.iterable(y):
#    1309         raise RuntimeError('y must be a sequence')
#    1310     self._yorig = copy.copy(y)
#
# File ~/Desktop/Thin_Film_Analysis/TFAvenv/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:379, in iterable(y)
#     341 """
#     342 Check whether or not an object can be iterated over.
#     343
#    (...)
#     376
#     377 """
#     378 try:
# --> 379     iter(y)
#     380 except TypeError:
#     381     return False
#
# KeyboardInterrupt:

# %% [markdown]
# ### 3. Mosaicity Impact (Crystallite Tilt)
#
# Mosaicity represents the distribution of crystallite orientations (tilt angles). It broadens peaks symmetrically but does NOT directly affect Laue oscillations (since N and c remain constant per crystallite).

# %%
# ========== Impact of Mosaicity (Crystallite Tilt) ==========

# Test three levels: Low, Medium, High mosaicity
mosaicity_levels = [
    {'value': 0.1, 'color': 'blue', 'linestyle': '-'},
    {'value': 3, 'color': 'orange', 'linestyle': '--'},
    {'value': 8, 'color': 'red', 'linestyle': '-.'}
]

print("Simulating Mosaicity Effects...")
start_time = time.time()
mosaicity_results = []

for level in mosaicity_levels:
    t0 = time.time()
    label = f'Mosaicity {level["value"]:.1f}°'
    
    # Create crystal system with ONLY mosaicity variation
    lat_arr, h_map, t_arr = create_crystal_system(
        nx_viz, ny_viz, nz_viz,
        lattice_perfect=c_BSO_exp,
        lattice_gradient=[c_BSO_exp, c_BSO_exp],  # No gradient
        mode='perfect',  # Use perfect mode with only mosaicity
        roughness_layers=0.0,  # No roughness
        mosaicity_fwhm=level['value'],  # Variable mosaicity
        spatial_var_percent=0.0  # No spatial variation
    )
    
    # Calculate XRD
    tt, intensity = calculate_xrd_vectorized(
        lat_arr, h_map, t_arr,
        two_theta_range=plot_range,
        wavelength=wavelength_viz,
        attenuation_length_nm=attenuation_viz,
        instrumental_broadening=instrumental_viz,
        n_points=2000,
        normalize=True
    )
    
    mosaicity_results.append({
        'name': label,
        'color': level['color'],
        'linestyle': level['linestyle'],
        'two_theta': tt,
        'intensity': intensity
    })
    
    print(f"  {label}: {time.time()-t0:.1f}s")

print(f"Total time: {time.time()-start_time:.1f}s\n")

# Plot
fig, ax = plt.subplots(figsize=(12, 7))

# Experimental data
ax.plot(x_exp[mask_exp], y_exp_norm[mask_exp], 'k-', 
        label='Experiment (EM007)', linewidth=2.5, alpha=0.6)

# Simulations
for res in mosaicity_results:
    ax.plot(res['two_theta'], res['intensity'], 
            color=res['color'], linestyle=res['linestyle'],
            label=res['name'], linewidth=2, alpha=0.8)

ax.set_xlabel(r'$2\theta$ (degrees)', fontsize=12)
ax.set_ylabel('Normalized Intensity', fontsize=12)
ax.set_title('Impact of Mosaicity (Crystallite Tilt) on XRD Pattern', fontsize=14, fontweight='bold')
ax.legend(fontsize=10)
ax.set_yscale('log')
ax.set_ylim(1e-4, 2)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("Key Observation: Higher mosaicity → Broader peak, but Laue oscillations remain")
print("Physical Reason: Tilted crystallites scatter at different 2θ, but N×Q×c stays coherent")
# Out:
# Simulating Mosaicity Effects...
#   Mosaicity 0.1°: 0.1s
#   Mosaicity 3.0°: 0.1s
#   Mosaicity 8.0°: 0.1s
# Total time: 0.2s
# Key Observation: Higher mosaicity → Broader peak, but Laue oscillations remain
# Physical Reason: Tilted crystallites scatter at different 2θ, but N×Q×c stays coherent

# %% [markdown]
# ### 4. Spatial Variation Impact (Lateral Inhomogeneity)
#
# Spatial variation represents lateral (x-y) fluctuations in lattice parameter across the film surface. Creates a distribution of slightly different lattice constants.

# %%
# ========== Impact of Spatial Variation (Lateral Inhomogeneity) ==========

# Spatial Variation Physical Meaning:
# Each column (x,y position) starts with a SLIGHTLY DIFFERENT interface lattice parameter,
# then the SAME gradient profile is applied vertically through that column.
# 
# Example with gradient [4.10, 4.12] Å:
# - Column A: starts at 4.098 Å (interface) → relaxes to 4.118 Å (surface)
# - Column B: starts at 4.105 Å (interface) → relaxes to 4.125 Å (surface)  
# - Column C: starts at 4.102 Å (interface) → relaxes to 4.122 Å (surface)
# All columns have the SAME gradient shape, but shifted up/down.
# 
# This represents lateral composition/strain inhomogeneity across the film surface.
# 
# Implementation: A Gaussian random shift is applied to c_start for each column,
# then that shift is added to the entire vertical gradient profile (exponential/linear).
# The variation is specified as a PERCENTAGE of the base lattice parameter.
#
# NOT the same as:
# - Roughness (which varies thickness/z-height per column)
# - Mosaicity (which varies tilt angle per column)
# - Gradient (which varies c along z within each column - this is ADDED to gradient)

# Test three levels: Low, Medium, High spatial variation
spatial_levels = [
    {'value': 0.1, 'color': 'blue', 'linestyle': '-'},
    {'value': 0.25, 'color': 'orange', 'linestyle': '--'},
    {'value': 0.5, 'color': 'red', 'linestyle': '-.'}
]

print("Simulating Spatial Variation Effects...")
start_time = time.time()
spatial_results = []

for level in spatial_levels:
    t0 = time.time()
    label = f'Spatial Var {level["value"]:.2f}%'
    
    # Create crystal system with ONLY spatial variation
    lat_arr, h_map, t_arr = create_crystal_system(
        nx_viz, ny_viz, nz_viz,
        lattice_perfect=c_BSO_exp,
        lattice_gradient=[c_BSO_exp, c_BSO_exp],  # No gradient
        mode='full',  # Use full mode to enable spatial variation
        spatial_var_percent=level['value'],  # Variable spatial variation
        roughness_layers=0.0,  # No roughness
        mosaicity_fwhm=0.0  # No mosaicity
    )
    
    # Calculate XRD
    tt, intensity = calculate_xrd_vectorized(
        lat_arr, h_map, t_arr,
        two_theta_range=plot_range,
        wavelength=wavelength_viz,
        attenuation_length_nm=attenuation_viz,
        instrumental_broadening=instrumental_viz,
        n_points=2000,
        normalize=True
    )
    
    spatial_results.append({
        'name': label,
        'color': level['color'],
        'linestyle': level['linestyle'],
        'two_theta': tt,
        'intensity': intensity
    })
    
    print(f"  {label}: {time.time()-t0:.1f}s")

print(f"Total time: {time.time()-start_time:.1f}s\n")

# Plot
fig, ax = plt.subplots(figsize=(12, 7))

# Experimental data
ax.plot(x_exp[mask_exp], y_exp_norm[mask_exp], 'k-', 
        label='Experiment (EM007)', linewidth=2.5, alpha=0.6)

# Simulations
for res in spatial_results:
    ax.plot(res['two_theta'], res['intensity'], 
            color=res['color'], linestyle=res['linestyle'],
            label=res['name'], linewidth=2, alpha=0.8)

ax.set_xlabel(r'$2\theta$ (degrees)', fontsize=12)
ax.set_ylabel('Normalized Intensity', fontsize=12)
ax.set_title('Impact of Spatial Variation on XRD Pattern', fontsize=14, fontweight='bold')
ax.legend(fontsize=10)
ax.set_yscale('log')
ax.set_ylim(1e-4, 2)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("Key Observation: Higher spatial variation → Peak broadening + Laue damping")
print("Physical Reason: Different columns have different c-parameters → incoherent sum")
# Out:
# Simulating Spatial Variation Effects...
#   Spatial Var 0.10%: 0.1s
#   Spatial Var 0.25%: 0.1s
#   Spatial Var 0.50%: 0.1s
# Total time: 0.2s
# Key Observation: Higher spatial variation → Peak broadening + Laue damping
# Physical Reason: Different columns have different c-parameters → incoherent sum

# %% [markdown]
# ### 5. Combined Effects Comparison
#
# Shows all four parameter effects on a single plot for direct comparison of their relative impacts.

# %%
# ========== Combined Comparison: All Parameters (Medium Level) ==========

# Define one "medium" case for each parameter
comparison_cases = [
    {'name': 'Perfect Crystal', 'color': 'green', 'linestyle': '-', 'linewidth': 2.5,
     'params': {'mode': 'perfect', 'lattice_gradient': [c_BSO_exp, c_BSO_exp],
                'roughness_layers': 0.0, 'mosaicity_fwhm': 0.0, 'spatial_var_percent': 0.0}},
    
    {'name': 'Roughness (0.8 nm)', 'color': 'blue', 'linestyle': '--', 'linewidth': 2,
     'params': {'mode': 'perfect', 'lattice_gradient': [c_BSO_exp, c_BSO_exp],
                'roughness_layers': (0.8*10)/c_BSO_exp, 'mosaicity_fwhm': 0.0, 'spatial_var_percent': 0.0}},
    
    {'name': 'Gradient (0.015 Å)', 'color': 'orange', 'linestyle': '-.', 'linewidth': 2,
     'params': {'mode': 'gradient', 'gradient_type': 'exponential', 'relaxation_length': 15,
                'lattice_gradient': [c_BSO_exp, c_BSO_exp + 0.015],
                'roughness_layers': 0.0, 'mosaicity_fwhm': 0.0, 'spatial_var_percent': 0.0}},
    
    {'name': 'Mosaicity (0.4°)', 'color': 'purple', 'linestyle': ':', 'linewidth': 2,
     'params': {'mode': 'perfect', 'lattice_gradient': [c_BSO_exp, c_BSO_exp],
                'roughness_layers': 0.0, 'mosaicity_fwhm': 0.4, 'spatial_var_percent': 0.0}},
    
    {'name': 'Spatial Var (0.5%)', 'color': 'red', 'linestyle': (0, (3, 1, 1, 1)), 'linewidth': 2,
     'params': {'mode': 'full', 'lattice_gradient': [c_BSO_exp, c_BSO_exp],
                'roughness_layers': 0.0, 'mosaicity_fwhm': 0.0, 'spatial_var_percent': 0.5}}
]

print("Generating Combined Comparison Plot...")
start_time = time.time()
comparison_results = []

for case in comparison_cases:
    t0 = time.time()
    
    # Create crystal system
    lat_arr, h_map, t_arr = create_crystal_system(
        nx_viz, ny_viz, nz_viz,
        lattice_perfect=c_BSO_exp,
        **case['params']
    )
    
    # Calculate XRD
    tt, intensity = calculate_xrd_vectorized(
        lat_arr, h_map, t_arr,
        two_theta_range=plot_range,
        wavelength=wavelength_viz,
        attenuation_length_nm=attenuation_viz,
        instrumental_broadening=instrumental_viz,
        n_points=2000,
        normalize=True
    )
    
    comparison_results.append({
        'name': case['name'],
        'color': case['color'],
        'linestyle': case['linestyle'],
        'linewidth': case['linewidth'],
        'two_theta': tt,
        'intensity': intensity
    })
    
    print(f"  {case['name']}: {time.time()-t0:.1f}s")

print(f"Total time: {time.time()-start_time:.1f}s\n")

# Plot
fig, ax = plt.subplots(figsize=(14, 8))

# Experimental data (prominent)
ax.plot(x_exp[mask_exp], y_exp_norm[mask_exp], 'k-', 
        label='Experiment (EM007)', linewidth=3, alpha=0.7, zorder=10)

# Simulations
for res in comparison_results:
    ax.plot(res['two_theta'], res['intensity'], 
            color=res['color'], linestyle=res['linestyle'],
            linewidth=res['linewidth'], label=res['name'], alpha=0.85)

ax.set_xlabel(r'$2\theta$ (degrees)', fontsize=13)
ax.set_ylabel('Normalized Intensity', fontsize=13)
ax.set_title('Comparison of Individual Parameter Effects on XRD Pattern', 
             fontsize=15, fontweight='bold')
ax.legend(fontsize=11, loc='best')
ax.set_yscale('log')
ax.set_ylim(1e-4, 2)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

print("\n" + "="*70)
print("Summary of Parameter Effects:")
print("="*70)
print("  • Roughness:      Dampens Laue oscillations (thickness variation)")
print("  • Lattice Gradient: Peak broadening + asymmetry (d-spacing variation)")
print("  • Mosaicity:      Peak broadening only (angular spread)")
print("  • Spatial Var:    Peak broadening + Laue damping (lateral c variation)")
print("="*70)
# Out:
# Generating Combined Comparison Plot...
#   Perfect Crystal: 0.1s
#   Roughness (0.8 nm): 0.1s
#   Gradient (0.015 Å): 0.1s
#   Mosaicity (0.4°): 0.1s
#   Spatial Var (0.5%): 0.1s
# Total time: 0.3s
# ======================================================================
# Summary of Parameter Effects:
# ======================================================================
#   • Roughness:      Dampens Laue oscillations (thickness variation)
#   • Lattice Gradient: Peak broadening + asymmetry (d-spacing variation)
#   • Mosaicity:      Peak broadening only (angular spread)
#   • Spatial Var:    Peak broadening + Laue damping (lateral c variation)
# ======================================================================

# %% [markdown]
# ## XRD Fitting: To Do List
# - Use STO roughness parameter to add a roughness to the z=0 layer so that you have a small offset in the z starting position from zero (this will then add to the top surface roughness which we separately fit)
# - Change to work with Q.r
#     - each lattice point should have x,y,z coordinates
#     - instead we initialise our crystal by slightly displacing these with tilt, roughness etc
#     - now including correlation (e.g. tilt will be for a certain grain x,y size and through z)
#     - then we calculate Q.r for these r positions
#     - done for array of Q to give Qx, Qz - RSM
#     - Can fit moscaicity from w rocking in RSM preferentially
#     - Get improved fit parameters by iterating through

# %%
single_dat[0].wavelength
# Out:
# 1.540598

# %%
# ========== 5a. Step 1: Fit Substrate (STO) Peak ==========
# Purpose: Determine instrumental broadening and attenuation length accurately
# Range: 46.0 - 48.0 degrees (STO 002 peak)

from ttw_models import run_xrd_fitting, find_peak

print('experimental_data=',single_dat) # chosen experimental data for fitting
exp_data = single_dat[0]
wavelength = exp_data.wavelength


# --- 1. STO Fitting Configuration ---
fit_range_STO = (46.0, 47.5)
# OPTIMIZATION: Reduced grid size for Substrate. 
# STO is uniform, so we don't need many columns to average out spatial variation.
nx_fit_STO, ny_fit_STO = 1, 1 
peak_search_range_STO = (46.0, 48.0)

# Find STO peak
peak_pos_STO, peak_int_STO = find_peak(exp_data, peak_search_range_STO)
print(f"Found STO peak at {peak_pos_STO:.3f}° with intensity {peak_int_STO:.0f}")

# Known STO Parameters
c_STO_lit = 3.905 # Å (Literature value for SrTiO3)

# --- 2. Bounds for STO (Substrate) ---
# Note on Thickness: We use 1500 nm. 
# Real thickness is 500,000 nm, but simulating >1 million layers causes memory crashes.
# 1500 nm is sufficient to approximate a "thick" crystal (Laue fringes merge).

bounds_STO = [
    (c_STO_lit * 0.998, c_STO_lit * 1.002), # 1. c_start: Fixed to 3.905 Å (Interface)
    (c_STO_lit * 0.998, c_STO_lit * 1.002), # 2. c_end: Fixed to 3.905 Å (Surface)
    (6000.0, 6000.0), # 3. Thickness: Fixed to 1500 nm (Computational Limit)
    (0.0, 0.05),     # 4. Spatial Var: Lattice variation (%) - Low for single crystal
    (0.0, 0.6),     # 5. Roughness: Surface roughness (nm)
    (0.0, 0.5),     # 6. Mosaicity: Crystallite tilt (deg)
    (1.0, 10.0),    # 7. Relaxation: Strain relaxation length (layers) - Irrelevant for constant c
    (10000, 50000),  # 8. Attenuation: X-ray penetration depth (nm) - FITTING TARGET
    (0.01, 0.1)     # 9. Instrumental: Machine broadening (deg) - FITTING TARGET
]

p0_STO = np.mean(bounds_STO, axis=1)

# --- 3. Optimization Settings ---
# For STO: Can use faster local-only search since it's a simple peak
use_global_STO = False  # Set True for global search (slower, more robust)
de_maxiter_STO = 30     # DE iterations (if use_global_STO=True)
de_popsize_STO = 10     # DE population multiplier (if use_global_STO=True)
powell_tol_STO = 0.01   # Powell tolerance (lower = more precise)
powell_maxiter_STO = 100  # Powell max iterations

# --- 4. Run STO Optimization ---
print("\n--- Fitting STO Substrate ---")
res_STO = run_xrd_fitting(exp_data, peak_int_STO, wavelength,
                          fit_range=fit_range_STO,
                          nx_fit=nx_fit_STO, ny_fit=ny_fit_STO,
                          use_log_residual=True,
                          p0=p0_STO, bounds=bounds_STO,
                          use_global_search=use_global_STO,
                          de_maxiter=de_maxiter_STO,
                          de_popsize=de_popsize_STO,
                          tol=powell_tol_STO, 
                          maxiter=powell_maxiter_STO)

p_STO = res_STO.x
print("\n" + "="*70)
print("STO Best Fit Parameters:")
print("="*70)
print(f"  c_start:       {p_STO[0]:.4f} Å (bounds: [{bounds_STO[0][0]:.4f}, {bounds_STO[0][1]:.4f}])")
print(f"  c_end:         {p_STO[1]:.4f} Å (bounds: [{bounds_STO[1][0]:.4f}, {bounds_STO[1][1]:.4f}])")
print(f"  Thickness:     {p_STO[2]:.2f} nm (bounds: [{bounds_STO[2][0]:.2f}, {bounds_STO[2][1]:.2f}])")
print(f"  Spatial Var:   {p_STO[3]:.4f} % (bounds: [{bounds_STO[3][0]:.4f}, {bounds_STO[3][1]:.4f}])")
print(f"  Roughness:     {p_STO[4]:.4f} nm (bounds: [{bounds_STO[4][0]:.4f}, {bounds_STO[4][1]:.4f}])")
print(f"  Mosaicity:     {p_STO[5]:.4f} deg (bounds: [{bounds_STO[5][0]:.4f}, {bounds_STO[5][1]:.4f}])")
print(f"  Relax Length:  {p_STO[6]:.2f} layers (bounds: [{bounds_STO[6][0]:.2f}, {bounds_STO[6][1]:.2f}])")
print(f"  Attenuation:   {p_STO[7]:.0f} nm (bounds: [{bounds_STO[7][0]:.0f}, {bounds_STO[7][1]:.0f}])")
print(f"  Instrumental:  {p_STO[8]:.4f} deg (bounds: [{bounds_STO[8][0]:.4f}, {bounds_STO[8][1]:.4f}])")
print("="*70)
# Out:
# experimental_data= [<ttw.ttw object at 0x1178a8530>]
# Found STO peak at 46.590° with intensity 7825938
#
# --- Fitting STO Substrate ---
# Setting up optimization in range (46.0, 47.5) with grid 1x1...
# Optimization mode: Local (Powell only)
#   Settings: film_scale=1.0000, background=None
#   Powell params: tol=0.01, maxiter=100
#
# === Local Optimization (Powell only) ===
# Eval 1: Residual = 75.610180
# Eval 2: Residual = 77.213662
# Eval 3: Residual = 74.104501
# Eval 4: Residual = 82.536389
# Eval 5: Residual = 91.603700
# Eval 6: Residual = 58.710069
# Eval 7: Residual = 75.719442
# Eval 8: Residual = 75.268824
# Eval 9: Residual = 71.034873
# Eval 10: Residual = 64.683762
# Eval 11: Residual = 102.037750
# Eval 12: Residual = 99.026071
# Eval 13: Residual = 84.853428
# Eval 14: Residual = 77.036752
# Eval 15: Residual = 72.661651
# Eval 16: Residual = 45.035059
# Eval 17: Residual = 61.334935
# Eval 18: Residual = 54.940766
# Eval 19: Residual = 103.874643
# Eval 20: Residual = 102.941852
# Eval 21: Residual = 57.279269
# Eval 22: Residual = 65.631560
# Eval 23: Residual = 69.838901
# Eval 24: Residual = 58.995769
# Eval 25: Residual = 71.073539
# Eval 26: Residual = 105.412046
# Eval 27: Residual = 70.086916
# Eval 28: Residual = 93.200955
# Eval 29: Residual = 101.007394
# Eval 30: Residual = 107.144097
# Eval 31: Residual = 87.867714
# Eval 32: Residual = 78.097360
# Eval 33: Residual = 81.776629
# Eval 34: Residual = 82.283640
# Eval 35: Residual = 73.901842
# Eval 36: Residual = 60.985885
# Eval 37: Residual = 78.609451
# Eval 38: Residual = 98.156680
# Eval 39: Residual = 93.023627
# Eval 40: Residual = 83.575254
# Eval 41: Residual = 63.141217
# Eval 42: Residual = 76.920464
# Eval 43: Residual = 46.335541
# Eval 44: Residual = 75.085989
# Eval 45: Residual = 83.993644
# Eval 46: Residual = 86.207302
# Eval 47: Residual = 86.047932
# Eval 48: Residual = 69.844073
# Eval 49: Residual = 62.664044
# Eval 50: Residual = 47.873860
# Eval 51: Residual = 97.142726
# Eval 52: Residual = 76.937158
# Eval 53: Residual = 64.048469
# Eval 54: Residual = 94.107251
# Eval 55: Residual = 82.626232
# Eval 56: Residual = 41.981777
# Eval 57: Residual = 70.626226
# Eval 58: Residual = 81.466402
# Eval 59: Residual = 88.516155
# Eval 60: Residual = 81.126687
# Eval 61: Residual = 75.655728
# Eval 62: Residual = 70.067257
# Eval 63: Residual = 110.103882
# Eval 64: Residual = 47.785908
# Eval 65: Residual = 94.639774
# Eval 66: Residual = 47.326627
# Eval 67: Residual = 45.804425
# Eval 68: Residual = 78.788479
# Eval 69: Residual = 79.926886
# Eval 70: Residual = 78.981035
# Eval 71: Residual = 63.890725
# Eval 72: Residual = 38.880086
# Eval 73: Residual = 56.946483
# Eval 74: Residual = 66.139941
# Eval 75: Residual = 82.671952
# Eval 76: Residual = 68.195035
# Eval 77: Residual = 87.927328
# Eval 78: Residual = 74.653672
# Eval 79: Residual = 65.614762
# Eval 80: Residual = 97.382378
# Eval 81: Residual = 34.976407
# Eval 82: Residual = 57.496448
# Eval 83: Residual = 77.379200
# Eval 84: Residual = 86.547468
# Eval 85: Residual = 64.543184
# Eval 86: Residual = 45.363489
# Eval 87: Residual = 46.404311
# Eval 88: Residual = 85.316751
# Eval 89: Residual = 39.424268
# Eval 90: Residual = 75.317932
# Eval 91: Residual = 56.702328
# Eval 92: Residual = 78.922430
# Eval 93: Residual = 67.386323
# Eval 94: Residual = 78.396427
# Eval 95: Residual = 64.863588
# Eval 96: Residual = 69.472472
# Eval 97: Residual = 76.332794
# Eval 98: Residual = 70.034058
# Eval 99: Residual = 77.896761
# Eval 100: Residual = 97.649534
# Eval 101: Residual = 87.235616
# Eval 102: Residual = 82.462994
# Eval 103: Residual = 82.631842
# Eval 104: Residual = 111.177694
# Eval 105: Residual = 60.099003
# Eval 106: Residual = 78.570389
# Eval 107: Residual = 62.471864
# Eval 108: Residual = 79.722754
# Eval 109: Residual = 74.936753
# Eval 110: Residual = 86.801188
# Eval 111: Residual = 67.992750
# Eval 112: Residual = 76.563135
# Eval 113: Residual = 69.552224
# Eval 114: Residual = 82.630860
# Eval 115: Residual = 61.046314
# Eval 116: Residual = 85.437180
# Eval 117: Residual = 80.377575
# Eval 118: Residual = 55.050912
# Eval 119: Residual = 65.735120
# Eval 120: Residual = 63.429637
# Eval 121: Residual = 47.146984
# Eval 122: Residual = 63.454406
# Eval 123: Residual = 67.755368
# Eval 124: Residual = 45.798691
# Eval 125: Residual = 44.249672
# Eval 126: Residual = 65.525825
# Eval 127: Residual = 65.096256
# Eval 128: Residual = 61.261506
# Eval 129: Residual = 81.334618
# Eval 130: Residual = 68.423086
# Eval 131: Residual = 97.465357
# Eval 132: Residual = 64.262085
# Eval 133: Residual = 85.211240
# Eval 134: Residual = 86.031618
# Eval 135: Residual = 78.183812
# Eval 136: Residual = 74.443873
# Eval 137: Residual = 87.354231
# Eval 138: Residual = 61.669855
# Eval 139: Residual = 59.712527
# Eval 140: Residual = 65.254250
# Eval 141: Residual = 38.190503
# Eval 142: Residual = 82.317528
# Eval 143: Residual = 51.389392
# Eval 144: Residual = 83.023488
# Eval 145: Residual = 54.426749
# Eval 146: Residual = 57.623798
# Eval 147: Residual = 71.925235
# Eval 148: Residual = 60.079645
# Eval 149: Residual = 43.280549
# Eval 150: Residual = 69.191926
# Eval 151: Residual = 71.720627
# Eval 152: Residual = 46.639959
# Eval 153: Residual = 71.774692
# Eval 154: Residual = 56.846404
# Eval 155: Residual = 67.068643
#
# === Optimization Complete ===
# Success: True
# Message: Optimization terminated successfully.
# Final Residual: 46.639959
#
# ======================================================================
# STO Best Fit Parameters:
# ======================================================================
#   c_start:       3.9068 Å (bounds: [3.8972, 3.9128])
#   c_end:         3.9032 Å (bounds: [3.8972, 3.9128])
#   Thickness:     6000.00 nm (bounds: [6000.00, 6000.00])
#   Spatial Var:   0.0309 % (bounds: [0.0000, 0.0500])
#   Roughness:     0.2292 nm (bounds: [0.0000, 0.6000])
#   Mosaicity:     0.1910 deg (bounds: [0.0000, 0.5000])
#   Relax Length:  7.23 layers (bounds: [1.00, 10.00])
#   Attenuation:   31645 nm (bounds: [10000, 50000])
#   Instrumental:  0.0312 deg (bounds: [0.0100, 0.1000])
# ======================================================================

# %%
# --- 4. Plot STO Fit Result ---
print("\nGenerating STO fit plot...")
# Re-run simulation with best parameters
nz_STO_best = int((p_STO[2] * 10) / p_STO[1])
lat_arr_STO, h_map_STO, t_arr_STO = create_crystal_system(
    nx_fit_STO, ny_fit_STO, nz_STO_best,
    p_STO[1], [p_STO[0], p_STO[1]],
    mode='full', gradient_type='exponential',
    spatial_var_percent=p_STO[3], roughness_layers=(p_STO[4]*10)/p_STO[1],
    mosaicity_fwhm=p_STO[5], relaxation_length=p_STO[6]
)

# Calculate STO signal
x_exp = exp_data.ttw_df[0]['Angle'].values
y_exp_norm = exp_data.ttw_df[0]['Intensity'].values / peak_int_STO

tt_best_STO, int_best_STO = calculate_xrd_vectorized(
    lat_arr_STO, h_map_STO, t_arr_STO,
    two_theta_range=(fit_range_STO[0]-0.5, fit_range_STO[1]+0.5), # Plot around fit range
    wavelength=wavelength,
    attenuation_length_nm=p_STO[7],
    instrumental_broadening=p_STO[8],
    n_points=1000,
    normalize=True
)

plt.figure(figsize=(10, 6))
# Plot experimental data in the relevant range
mask_plot = (x_exp >= fit_range_STO[0]-0.5) & (x_exp <= fit_range_STO[1]+0.5)
plt.plot(x_exp[mask_plot], y_exp_norm[mask_plot], 'k-', label='Experiment (STO)', alpha=0.5, linewidth=2)
plt.plot(tt_best_STO, int_best_STO, 'r--', label='Best Fit (STO)', linewidth=2)

plt.axvspan(fit_range_STO[0], fit_range_STO[1], color='blue', alpha=0.1, label='STO Fit Region')

plt.xlabel(r'$2\theta$ (degrees)')
plt.ylabel('Normalized Intensity')
plt.title('STO Substrate Fit Result')
plt.legend()
plt.yscale('log')
#plt.ylim(1e-3, 1.5)
plt.grid(True, alpha=0.3)
plt.show()



print("\n" + "="*70)
print("STO Best Fit Parameters:")
print("="*70)
print(f"  c_start:       {p_STO[0]:.4f} Å (bounds: [{bounds_STO[0][0]:.4f}, {bounds_STO[0][1]:.4f}])")
print(f"  c_end:         {p_STO[1]:.4f} Å (bounds: [{bounds_STO[1][0]:.4f}, {bounds_STO[1][1]:.4f}])")
print(f"  Thickness:     {p_STO[2]:.2f} nm (bounds: [{bounds_STO[2][0]:.2f}, {bounds_STO[2][1]:.2f}])")
print(f"  Spatial Var:   {p_STO[3]:.4f} % (bounds: [{bounds_STO[3][0]:.4f}, {bounds_STO[3][1]:.4f}])")
print(f"  Roughness:     {p_STO[4]:.4f} nm (bounds: [{bounds_STO[4][0]:.4f}, {bounds_STO[4][1]:.4f}])")
print(f"  Mosaicity:     {p_STO[5]:.4f} deg (bounds: [{bounds_STO[5][0]:.4f}, {bounds_STO[5][1]:.4f}])")
print(f"  Relax Length:  {p_STO[6]:.2f} layers (bounds: [{bounds_STO[6][0]:.2f}, {bounds_STO[6][1]:.2f}])")
print(f"  Attenuation:   {p_STO[7]:.0f} nm (bounds: [{bounds_STO[7][0]:.0f}, {bounds_STO[7][1]:.0f}])")
print(f"  Instrumental:  {p_STO[8]:.4f} deg (bounds: [{bounds_STO[8][0]:.4f}, {bounds_STO[8][1]:.4f}])")
print("="*70)
# Out:
# Generating STO fit plot...
# ======================================================================
# STO Best Fit Parameters:
# ======================================================================
#   c_start:       3.9032 Å (bounds: [3.8972, 3.9128])
#   c_end:         3.9032 Å (bounds: [3.8972, 3.9128])
#   Thickness:     6000.00 nm (bounds: [6000.00, 6000.00])
#   Spatial Var:   0.0085 % (bounds: [0.0000, 0.0500])
#   Roughness:     0.2371 nm (bounds: [0.0000, 0.6000])
#   Mosaicity:     0.3646 deg (bounds: [0.0000, 0.5000])
#   Relax Length:  4.36 layers (bounds: [1.00, 10.00])
#   Attenuation:   25278 nm (bounds: [10000, 50000])
#   Instrumental:  0.0656 deg (bounds: [0.0100, 0.1000])
# ======================================================================

# %%
# ========== 5b. Step 2: Fit Film (BSO) with Fixed Substrate Background ==========
# Purpose: Fit film parameters using STO-derived instrumental values and background
# Normalization: All data normalized to STO peak = 1. BSO peak is scaled relative to STO.

# --- 1. Generate STO Background for BSO Range ---
fit_range_BSO = (42.0, 45.5)
peak_search_range_BSO = (42.0, 45.0)
nx_fit_BSO, ny_fit_BSO = 8, 8 # Keep higher quality for film fitting

# Find BSO peak
peak_pos_BSO, peak_int_BSO = find_peak(exp_data, peak_search_range_BSO)
print(f"Found BSO peak at {peak_pos_BSO:.3f}° with intensity {peak_int_BSO:.0f}")

# Calculate Scaling Factor
# We normalize the experimental data to the STO peak (Max=1).
# The BSO peak in the experiment is much smaller.
# Ratio = BSO_Intensity / STO_Intensity
film_scale_factor = peak_int_BSO / peak_int_STO
print(f"Film/Substrate Intensity Ratio: {film_scale_factor:.4f}")

# Generate STO simulation over a WIDE range
print("\nGenerating STO background...")
# Use best fit STO parameters
nz_STO = int((p_STO[2] * 10) / p_STO[1])
lat_arr_STO, h_map_STO, t_arr_STO = create_crystal_system(
    nx_fit_STO, ny_fit_STO, nz_STO, # Use STO grid size
    p_STO[1], [p_STO[0], p_STO[1]],
    mode='full', gradient_type='exponential',
    spatial_var_percent=p_STO[3], roughness_layers=(p_STO[4]*10)/p_STO[1],
    mosaicity_fwhm=p_STO[5], relaxation_length=p_STO[6]
)

# Simulate STO over full range (BSO + STO)
full_range = (40.0, 50.0)
tt_full, int_full_STO = calculate_xrd_vectorized(
    lat_arr_STO, h_map_STO, t_arr_STO,
    two_theta_range=full_range,
    wavelength=wavelength,
    attenuation_length_nm=p_STO[7],
    instrumental_broadening=p_STO[8],
    n_points=5000,
    normalize=True # Normalize to STO peak = 1
)

# Interpolate STO signal to the BSO fitting grid (1000 points over fit_range_BSO)
tt_fit_BSO = np.linspace(fit_range_BSO[0], fit_range_BSO[1], 1000)
int_bg_STO = np.interp(tt_fit_BSO, tt_full, int_full_STO)

# Note on Attenuation: The 20nm BSO film attenuates the STO signal by <1% (negligible).
# Since we normalize to the observed STO peak, this effect is implicitly handled.

# --- 2. BSO Fitting Configuration ---
# Use STO results to constrain Instrumental Broadening and Attenuation
instr_STO = p_STO[8]
atten_STO = p_STO[7]

# Calculate c_guess for BSO
theta_rad_BSO = np.radians(peak_pos_BSO / 2)
c_guess_BSO = (wavelength / (2 * np.sin(theta_rad_BSO))) * 2

bounds_BSO = [
    (c_guess_BSO * 0.96, c_guess_BSO * 1.04), # 1. c_start: Lattice parameter at interface (Å)
    (c_guess_BSO * 0.96, c_guess_BSO * 1.04), # 2. c_end: Lattice parameter at surface (Å)
    (40, 48),   # 3. Thickness: Total film thickness (nm)
    (0.0, 0.5),     # 4. Spatial Var: Lattice variation across film (%)
    (0.0, 1.0),     # 5. Roughness: Surface roughness (nm)
    (0.0, 1.0),     # 6. Mosaicity: Crystallite tilt spread (deg)
    (1.0, 50.0),    # 7. Relaxation: Layers for strain to relax
    (atten_STO * 0.97, atten_STO * 1.03),  # 8. Attenuation: Constrained by STO fit (nm)
    (instr_STO * 0.97, instr_STO * 1.03)   # 9. Instrumental: Constrained by STO fit (deg)
]

p0_BSO = np.mean(bounds_BSO, axis=1)

# --- 3. Optimization Settings ---
# For Film: Use global search for robustness (complex Laue oscillations)
use_global_BSO = True   # Set False for faster local-only search
de_maxiter_BSO = 30     # DE iterations (reduce to 20-30 for speed)
de_popsize_BSO = 30     # DE population multiplier
powell_tol_BSO = 0.01  # Powell tolerance
powell_maxiter_BSO = 40  # Powell max iterations

# --- 4. Run BSO Optimization ---
print("\n--- Fitting BSO/SSO Film ---")
# CRITICAL: We fit the SUM of the simulated film and the fixed STO background.
# The optimizer minimizes: Residual = (Experiment - (Film_Sim * Scale + STO_Background))^2
# This correctly handles peak overlap/crossover.
res_BSO = run_xrd_fitting(exp_data, peak_int_STO, wavelength,
                          fit_range=fit_range_BSO,
                          nx_fit=nx_fit_BSO, ny_fit=ny_fit_BSO,
                          use_log_residual=True,
                          p0=p0_BSO, bounds=bounds_BSO,
                          use_global_search=use_global_BSO,
                          de_maxiter=de_maxiter_BSO,
                          de_popsize=de_popsize_BSO,
                          tol=powell_tol_BSO, 
                          maxiter=powell_maxiter_BSO,
                          background_intensity=int_bg_STO,
                          film_scale=film_scale_factor)
# Out:
# Found BSO peak at 44.890° with intensity 34884
# Film/Substrate Intensity Ratio: 0.0045
#
# Generating STO background...
#
# --- Fitting BSO/SSO Film ---
# Setting up optimization in range (42.0, 45.5) with grid 8x8...
# Optimization mode: Global (DE) + Local (Powell)
#   Settings: film_scale=0.0045, background=Enabled
#   DE params: maxiter=30, popsize=30 (total evals ~8100)
#   Powell params: tol=0.01, maxiter=40
#   -> Fitting target: (Simulated_Film * Scale) + Background_Intensity
#
# === STAGE 1: Global Search (Differential Evolution) ===
# Eval 1: Residual = 63.916759
# Eval 2: Residual = 146.188775
# Eval 3: Residual = 80.774155
# Eval 4: Residual = 91.325831
# Eval 5: Residual = 113.130225
# Eval 6: Residual = 78.347103
# Eval 7: Residual = 244.368395
# Eval 8: Residual = 167.027956
# Eval 9: Residual = 111.645487
# Eval 10: Residual = 115.169245
# Eval 11: Residual = 229.586691
# Eval 12: Residual = 166.445305
# Eval 13: Residual = 18.449990
# Eval 14: Residual = 153.063437
# Eval 15: Residual = 261.632424
# Eval 16: Residual = 179.996035
# Eval 17: Residual = 19.417094
# Eval 18: Residual = 258.467509
# Eval 19: Residual = 216.990341
# Eval 20: Residual = 161.782824
# Eval 21: Residual = 158.655219
# Eval 22: Residual = 176.363296
# Eval 23: Residual = 86.345925
# Eval 24: Residual = 178.276795
# Eval 25: Residual = 270.792001
# Eval 26: Residual = 80.095376
# Eval 27: Residual = 96.110382
# Eval 28: Residual = 150.952496
# Eval 29: Residual = 159.021582
# Eval 30: Residual = 327.885872
# Eval 31: Residual = 92.868907
# Eval 32: Residual = 71.775231
# Eval 33: Residual = 132.601599
# Eval 34: Residual = 46.053265
# Eval 35: Residual = 34.417430
# Eval 36: Residual = 70.529891
# Eval 37: Residual = 43.142575
# Eval 38: Residual = 35.313642
# Eval 39: Residual = 208.934895
# Eval 40: Residual = 72.093789
# Eval 41: Residual = 309.189818
# Eval 42: Residual = 56.011960
# Eval 43: Residual = 86.882547
# Eval 44: Residual = 169.729343
# Eval 45: Residual = 172.486331
# Eval 46: Residual = 79.322485
# Eval 47: Residual = 90.925199
# Eval 48: Residual = 92.429270
# Eval 49: Residual = 310.332855
# Eval 50: Residual = 223.200719
# Eval 51: Residual = 52.799421
# Eval 52: Residual = 29.476531
# Eval 53: Residual = 121.669346
# Eval 54: Residual = 262.704622
# Eval 55: Residual = 208.635478
# Eval 56: Residual = 121.230697
# Eval 57: Residual = 231.530966
# Eval 58: Residual = 34.624187
# Eval 59: Residual = 99.836597
# Eval 60: Residual = 125.896040
# Eval 61: Residual = 56.216318
# Eval 62: Residual = 98.447599
# Eval 63: Residual = 187.659155
# Eval 64: Residual = 120.304739
# Eval 65: Residual = 78.899111
# Eval 66: Residual = 263.344942
# Eval 67: Residual = 106.596552
# Eval 68: Residual = 127.824476
# Eval 69: Residual = 174.116998
# Eval 70: Residual = 165.598977
# Eval 71: Residual = 246.568736
# Eval 72: Residual = 228.532398
# Eval 73: Residual = 126.493881
# Eval 74: Residual = 222.418263
# Eval 75: Residual = 211.592288
# Eval 76: Residual = 83.192325
# Eval 77: Residual = 44.287439
# Eval 78: Residual = 78.770537
# Eval 79: Residual = 220.309881
# Eval 80: Residual = 28.223187
# Eval 81: Residual = 18.935489
# Eval 82: Residual = 108.846215
# Eval 83: Residual = 94.462670
# Eval 84: Residual = 86.179157
# Eval 85: Residual = 42.522564
# Eval 86: Residual = 45.114827
# Eval 87: Residual = 316.676619
# Eval 88: Residual = 298.423233
# Eval 89: Residual = 204.942915
# Eval 90: Residual = 48.477217
# Eval 91: Residual = 228.612036
# Eval 92: Residual = 61.694160
# Eval 93: Residual = 282.708702
# Eval 94: Residual = 90.549270
# Eval 95: Residual = 138.593284
# Eval 96: Residual = 123.912665
# Eval 97: Residual = 72.542356
# Eval 98: Residual = 172.203944
# Eval 99: Residual = 110.916319
# Eval 100: Residual = 98.593088
# Eval 101: Residual = 272.286188
# Eval 102: Residual = 197.919343
# Eval 103: Residual = 77.604724
# Eval 104: Residual = 147.018538
# Eval 105: Residual = 162.696461
# Eval 106: Residual = 278.198609
# Eval 107: Residual = 353.831147
# Eval 108: Residual = 26.897173
# Eval 109: Residual = 42.040864
# Eval 110: Residual = 350.619990
# Eval 111: Residual = 127.622775
# Eval 112: Residual = 49.717803
# Eval 113: Residual = 102.077237
# Eval 114: Residual = 106.707730
# Eval 115: Residual = 281.436247
# Eval 116: Residual = 92.198228
# Eval 117: Residual = 101.631668
# Eval 118: Residual = 129.350389
# Eval 119: Residual = 80.573184
# Eval 120: Residual = 153.466488
# Eval 121: Residual = 78.055755
# Eval 122: Residual = 81.489920
# Eval 123: Residual = 56.496797
# Eval 124: Residual = 118.672144
# Eval 125: Residual = 380.627149
# Eval 126: Residual = 183.613789
# Eval 127: Residual = 63.559868
# Eval 128: Residual = 43.584809
# Eval 129: Residual = 60.026119
# Eval 130: Residual = 158.021230
# Eval 131: Residual = 47.318957
# Eval 132: Residual = 145.140806
# Eval 133: Residual = 55.775578
# Eval 134: Residual = 243.516105
# Eval 135: Residual = 127.429031
# Eval 136: Residual = 243.130482
# Eval 137: Residual = 115.332682
# Eval 138: Residual = 96.495188
# Eval 139: Residual = 196.794105
# Eval 140: Residual = 40.329210
# Eval 141: Residual = 100.296340
# Eval 142: Residual = 45.552696
# Eval 143: Residual = 122.994425
# Eval 144: Residual = 128.375259
# Eval 145: Residual = 119.867170
# Eval 146: Residual = 224.367501
# Eval 147: Residual = 189.576380
# Eval 148: Residual = 219.048956
# Eval 149: Residual = 96.080715
# Eval 150: Residual = 202.012023
# Eval 151: Residual = 95.795871
# Eval 152: Residual = 85.365424
# Eval 153: Residual = 172.166046
# Eval 154: Residual = 115.850885
# Eval 155: Residual = 27.475015
# Eval 156: Residual = 73.848300
# Eval 157: Residual = 280.359347
# Eval 158: Residual = 55.350971
# Eval 159: Residual = 225.047392
# Eval 160: Residual = 121.280183
# Eval 161: Residual = 106.809353
# Eval 162: Residual = 29.891426
# Eval 163: Residual = 49.751614
# Eval 164: Residual = 113.422199
# Eval 165: Residual = 152.331055
# Eval 166: Residual = 114.166060
# Eval 167: Residual = 39.945429
# Eval 168: Residual = 156.488471
# Eval 169: Residual = 70.099287
# Eval 170: Residual = 260.312111
# Eval 171: Residual = 72.296181
# Eval 172: Residual = 92.489043
# Eval 173: Residual = 96.033599
# Eval 174: Residual = 267.631117
# Eval 175: Residual = 88.680448
# Eval 176: Residual = 105.204736
# Eval 177: Residual = 219.200190
# Eval 178: Residual = 68.115221
# Eval 179: Residual = 173.102966
# Eval 180: Residual = 193.042672
# Eval 181: Residual = 153.523499
# Eval 182: Residual = 140.385567
# Eval 183: Residual = 212.373962
# Eval 184: Residual = 249.041174
# Eval 185: Residual = 109.759420
# Eval 186: Residual = 198.511224
# Eval 187: Residual = 48.526333
# Eval 188: Residual = 71.668368
# Eval 189: Residual = 93.610857
# Eval 190: Residual = 76.138311
# Eval 191: Residual = 87.278873
# Eval 192: Residual = 307.998289
# Eval 193: Residual = 100.867234
# Eval 194: Residual = 297.626129
# Eval 195: Residual = 39.475063
# Eval 196: Residual = 31.193969
# Eval 197: Residual = 92.684978
# Eval 198: Residual = 122.770363
# Eval 199: Residual = 61.916806
# Eval 200: Residual = 157.596276
# Eval 201: Residual = 77.558221
# Eval 202: Residual = 137.490316
# Eval 203: Residual = 92.632344
# Eval 204: Residual = 78.678664
# Eval 205: Residual = 56.851159
# Eval 206: Residual = 107.048324
# Eval 207: Residual = 42.230033
# Eval 208: Residual = 246.540116
# Eval 209: Residual = 77.947434
# Eval 210: Residual = 69.283502
# Eval 211: Residual = 196.396808
# Eval 212: Residual = 153.312146
# Eval 213: Residual = 99.999993
# Eval 214: Residual = 81.304556
# Eval 215: Residual = 188.763485
# Eval 216: Residual = 71.623273
# Eval 217: Residual = 146.469269
# Eval 218: Residual = 327.968469
# Eval 219: Residual = 20.479991
# Eval 220: Residual = 73.284156
# Eval 221: Residual = 28.952816
# Eval 222: Residual = 128.537142
# Eval 223: Residual = 101.400608
# Eval 224: Residual = 100.125660
# Eval 225: Residual = 221.618012
# Eval 226: Residual = 112.064225
# Eval 227: Residual = 71.641848
# Eval 228: Residual = 63.056584
# Eval 229: Residual = 111.181058
# Eval 230: Residual = 168.067185
# Eval 231: Residual = 115.110446
# Eval 232: Residual = 69.380875
# Eval 233: Residual = 42.445070
# Eval 234: Residual = 99.788868
# Eval 235: Residual = 126.276266
# Eval 236: Residual = 205.470037
# Eval 237: Residual = 190.006794
# Eval 238: Residual = 112.633193
# Eval 239: Residual = 203.059740
# Eval 240: Residual = 44.765138
# Eval 241: Residual = 320.010650
# Eval 242: Residual = 152.674390
# Eval 243: Residual = 132.296699
# Eval 244: Residual = 122.435910
# Eval 245: Residual = 266.892370
# Eval 246: Residual = 34.207110
# Eval 247: Residual = 164.563432
# Eval 248: Residual = 124.851822
# Eval 249: Residual = 208.103401
# Eval 250: Residual = 201.085462
# Eval 251: Residual = 117.864816
# Eval 252: Residual = 175.879675
# Eval 253: Residual = 150.911918
# Eval 254: Residual = 185.852927
# Eval 255: Residual = 166.479844
# Eval 256: Residual = 53.341304
# Eval 257: Residual = 31.683525
# Eval 258: Residual = 135.554204
# Eval 259: Residual = 76.720388
# Eval 260: Residual = 93.458279
# Eval 261: Residual = 170.013662
# Eval 262: Residual = 70.465245
# Eval 263: Residual = 76.994354
# Eval 264: Residual = 74.480161
# Eval 265: Residual = 149.634442
# Eval 266: Residual = 182.509405
# Eval 267: Residual = 94.291662
# Eval 268: Residual = 265.052322
# Eval 269: Residual = 179.585890
# Eval 270: Residual = 63.226289
# Eval 271: Residual = 323.773294
# Eval 272: Residual = 84.763088
# Eval 273: Residual = 159.338090
# Eval 274: Residual = 44.947800
# Eval 275: Residual = 73.289187
# Eval 276: Residual = 93.615599
# Eval 277: Residual = 176.254362
# Eval 278: Residual = 149.668914
# Eval 279: Residual = 141.891092
# Eval 280: Residual = 106.086007
# Eval 281: Residual = 112.666924
# Eval 282: Residual = 102.420974
# Eval 283: Residual = 28.063797
# Eval 284: Residual = 58.001063
# Eval 285: Residual = 65.814857
# Eval 286: Residual = 50.752721
# Eval 287: Residual = 104.028054
# Eval 288: Residual = 298.216740
# Eval 289: Residual = 57.229740
# Eval 290: Residual = 179.443208
# Eval 291: Residual = 111.184871
# Eval 292: Residual = 118.140209
# Eval 293: Residual = 25.088435
# Eval 294: Residual = 170.629492
# Eval 295: Residual = 35.724143
# Eval 296: Residual = 99.186933
# Eval 297: Residual = 278.793289
# Eval 298: Residual = 184.007293
# Eval 299: Residual = 57.395838
# Eval 300: Residual = 65.527647
# Eval 301: Residual = 75.404720
# Eval 302: Residual = 87.733901
# Eval 303: Residual = 91.159084
# Eval 304: Residual = 94.139182
# Eval 305: Residual = 255.470059
# Eval 306: Residual = 94.905880
# Eval 307: Residual = 99.986144
# Eval 308: Residual = 53.401009
# Eval 309: Residual = 284.976699
# Eval 310: Residual = 330.058632
# Eval 311: Residual = 266.284448
# Eval 312: Residual = 74.348353
# Eval 313: Residual = 130.741743
# Eval 314: Residual = 93.693974
# Eval 315: Residual = 65.127970
# Eval 316: Residual = 49.799884
# Eval 317: Residual = 102.512950
# Eval 318: Residual = 134.419581
# Eval 319: Residual = 190.081688
# Eval 320: Residual = 179.639348
# Eval 321: Residual = 41.777266
# Eval 322: Residual = 186.189443
# Eval 323: Residual = 107.679868
# Eval 324: Residual = 41.613270
# Eval 325: Residual = 194.219059
# Eval 326: Residual = 44.930235
# Eval 327: Residual = 87.321483
# Eval 328: Residual = 68.215487
# Eval 329: Residual = 80.261875
# Eval 330: Residual = 111.297728
# Eval 331: Residual = 59.907483
# Eval 332: Residual = 34.610751
# Eval 333: Residual = 36.773521
# Eval 334: Residual = 118.468187
# Eval 335: Residual = 78.450690
# Eval 336: Residual = 309.029616
# Eval 337: Residual = 37.338246
# Eval 338: Residual = 111.576533
# Eval 339: Residual = 133.804348
# Eval 340: Residual = 67.480478
# Eval 341: Residual = 25.255560
# Eval 342: Residual = 60.478287
# Eval 343: Residual = 78.112293
# Eval 344: Residual = 176.095041
# Eval 345: Residual = 162.613800
# Eval 346: Residual = 155.893472
# Eval 347: Residual = 92.760822
# Eval 348: Residual = 73.631070
# Eval 349: Residual = 179.946606
# Eval 350: Residual = 95.968163
# Eval 351: Residual = 30.395226
# Eval 352: Residual = 66.713351
# Eval 353: Residual = 64.286296
# Eval 354: Residual = 39.475198
# Eval 355: Residual = 36.869706
# Eval 356: Residual = 80.940730
# Eval 357: Residual = 73.796348
# Eval 358: Residual = 292.836474
# Eval 359: Residual = 100.527440
# Eval 360: Residual = 50.738005
# Eval 361: Residual = 124.843582
# Eval 362: Residual = 68.148596
# Eval 363: Residual = 160.078536
# Eval 364: Residual = 130.833138
# Eval 365: Residual = 201.849684
# Eval 366: Residual = 147.791058
# Eval 367: Residual = 65.773761
# Eval 368: Residual = 51.297090
# Eval 369: Residual = 76.404390
# Eval 370: Residual = 50.007232
# Eval 371: Residual = 273.312485
# Eval 372: Residual = 91.625426
# Eval 373: Residual = 31.256822
# Eval 374: Residual = 103.421921
# Eval 375: Residual = 132.143988
# Eval 376: Residual = 174.058779
# Eval 377: Residual = 236.757807
# Eval 378: Residual = 129.296904
# Eval 379: Residual = 157.060230
# Eval 380: Residual = 48.762159
# Eval 381: Residual = 144.407452
# Eval 382: Residual = 52.007450
# Eval 383: Residual = 170.276035
# Eval 384: Residual = 208.898744
# Eval 385: Residual = 105.455304
# Eval 386: Residual = 113.803513
# Eval 387: Residual = 88.494328
# Eval 388: Residual = 199.728185
# Eval 389: Residual = 69.813668
# Eval 390: Residual = 51.034484
# Eval 391: Residual = 99.139584
# Eval 392: Residual = 167.578766
# Eval 393: Residual = 129.506804
# Eval 394: Residual = 108.855685
# Eval 395: Residual = 326.940745
# Eval 396: Residual = 305.128312
# Eval 397: Residual = 175.889669
# Eval 398: Residual = 106.262609
# Eval 399: Residual = 113.502962
# Eval 400: Residual = 170.263948
# Eval 401: Residual = 47.990574
# Eval 402: Residual = 37.836248
# Eval 403: Residual = 301.021573
# Eval 404: Residual = 137.872609
# Eval 405: Residual = 164.407433
# Eval 406: Residual = 192.394282
# Eval 407: Residual = 31.076196
# Eval 408: Residual = 83.960024
# Eval 409: Residual = 149.833398
# Eval 410: Residual = 308.126113
# Eval 411: Residual = 103.864510
# Eval 412: Residual = 23.557588
# Eval 413: Residual = 27.589773
# Eval 414: Residual = 122.096242
# Eval 415: Residual = 86.552189
# Eval 416: Residual = 280.919096
# Eval 417: Residual = 130.766688
# Eval 418: Residual = 46.882899
# Eval 419: Residual = 38.219245
# Eval 420: Residual = 111.317852
# Eval 421: Residual = 76.045142
# Eval 422: Residual = 132.442381
# Eval 423: Residual = 93.308130
# Eval 424: Residual = 87.977763
# Eval 425: Residual = 67.936439
# Eval 426: Residual = 156.563059
# Eval 427: Residual = 37.322988
# Eval 428: Residual = 168.734083
# Eval 429: Residual = 253.094278
# Eval 430: Residual = 184.290041
# Eval 431: Residual = 97.865612
# Eval 432: Residual = 37.709601
# Eval 433: Residual = 211.092165
# Eval 434: Residual = 146.499840
# Eval 435: Residual = 91.752656
# Eval 436: Residual = 196.337555
# Eval 437: Residual = 72.967912
# Eval 438: Residual = 200.993035
# Eval 439: Residual = 74.584794
# Eval 440: Residual = 171.873947
# Eval 441: Residual = 123.197946
# Eval 442: Residual = 257.975668
# Eval 443: Residual = 45.700587
# Eval 444: Residual = 208.737158
# Eval 445: Residual = 71.639031
# Eval 446: Residual = 72.060861
# Eval 447: Residual = 175.045822
# Eval 448: Residual = 295.007996
# Eval 449: Residual = 89.799847
# Eval 450: Residual = 210.358517
# Eval 451: Residual = 74.641084
# Eval 452: Residual = 198.434323
# Eval 453: Residual = 94.286808
# Eval 454: Residual = 106.618510
# Eval 455: Residual = 101.792195
# Eval 456: Residual = 51.123182
# Eval 457: Residual = 58.836059
# Eval 458: Residual = 203.488796
# Eval 459: Residual = 56.430816
# Eval 460: Residual = 162.581440
# Eval 461: Residual = 46.558389
# Eval 462: Residual = 305.165879
# Eval 463: Residual = 97.904094
# Eval 464: Residual = 25.325419
# Eval 465: Residual = 127.969797
# Eval 466: Residual = 202.162748
# Eval 467: Residual = 83.170524
# Eval 468: Residual = 196.281232
# Eval 469: Residual = 79.062269
# Eval 470: Residual = 90.060319
# Eval 471: Residual = 138.006296
# Eval 472: Residual = 160.890116
# Eval 473: Residual = 43.182353
# Eval 474: Residual = 121.800165
# Eval 475: Residual = 87.896721
# Eval 476: Residual = 126.665456
# Eval 477: Residual = 63.001996
# Eval 478: Residual = 50.958615
# Eval 479: Residual = 229.070271
# Eval 480: Residual = 93.947057
# Eval 481: Residual = 183.011330
# Eval 482: Residual = 151.100600
# Eval 483: Residual = 42.003168
# Eval 484: Residual = 50.049930
# Eval 485: Residual = 114.872232
# Eval 486: Residual = 115.513542
# Eval 487: Residual = 44.627155
# Eval 488: Residual = 342.712697
# Eval 489: Residual = 98.032192
# Eval 490: Residual = 41.595466
# Eval 491: Residual = 138.000666
# Eval 492: Residual = 263.821355
# Eval 493: Residual = 139.825563
# Eval 494: Residual = 87.963703
# Eval 495: Residual = 69.229929
# Eval 496: Residual = 224.533496
# Eval 497: Residual = 228.280713
# Eval 498: Residual = 35.833807
# Eval 499: Residual = 40.353252
# Eval 500: Residual = 91.736074
# Eval 501: Residual = 84.604133
# Eval 502: Residual = 118.550014
# Eval 503: Residual = 66.231074
# Eval 504: Residual = 40.978300
# Eval 505: Residual = 122.523371
# Eval 506: Residual = 115.302369
# Eval 507: Residual = 31.816520
# Eval 508: Residual = 107.400814
# Eval 509: Residual = 137.980933
# Eval 510: Residual = 77.469914
# Eval 511: Residual = 340.203698
# Eval 512: Residual = 246.499208
# Eval 513: Residual = 77.455550
# Eval 514: Residual = 40.273510
# Eval 515: Residual = 46.109046
# Eval 516: Residual = 30.275904
# Eval 517: Residual = 42.799959
# Eval 518: Residual = 104.797815
# Eval 519: Residual = 216.441010
# Eval 520: Residual = 155.554672
# Eval 521: Residual = 91.375144
# Eval 522: Residual = 174.278385
# Eval 523: Residual = 119.622166
# Eval 524: Residual = 227.641866
# Eval 525: Residual = 102.887402
# Eval 526: Residual = 142.067960
# Eval 527: Residual = 241.266562
# Eval 528: Residual = 135.533495
# Eval 529: Residual = 204.819428
# Eval 530: Residual = 74.977936
# Eval 531: Residual = 32.447984
# Eval 532: Residual = 289.490223
# Eval 533: Residual = 35.073525
# Eval 534: Residual = 57.208963
# Eval 535: Residual = 229.360665
# Eval 536: Residual = 94.388557
# Eval 537: Residual = 163.584739
# Eval 538: Residual = 211.265635
# Eval 539: Residual = 155.291784
# Eval 540: Residual = 42.421753
# Eval 541: Residual = 90.283678
# Eval 542: Residual = 92.885328
# Eval 543: Residual = 65.139808
# Eval 544: Residual = 29.454704
# Eval 545: Residual = 43.496555
# Eval 546: Residual = 121.153974
# Eval 547: Residual = 43.519534
# Eval 548: Residual = 43.853299
# Eval 549: Residual = 228.070280
# Eval 550: Residual = 69.357916
# Eval 551: Residual = 198.903292
# Eval 552: Residual = 120.738471
# Eval 553: Residual = 141.021670
# Eval 554: Residual = 42.756796
# Eval 555: Residual = 123.329623
# Eval 556: Residual = 83.498342
# Eval 557: Residual = 70.076852
# Eval 558: Residual = 89.181369
# Eval 559: Residual = 24.820603
# Eval 560: Residual = 74.830853
# Eval 561: Residual = 45.678792
# Eval 562: Residual = 71.380911
# Eval 563: Residual = 160.018495
# Eval 564: Residual = 105.308998
# Eval 565: Residual = 95.061417
# Eval 566: Residual = 203.442198
# Eval 567: Residual = 207.689879
# Eval 568: Residual = 180.592893
# Eval 569: Residual = 139.497968
# Eval 570: Residual = 223.039376
# Eval 571: Residual = 35.047785
# Eval 572: Residual = 238.324318
# Eval 573: Residual = 151.720251
# Eval 574: Residual = 46.147728
# Eval 575: Residual = 85.268635
# Eval 576: Residual = 68.320317
# Eval 577: Residual = 38.381664
# Eval 578: Residual = 97.425055
# Eval 579: Residual = 57.747928
# Eval 580: Residual = 23.795676
# Eval 581: Residual = 57.153012
# Eval 582: Residual = 105.627640
# Eval 583: Residual = 116.476106
# Eval 584: Residual = 168.282000
# Eval 585: Residual = 48.196650
# Eval 586: Residual = 56.547433
# Eval 587: Residual = 146.642868
# Eval 588: Residual = 52.929466
# Eval 589: Residual = 23.484010
# Eval 590: Residual = 202.822094
# Eval 591: Residual = 89.145448
# Eval 592: Residual = 162.424230
# Eval 593: Residual = 146.321642
# Eval 594: Residual = 18.912861
# Eval 595: Residual = 275.544642
# Eval 596: Residual = 142.078581
# Eval 597: Residual = 23.785993
# Eval 598: Residual = 41.676257
# Eval 599: Residual = 174.562416
# Eval 600: Residual = 260.712794
# Eval 601: Residual = 24.233333
# Eval 602: Residual = 40.448386
# Eval 603: Residual = 157.770788
# Eval 604: Residual = 31.452687
# Eval 605: Residual = 22.427464
# Eval 606: Residual = 280.926357
# Eval 607: Residual = 113.781453
# Eval 608: Residual = 150.116340
# Eval 609: Residual = 141.897558
# Eval 610: Residual = 78.186106
# Eval 611: Residual = 238.999969
# Eval 612: Residual = 11.812466
# Eval 613: Residual = 60.460329
# Eval 614: Residual = 88.889812
# Eval 615: Residual = 81.323756
# Eval 616: Residual = 239.107570
# Eval 617: Residual = 29.011319
# Eval 618: Residual = 50.851043
# Eval 619: Residual = 65.247782
# Eval 620: Residual = 72.985313
# Eval 621: Residual = 46.099266
# Eval 622: Residual = 85.642615
# Eval 623: Residual = 169.641643
# Eval 624: Residual = 29.445129
# Eval 625: Residual = 35.622142
# Eval 626: Residual = 153.543023
# Eval 627: Residual = 81.774788
# Eval 628: Residual = 220.191453
# Eval 629: Residual = 72.399877
# Eval 630: Residual = 59.348040
# Eval 631: Residual = 135.512505
# Eval 632: Residual = 44.901934
# Eval 633: Residual = 82.004880
# Eval 634: Residual = 240.060771
# Eval 635: Residual = 129.900463
# Eval 636: Residual = 39.159846
# Eval 637: Residual = 63.800264
# Eval 638: Residual = 102.091653
# Eval 639: Residual = 56.758349
# Eval 640: Residual = 109.388728
# Eval 641: Residual = 108.234799
# Eval 642: Residual = 114.589647
# Eval 643: Residual = 31.630328
# Eval 644: Residual = 247.896398
# Eval 645: Residual = 69.115029
# Eval 646: Residual = 62.142690
# Eval 647: Residual = 241.196236
# Eval 648: Residual = 29.512308
# Eval 649: Residual = 75.356673
# Eval 650: Residual = 56.369308
# Eval 651: Residual = 90.692035
# Eval 652: Residual = 47.773516
# Eval 653: Residual = 178.560975
# Eval 654: Residual = 37.134198
# Eval 655: Residual = 149.054837
# Eval 656: Residual = 42.959316
# Eval 657: Residual = 43.573286
# Eval 658: Residual = 57.308936
# Eval 659: Residual = 116.330008
# Eval 660: Residual = 43.710451
# Eval 661: Residual = 76.443878
# Eval 662: Residual = 45.913455
# Eval 663: Residual = 89.457697
# Eval 664: Residual = 122.599225
# Eval 665: Residual = 131.262313
# Eval 666: Residual = 29.336869
# Eval 667: Residual = 184.105958
# Eval 668: Residual = 127.412386
# Eval 669: Residual = 31.846088
# Eval 670: Residual = 198.706340
# Eval 671: Residual = 91.313164
# Eval 672: Residual = 30.712916
# Eval 673: Residual = 106.502236
# Eval 674: Residual = 20.986842
# Eval 675: Residual = 308.454111
# Eval 676: Residual = 36.389262
# Eval 677: Residual = 83.237658
# Eval 678: Residual = 23.780875
# Eval 679: Residual = 42.838700
# Eval 680: Residual = 15.699124
# Eval 681: Residual = 110.337813
# Eval 682: Residual = 25.047615
# Eval 683: Residual = 130.391283
# Eval 684: Residual = 91.071901
# Eval 685: Residual = 35.679088
# Eval 686: Residual = 103.453309
# Eval 687: Residual = 83.580224
# Eval 688: Residual = 293.633411
# Eval 689: Residual = 29.084567
# Eval 690: Residual = 109.502312
# Eval 691: Residual = 40.457582
# Eval 692: Residual = 90.184479
# Eval 693: Residual = 48.322212
# Eval 694: Residual = 167.018840
# Eval 695: Residual = 49.073487
# Eval 696: Residual = 85.956301
# Eval 697: Residual = 83.639938
# Eval 698: Residual = 75.945809
# Eval 699: Residual = 147.661324
# Eval 700: Residual = 43.832931
# Eval 701: Residual = 73.505308
# Eval 702: Residual = 144.768214
# Eval 703: Residual = 31.505713
# Eval 704: Residual = 99.845049
# Eval 705: Residual = 154.005984
# Eval 706: Residual = 177.792524
# Eval 707: Residual = 82.147608
# Eval 708: Residual = 71.873205
# Eval 709: Residual = 69.484483
# Eval 710: Residual = 110.857880
# Eval 711: Residual = 156.105310
# Eval 712: Residual = 209.450330
# Eval 713: Residual = 79.255076
# Eval 714: Residual = 63.901846
# Eval 715: Residual = 73.651166
# Eval 716: Residual = 306.421971
# Eval 717: Residual = 97.727670
# Eval 718: Residual = 27.713531
# Eval 719: Residual = 36.567266
# Eval 720: Residual = 197.759272
# Eval 721: Residual = 175.877944
# Eval 722: Residual = 76.534002
# Eval 723: Residual = 173.069185
# Eval 724: Residual = 118.575157
# Eval 725: Residual = 72.059172
# Eval 726: Residual = 233.304168
# Eval 727: Residual = 38.524473
# Eval 728: Residual = 43.431108
# Eval 729: Residual = 80.975466
# Eval 730: Residual = 102.264703
# Eval 731: Residual = 125.110063
# Eval 732: Residual = 72.532417
# Eval 733: Residual = 28.002669
# Eval 734: Residual = 31.373393
# Eval 735: Residual = 19.916974
# Eval 736: Residual = 301.286180
# Eval 737: Residual = 30.202891
# Eval 738: Residual = 117.725864
# Eval 739: Residual = 61.014931
# Eval 740: Residual = 64.333752
# Eval 741: Residual = 121.310234
# Eval 742: Residual = 196.111503
# Eval 743: Residual = 80.411044
# Eval 744: Residual = 51.610941
# Eval 745: Residual = 105.213481
# Eval 746: Residual = 113.661866
# Eval 747: Residual = 64.533149
# Eval 748: Residual = 18.532684
# Eval 749: Residual = 77.062594
# Eval 750: Residual = 23.454004
# Eval 751: Residual = 77.632983
# Eval 752: Residual = 39.423262
# Eval 753: Residual = 88.100607
# Eval 754: Residual = 139.852901
# Eval 755: Residual = 70.821041
# Eval 756: Residual = 74.389820
# Eval 757: Residual = 28.126079
# Eval 758: Residual = 325.548055
# Eval 759: Residual = 55.752934
# Eval 760: Residual = 49.440972
# Eval 761: Residual = 47.158407
# Eval 762: Residual = 51.825471
# Eval 763: Residual = 48.953917
# Eval 764: Residual = 152.997084
# Eval 765: Residual = 41.176420
# Eval 766: Residual = 109.579048
# Eval 767: Residual = 47.233922
# Eval 768: Residual = 135.425893
# Eval 769: Residual = 46.576675
# Eval 770: Residual = 75.228635
# Eval 771: Residual = 235.504389
# Eval 772: Residual = 254.092885
# Eval 773: Residual = 77.821581
# Eval 774: Residual = 57.548203
# Eval 775: Residual = 113.607388
# Eval 776: Residual = 119.573295
# Eval 777: Residual = 39.364487
# Eval 778: Residual = 176.270844
# Eval 779: Residual = 132.297490
# Eval 780: Residual = 92.987256
# Eval 781: Residual = 361.657964
# Eval 782: Residual = 84.958735
# Eval 783: Residual = 157.046857
# Eval 784: Residual = 171.744373
# Eval 785: Residual = 46.457959
# Eval 786: Residual = 51.728409
# Eval 787: Residual = 178.733246
# Eval 788: Residual = 106.096765
# Eval 789: Residual = 167.001327
# Eval 790: Residual = 58.571647
# Eval 791: Residual = 25.226177
# Eval 792: Residual = 201.870984
# Eval 793: Residual = 71.770353
# Eval 794: Residual = 164.793199
# Eval 795: Residual = 132.679562
# Eval 796: Residual = 35.387637
# Eval 797: Residual = 51.733215
# Eval 798: Residual = 104.735802
# Eval 799: Residual = 122.468845
# Eval 800: Residual = 70.262602
# Eval 801: Residual = 68.035518
# Eval 802: Residual = 29.373935
# Eval 803: Residual = 92.174669
# Eval 804: Residual = 78.059600
# Eval 805: Residual = 142.419067
# Eval 806: Residual = 36.611800
# Eval 807: Residual = 178.264476
# Eval 808: Residual = 193.043294
# Eval 809: Residual = 216.113783
# Eval 810: Residual = 23.495313
# Eval 811: Residual = 19.033291
# Eval 812: Residual = 97.473913
# Eval 813: Residual = 44.916461
# Eval 814: Residual = 121.084300
# Eval 815: Residual = 84.597803
# Eval 816: Residual = 173.634753
# Eval 817: Residual = 74.548533
# Eval 818: Residual = 114.219037
# Eval 819: Residual = 26.219416
# Eval 820: Residual = 26.683482
# Eval 821: Residual = 34.499699
# Eval 822: Residual = 77.504491
# Eval 823: Residual = 78.237835
# Eval 824: Residual = 135.273667
# Eval 825: Residual = 103.752162
# Eval 826: Residual = 68.991551
# Eval 827: Residual = 107.880575
# Eval 828: Residual = 91.976482
# Eval 829: Residual = 84.308422
# Eval 830: Residual = 21.820052
# Eval 831: Residual = 73.263337
# Eval 832: Residual = 135.131665
# Eval 833: Residual = 199.664679
# Eval 834: Residual = 20.709335
# Eval 835: Residual = 129.618943
# Eval 836: Residual = 259.145696
# Eval 837: Residual = 178.293632
# Eval 838: Residual = 144.570120
# Eval 839: Residual = 62.219692
# Eval 840: Residual = 44.828914
# Eval 841: Residual = 160.449954
# Eval 842: Residual = 122.209097
# Eval 843: Residual = 242.689410
# Eval 844: Residual = 77.134557
# Eval 845: Residual = 35.076094
# Eval 846: Residual = 32.248120
# Eval 847: Residual = 48.613303
# Eval 848: Residual = 70.160927
# Eval 849: Residual = 30.759864
# Eval 850: Residual = 27.899421
# Eval 851: Residual = 211.662846
# Eval 852: Residual = 130.729146
# Eval 853: Residual = 103.515804
# Eval 854: Residual = 203.182341
# Eval 855: Residual = 43.490310
# Eval 856: Residual = 90.930640
# Eval 857: Residual = 79.536794
# Eval 858: Residual = 103.102988
# Eval 859: Residual = 24.413256
# Eval 860: Residual = 336.546822
# Eval 861: Residual = 145.999239
# Eval 862: Residual = 123.156537
# Eval 863: Residual = 24.971209
# Eval 864: Residual = 43.783617
# Eval 865: Residual = 89.055988
# Eval 866: Residual = 76.251937
# Eval 867: Residual = 217.334131
# Eval 868: Residual = 71.603429
# Eval 869: Residual = 22.781528
# Eval 870: Residual = 129.908807
# Eval 871: Residual = 61.971562
# Eval 872: Residual = 165.993433
# Eval 873: Residual = 73.474953
# Eval 874: Residual = 121.002858
# Eval 875: Residual = 67.802853
# Eval 876: Residual = 84.406876
# Eval 877: Residual = 33.721397
# Eval 878: Residual = 152.619265
# Eval 879: Residual = 46.461816
# Eval 880: Residual = 51.638271
# Eval 881: Residual = 93.850090
# Eval 882: Residual = 35.295565
# Eval 883: Residual = 54.474709
# Eval 884: Residual = 84.602470
# Eval 885: Residual = 154.204898
# Eval 886: Residual = 52.992060
# Eval 887: Residual = 143.238192
# Eval 888: Residual = 101.097475
# Eval 889: Residual = 75.069539
# Eval 890: Residual = 81.780315
# Eval 891: Residual = 23.797170
# Eval 892: Residual = 87.141343
# Eval 893: Residual = 88.977087
# Eval 894: Residual = 62.330948
# Eval 895: Residual = 115.894075
# Eval 896: Residual = 157.063212
# Eval 897: Residual = 29.595559
# Eval 898: Residual = 79.299838
# Eval 899: Residual = 55.619136
# Eval 900: Residual = 90.608978
# Eval 901: Residual = 85.527579
# Eval 902: Residual = 28.534383
# Eval 903: Residual = 87.486832
# Eval 904: Residual = 67.643303
# Eval 905: Residual = 149.104011
# Eval 906: Residual = 105.509715
# Eval 907: Residual = 56.401628
# Eval 908: Residual = 150.575726
# Eval 909: Residual = 37.622373
# Eval 910: Residual = 54.162906
# Eval 911: Residual = 97.670980
# Eval 912: Residual = 129.056089
# Eval 913: Residual = 254.950344
# Eval 914: Residual = 226.116689
# Eval 915: Residual = 89.152271
# Eval 916: Residual = 72.423086
# Eval 917: Residual = 226.191987
# Eval 918: Residual = 26.850540
# Eval 919: Residual = 238.984480
# Eval 920: Residual = 160.025751
# Eval 921: Residual = 119.612804
# Eval 922: Residual = 51.035852
# Eval 923: Residual = 93.535623
# Eval 924: Residual = 116.208351
# Eval 925: Residual = 151.328239
# Eval 926: Residual = 184.438852
# Eval 927: Residual = 36.536795
# Eval 928: Residual = 223.277051
# Eval 929: Residual = 67.574433
# Eval 930: Residual = 97.333681
# Eval 931: Residual = 44.400471
# Eval 932: Residual = 67.089483
# Eval 933: Residual = 141.455862
# Eval 934: Residual = 60.496892
# Eval 935: Residual = 108.359594
# Eval 936: Residual = 68.648364
# Eval 937: Residual = 196.067041
# Eval 938: Residual = 30.217483
# Eval 939: Residual = 115.173924
# Eval 940: Residual = 40.944418
# Eval 941: Residual = 97.026129
# Eval 942: Residual = 49.797110
# Eval 943: Residual = 77.132304
# Eval 944: Residual = 77.821071
# Eval 945: Residual = 183.327620
# Eval 946: Residual = 53.588282
# Eval 947: Residual = 39.336277
# Eval 948: Residual = 54.773870
# Eval 949: Residual = 64.835120
# Eval 950: Residual = 90.569828
# Eval 951: Residual = 172.689670
# Eval 952: Residual = 80.197677
# Eval 953: Residual = 45.332140
# Eval 954: Residual = 88.251746
# Eval 955: Residual = 32.966835
# Eval 956: Residual = 41.982873
# Eval 957: Residual = 148.481970
# Eval 958: Residual = 25.408108
# Eval 959: Residual = 63.273547
# Eval 960: Residual = 71.871444
# Eval 961: Residual = 61.710739
# Eval 962: Residual = 83.438240
# Eval 963: Residual = 180.484079
# Eval 964: Residual = 122.618096
# Eval 965: Residual = 33.862049
# Eval 966: Residual = 145.877827
# Eval 967: Residual = 65.009503

# %%
# --- 4. Plot Final Result ---
p_best = res_BSO.x
print("\n" + "="*70)
print("Film (BSO/SSO) Best Fit Parameters:")
print("="*70)
print(f"  c_start (Interface):  {p_best[0]:.4f} Å (bounds: [{bounds_BSO[0][0]:.4f}, {bounds_BSO[0][1]:.4f}])")
print(f"  c_end (Surface):      {p_best[1]:.4f} Å (bounds: [{bounds_BSO[1][0]:.4f}, {bounds_BSO[1][1]:.4f}])")
print(f"  Thickness:            {p_best[2]:.2f} nm (bounds: [{bounds_BSO[2][0]:.2f}, {bounds_BSO[2][1]:.2f}])")
print(f"  Spatial Var:          {p_best[3]:.4f} % (bounds: [{bounds_BSO[3][0]:.4f}, {bounds_BSO[3][1]:.4f}])")
print(f"  Roughness:            {p_best[4]:.4f} nm (bounds: [{bounds_BSO[4][0]:.4f}, {bounds_BSO[4][1]:.4f}])")
print(f"  Mosaicity:            {p_best[5]:.4f} deg (bounds: [{bounds_BSO[5][0]:.4f}, {bounds_BSO[5][1]:.4f}])")
print(f"  Relax Length:         {p_best[6]:.2f} layers (bounds: [{bounds_BSO[6][0]:.2f}, {bounds_BSO[6][1]:.2f}])")
print(f"  Attenuation:          {p_best[7]:.0f} nm (bounds: [{bounds_BSO[7][0]:.0f}, {bounds_BSO[7][1]:.0f}])")
print(f"  Instrumental:         {p_best[8]:.4f} deg (bounds: [{bounds_BSO[8][0]:.4f}, {bounds_BSO[8][1]:.4f}])")
print("="*70)

# Re-run simulation with best parameters
nz_best = int((p_best[2] * 10) / p_best[1])
r_layers_best = (p_best[4] * 10) / p_best[1]

lat_arr, h_map, t_arr = create_crystal_system(
    nx_fit_BSO, ny_fit_BSO, nz_best,
    p_best[1], [p_best[0], p_best[1]],
    mode='full', gradient_type='exponential',
    spatial_var_percent=p_best[3], roughness_layers=r_layers_best,
    mosaicity_fwhm=p_best[5], relaxation_length=p_best[6]
)

# Calculate BSO signal
x_exp = exp_data.ttw_df[0]['Angle'].values
y_exp_norm = exp_data.ttw_df[0]['Intensity'].values / peak_int_STO # Normalize to STO=1

tt_best, int_best_BSO = calculate_xrd_vectorized(
    lat_arr, h_map, t_arr,
    two_theta_range=(x_exp.min(), x_exp.max()),
    wavelength=wavelength,
    attenuation_length_nm=p_best[7],
    instrumental_broadening=p_best[8],
    n_points=3000,
    normalize=True
)

# Add STO background (interpolated to full range)
int_bg_STO_full = np.interp(tt_best, tt_full, int_full_STO)
# Total = (BSO_Sim * Scale) + STO_Background
int_total = (int_best_BSO * film_scale_factor) + int_bg_STO_full

plt.figure(figsize=(10, 6))
plt.plot(x_exp, y_exp_norm, 'k-', label='Experiment (Norm to STO)', alpha=0.5, linewidth=2)
plt.plot(tt_best, int_total, 'r--', label='Best Fit (BSO + STO)', linewidth=2)
plt.plot(tt_best, int_bg_STO_full, 'g:', label='STO Background', linewidth=1)

plt.axvspan(fit_range_BSO[0], fit_range_BSO[1], color='yellow', alpha=0.1, label='BSO Fit Region')
plt.axvspan(fit_range_STO[0], fit_range_STO[1], color='blue', alpha=0.1, label='STO Fit Region')

plt.xlabel(r'$2\theta$ (degrees)')
plt.ylabel('Normalized Intensity (STO=1)')
plt.title('Double Fit Result: BSO Film + STO Substrate')
plt.legend()
plt.yscale('log')
#plt.ylim(1e-4, 1.5)
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ## Multi-Peak Fitting: Overlapping BSO + SSO
#
# This section demonstrates simultaneous fitting of multiple overlapping film peaks (e.g., BSO and SSO) with the STO substrate background.
#
# **Key Differences from Single-Peak Fitting:**
# - Each peak has its own 9 parameters (lattice, thickness, roughness, etc.)
# - All peaks are simulated and summed together before comparison to experiment
# - The optimizer adjusts all parameters simultaneously to minimize total residual
# - Enables proper deconvolution of overlapping contributions

# %%
# ========== Fit Substrate (STO) Peak ==========
# Purpose: Determine instrumental broadening and attenuation length accurately
# Range: 46.0 - 48.0 degrees (STO 002 peak)



print('experimental_data=',single_dat) # chosen experimental data for fitting
exp_data = single_dat[0]
wavelength = exp_data.wavelength


# --- 1. STO Fitting Configuration ---
fit_range_STO = (46.0, 47.5)
# OPTIMIZATION: Reduced grid size for Substrate. 
# STO is uniform, so we don't need many columns to average out spatial variation.
nx_fit_STO, ny_fit_STO = 1, 1 
peak_search_range_STO = (46.0, 48.0)

# Find STO peak
peak_pos_STO, peak_int_STO = find_peak(exp_data, peak_search_range_STO)
print(f"Found STO peak at {peak_pos_STO:.3f}° with intensity {peak_int_STO:.0f}")

# Known STO Parameters
c_STO_lit = 3.905 # Å (Literature value for SrTiO3)

# --- 2. Bounds for STO (Substrate) ---
# Note on Thickness: We use 1500 nm. 
# Real thickness is 500,000 nm, but simulating >1 million layers causes memory crashes.
# 1500 nm is sufficient to approximate a "thick" crystal (Laue fringes merge).

bounds_STO = [
    (c_STO_lit * 0.998, c_STO_lit * 1.002), # 1. c_start: Fixed to 3.905 Å (Interface)
    (c_STO_lit * 0.998, c_STO_lit * 1.002), # 2. c_end: Fixed to 3.905 Å (Surface)
    (6000.0, 6000.0), # 3. Thickness: Fixed to 1500 nm (Computational Limit)
    (0.0, 0.05),     # 4. Spatial Var: Lattice variation (%) - Low for single crystal
    (0.0, 0.6),     # 5. Roughness: Surface roughness (nm)
    (0.0, 0.5),     # 6. Mosaicity: Crystallite tilt (deg)
    (1.0, 10.0),    # 7. Relaxation: Strain relaxation length (layers) - Irrelevant for constant c
    (10000, 50000),  # 8. Attenuation: X-ray penetration depth (nm) - FITTING TARGET
    (0.01, 0.1)     # 9. Instrumental: Machine broadening (deg) - FITTING TARGET
]

p0_STO = np.mean(bounds_STO, axis=1)

# --- 3. Optimization Settings ---
# For STO: Can use faster local-only search since it's a simple peak
use_global_STO = False  # Set True for global search (slower, more robust)
de_maxiter_STO = 30     # DE iterations (if use_global_STO=True)
de_popsize_STO = 10     # DE population multiplier (if use_global_STO=True)
powell_tol_STO = 0.01   # Powell tolerance (lower = more precise)
powell_maxiter_STO = 100  # Powell max iterations

# --- 4. Run STO Optimization ---
print("\n--- Fitting STO Substrate ---")
res_STO = run_xrd_fitting(exp_data, peak_int_STO, wavelength,
                          fit_range=fit_range_STO,
                          nx_fit=nx_fit_STO, ny_fit=ny_fit_STO,
                          use_log_residual=True,
                          p0=p0_STO, bounds=bounds_STO,
                          use_global_search=use_global_STO,
                          de_maxiter=de_maxiter_STO,
                          de_popsize=de_popsize_STO,
                          tol=powell_tol_STO, 
                          maxiter=powell_maxiter_STO)

p_STO = res_STO.x
print("\n" + "="*70)
print("STO Best Fit Parameters:")
print("="*70)
print(f"  c_start:       {p_STO[0]:.4f} Å (bounds: [{bounds_STO[0][0]:.4f}, {bounds_STO[0][1]:.4f}])")
print(f"  c_end:         {p_STO[1]:.4f} Å (bounds: [{bounds_STO[1][0]:.4f}, {bounds_STO[1][1]:.4f}])")
print(f"  Thickness:     {p_STO[2]:.2f} nm (bounds: [{bounds_STO[2][0]:.2f}, {bounds_STO[2][1]:.2f}])")
print(f"  Spatial Var:   {p_STO[3]:.4f} % (bounds: [{bounds_STO[3][0]:.4f}, {bounds_STO[3][1]:.4f}])")
print(f"  Roughness:     {p_STO[4]:.4f} nm (bounds: [{bounds_STO[4][0]:.4f}, {bounds_STO[4][1]:.4f}])")
print(f"  Mosaicity:     {p_STO[5]:.4f} deg (bounds: [{bounds_STO[5][0]:.4f}, {bounds_STO[5][1]:.4f}])")
print(f"  Relax Length:  {p_STO[6]:.2f} layers (bounds: [{bounds_STO[6][0]:.2f}, {bounds_STO[6][1]:.2f}])")
print(f"  Attenuation:   {p_STO[7]:.0f} nm (bounds: [{bounds_STO[7][0]:.0f}, {bounds_STO[7][1]:.0f}])")
print(f"  Instrumental:  {p_STO[8]:.4f} deg (bounds: [{bounds_STO[8][0]:.4f}, {bounds_STO[8][1]:.4f}])")
print("="*70)
# Out:
# experimental_data= [<ttw.ttw object at 0x1178a8530>]
# Found STO peak at 46.590° with intensity 7825938
#
# --- Fitting STO Substrate ---
# Setting up optimization in range (46.0, 47.5) with grid 1x1...
# Optimization mode: Local (Powell only)
#   Settings: film_scale=1.0000, background=None
#   Powell params: tol=0.01, maxiter=100
#
# === Local Optimization (Powell only) ===
# Eval 1: Residual = 94.043547
# Eval 2: Residual = 82.611563
# Eval 3: Residual = 97.711479
# Eval 4: Residual = 59.678272
# Eval 5: Residual = 107.312663
# Eval 6: Residual = 76.994467
# Eval 7: Residual = 63.070769
# Eval 8: Residual = 76.008239
# Eval 9: Residual = 72.103542
# Eval 10: Residual = 49.972376
# Eval 11: Residual = 75.456168
# Eval 12: Residual = 78.294844
# Eval 13: Residual = 62.945221
# Eval 14: Residual = 74.724898
# Eval 15: Residual = 59.254742
# Eval 16: Residual = 77.351841
# Eval 17: Residual = 59.184253
# Eval 18: Residual = 71.172049
# Eval 19: Residual = 65.893479
# Eval 20: Residual = 64.059392
# Eval 21: Residual = 62.413745
# Eval 22: Residual = 61.079107
# Eval 23: Residual = 69.597997
# Eval 24: Residual = 74.097758
# Eval 25: Residual = 68.331825
# Eval 26: Residual = 65.913286
# Eval 27: Residual = 59.576566
# Eval 28: Residual = 61.556412
# Eval 29: Residual = 66.208924
# Eval 30: Residual = 79.749623
# Eval 31: Residual = 52.534393
# Eval 32: Residual = 79.801600
# Eval 33: Residual = 65.176981
# Eval 34: Residual = 63.585083
# Eval 35: Residual = 70.273436
# Eval 36: Residual = 60.507474
# Eval 37: Residual = 73.606789
# Eval 38: Residual = 49.477517
# Eval 39: Residual = 86.009485
# Eval 40: Residual = 55.876408
# Eval 41: Residual = 66.346886
# Eval 42: Residual = 81.750125
# Eval 43: Residual = 71.346572
# Eval 44: Residual = 74.486447
# Eval 45: Residual = 89.940083
# Eval 46: Residual = 62.557237
# Eval 47: Residual = 70.941838
# Eval 48: Residual = 82.605677
# Eval 49: Residual = 75.183351
# Eval 50: Residual = 70.513658
# Eval 51: Residual = 71.637341
# Eval 52: Residual = 65.743298
# Eval 53: Residual = 52.092415
# Eval 54: Residual = 73.144037
# Eval 55: Residual = 62.833162
# Eval 56: Residual = 70.914678
# Eval 57: Residual = 67.514711
# Eval 58: Residual = 59.728447
# Eval 59: Residual = 70.871337
# Eval 60: Residual = 70.960525
# Eval 61: Residual = 76.155432
# Eval 62: Residual = 64.246825
# Eval 63: Residual = 74.445541
# Eval 64: Residual = 72.005319
# Eval 65: Residual = 59.955597
# Eval 66: Residual = 57.907372
# Eval 67: Residual = 64.758560
# Eval 68: Residual = 73.895189
# Eval 69: Residual = 59.662202
# Eval 70: Residual = 73.453855
# Eval 71: Residual = 66.944747
# Eval 72: Residual = 73.297422
# Eval 73: Residual = 57.742413
# Eval 74: Residual = 62.089982
# Eval 75: Residual = 67.913810
# Eval 76: Residual = 63.171871
# Eval 77: Residual = 65.387553
# Eval 78: Residual = 73.027092
# Eval 79: Residual = 60.411487
# Eval 80: Residual = 49.537912
# Eval 81: Residual = 104.329029
# Eval 82: Residual = 70.282757
# Eval 83: Residual = 43.553780
# Eval 84: Residual = 40.282020
# Eval 85: Residual = 32.830097
# Eval 86: Residual = 38.366496
# Eval 87: Residual = 42.817094
# Eval 88: Residual = 30.590437
# Eval 89: Residual = 27.104632
# Eval 90: Residual = 37.343524
# Eval 91: Residual = 31.161513
# Eval 92: Residual = 39.703975
# Eval 93: Residual = 28.200901
# Eval 94: Residual = 38.603027
# Eval 95: Residual = 39.436933
# Eval 96: Residual = 63.849370
# Eval 97: Residual = 85.820606
# Eval 98: Residual = 60.568489
# Eval 99: Residual = 67.618578
# Eval 100: Residual = 64.743656
# Eval 101: Residual = 77.259551
# Eval 102: Residual = 70.211697
# Eval 103: Residual = 91.101891
# Eval 104: Residual = 58.172527
# Eval 105: Residual = 69.626791
# Eval 106: Residual = 87.398838
# Eval 107: Residual = 71.266499
# Eval 108: Residual = 77.397096
# Eval 109: Residual = 69.881889
# Eval 110: Residual = 71.299280
# Eval 111: Residual = 72.467914
# Eval 112: Residual = 65.733422
# Eval 113: Residual = 74.547994
# Eval 114: Residual = 76.233373
# Eval 115: Residual = 77.732552
# Eval 116: Residual = 73.282623
# Eval 117: Residual = 72.091752
# Eval 118: Residual = 69.222154
# Eval 119: Residual = 71.172640
# Eval 120: Residual = 72.948243
# Eval 121: Residual = 65.150092
# Eval 122: Residual = 72.751260
# Eval 123: Residual = 78.806022
# Eval 124: Residual = 79.597951
# Eval 125: Residual = 76.914763
# Eval 126: Residual = 75.297224
# Eval 127: Residual = 70.908317
# Eval 128: Residual = 66.906709
# Eval 129: Residual = 69.318312
# Eval 130: Residual = 59.704076
# Eval 131: Residual = 81.685358
# Eval 132: Residual = 80.105764
# Eval 133: Residual = 74.418644
# Eval 134: Residual = 65.450894
# Eval 135: Residual = 70.666797
# Eval 136: Residual = 80.883268
# Eval 137: Residual = 74.949495
# Eval 138: Residual = 72.119490
# Eval 139: Residual = 68.077518
# Eval 140: Residual = 67.689403
# Eval 141: Residual = 83.272285
# Eval 142: Residual = 70.356139
# Eval 143: Residual = 70.473022
# Eval 144: Residual = 64.812228
# Eval 145: Residual = 70.561668
# Eval 146: Residual = 86.407834
# Eval 147: Residual = 76.563957
# Eval 148: Residual = 58.096119
# Eval 149: Residual = 84.182117
# Eval 150: Residual = 76.445179
# Eval 151: Residual = 66.918719
# Eval 152: Residual = 56.158051
# Eval 153: Residual = 60.413613
# Eval 154: Residual = 71.622259
# Eval 155: Residual = 63.645700
# Eval 156: Residual = 58.884449
# Eval 157: Residual = 95.342669
# Eval 158: Residual = 63.459350
# Eval 159: Residual = 68.874773
# Eval 160: Residual = 66.434863
# Eval 161: Residual = 69.780260
# Eval 162: Residual = 85.787488
# Eval 163: Residual = 58.487195
# Eval 164: Residual = 64.033237
# Eval 165: Residual = 70.214862
# Eval 166: Residual = 80.318889
# Eval 167: Residual = 72.736241
# Eval 168: Residual = 58.878645
# Eval 169: Residual = 69.678421
# Eval 170: Residual = 69.804887
# Eval 171: Residual = 47.883932
# Eval 172: Residual = 63.491754
# Eval 173: Residual = 76.343755
# Eval 174: Residual = 68.931243
#
# === Optimization Complete ===
# Success: True
# Message: Optimization terminated successfully.
# Final Residual: 47.883932
#
# ======================================================================
# STO Best Fit Parameters:
# ======================================================================
#   c_start:       3.9026 Å (bounds: [3.8972, 3.9128])
#   c_end:         3.9026 Å (bounds: [3.8972, 3.9128])
#   Thickness:     6000.00 nm (bounds: [6000.00, 6000.00])
#   Spatial Var:   0.0172 % (bounds: [0.0000, 0.0500])
#   Roughness:     0.2438 nm (bounds: [0.0000, 0.6000])
#   Mosaicity:     0.0236 deg (bounds: [0.0000, 0.5000])
#   Relax Length:  1.84 layers (bounds: [1.00, 10.00])
#   Attenuation:   43087 nm (bounds: [10000, 50000])
#   Instrumental:  0.0602 deg (bounds: [0.0100, 0.1000])
# ======================================================================

# %%
# --- 4. Plot STO Fit Result ---
print("\nGenerating STO fit plot...")
# Re-run simulation with best parameters
nz_STO_best = int((p_STO[2] * 10) / p_STO[1])
lat_arr_STO, h_map_STO, t_arr_STO = create_crystal_system(
    nx_fit_STO, ny_fit_STO, nz_STO_best,
    p_STO[1], [p_STO[0], p_STO[1]],
    mode='full', gradient_type='exponential',
    spatial_var_percent=p_STO[3], roughness_layers=(p_STO[4]*10)/p_STO[1],
    mosaicity_fwhm=p_STO[5], relaxation_length=p_STO[6]
)

# Calculate STO signal
x_exp = exp_data.ttw_df[0]['Angle'].values
y_exp_norm = exp_data.ttw_df[0]['Intensity'].values / peak_int_STO

tt_best_STO, int_best_STO = calculate_xrd_vectorized(
    lat_arr_STO, h_map_STO, t_arr_STO,
    two_theta_range=(fit_range_STO[0]-0.5, fit_range_STO[1]+0.5), # Plot around fit range
    wavelength=wavelength,
    attenuation_length_nm=p_STO[7],
    instrumental_broadening=p_STO[8],
    n_points=1000,
    normalize=True
)

plt.figure(figsize=(10, 6))
# Plot experimental data in the relevant range
mask_plot = (x_exp >= fit_range_STO[0]-0.5) & (x_exp <= fit_range_STO[1]+0.5)
plt.plot(x_exp[mask_plot], y_exp_norm[mask_plot], 'k-', label='Experiment (STO)', alpha=0.5, linewidth=2)
plt.plot(tt_best_STO, int_best_STO, 'r--', label='Best Fit (STO)', linewidth=2)

plt.axvspan(fit_range_STO[0], fit_range_STO[1], color='blue', alpha=0.1, label='STO Fit Region')

plt.xlabel(r'$2\theta$ (degrees)')
plt.ylabel('Normalized Intensity')
plt.title('STO Substrate Fit Result')
plt.legend()
plt.yscale('log')
#plt.ylim(1e-3, 1.5)
plt.grid(True, alpha=0.3)
plt.show()



print("\n" + "="*70)
print("STO Best Fit Parameters:")
print("="*70)
print(f"  c_start:       {p_STO[0]:.4f} Å (bounds: [{bounds_STO[0][0]:.4f}, {bounds_STO[0][1]:.4f}])")
print(f"  c_end:         {p_STO[1]:.4f} Å (bounds: [{bounds_STO[1][0]:.4f}, {bounds_STO[1][1]:.4f}])")
print(f"  Thickness:     {p_STO[2]:.2f} nm (bounds: [{bounds_STO[2][0]:.2f}, {bounds_STO[2][1]:.2f}])")
print(f"  Spatial Var:   {p_STO[3]:.4f} % (bounds: [{bounds_STO[3][0]:.4f}, {bounds_STO[3][1]:.4f}])")
print(f"  Roughness:     {p_STO[4]:.4f} nm (bounds: [{bounds_STO[4][0]:.4f}, {bounds_STO[4][1]:.4f}])")
print(f"  Mosaicity:     {p_STO[5]:.4f} deg (bounds: [{bounds_STO[5][0]:.4f}, {bounds_STO[5][1]:.4f}])")
print(f"  Relax Length:  {p_STO[6]:.2f} layers (bounds: [{bounds_STO[6][0]:.2f}, {bounds_STO[6][1]:.2f}])")
print(f"  Attenuation:   {p_STO[7]:.0f} nm (bounds: [{bounds_STO[7][0]:.0f}, {bounds_STO[7][1]:.0f}])")
print(f"  Instrumental:  {p_STO[8]:.4f} deg (bounds: [{bounds_STO[8][0]:.4f}, {bounds_STO[8][1]:.4f}])")
print("="*70)

# %%
# ========== Multi-Peak Setup: Find Both BSO and SSO Peaks ==========
from ttw_models import run_multi_peak_xrd_fitting

# Use the same experimental data and STO background as before
# exp_data and int_bg_STO_full should already be defined from previous cells

# Define the two peaks we want to fit
peak_labels = ['BSO', 'SSO']

# Search for each peak in its expected range
peak_search_range_BSO_multi = (43.5, 45.0)  # BSO expected around 44°
peak_search_range_SSO_multi = (42.0, 43.5)  # SSO expected around 42.5°

# Find peak positions and intensities
peak_pos_BSO_multi, peak_int_BSO_multi = find_peak(exp_data, peak_search_range_BSO_multi)
peak_pos_SSO_multi, peak_int_SSO_multi = find_peak(exp_data, peak_search_range_SSO_multi)

print(f"BSO Peak: {peak_pos_BSO_multi:.3f}° with intensity {peak_int_BSO_multi:.0f}")
print(f"SSO Peak: {peak_pos_SSO_multi:.3f}° with intensity {peak_int_SSO_multi:.0f}")

# Calculate initial lattice parameter guesses
theta_rad_BSO_multi = np.radians(peak_pos_BSO_multi / 2)
c_guess_BSO_multi = (wavelength / (2 * np.sin(theta_rad_BSO_multi))) * 2

theta_rad_SSO_multi = np.radians(peak_pos_SSO_multi / 2)
c_guess_SSO_multi = (wavelength / (2 * np.sin(theta_rad_SSO_multi))) * 2

print(f"\nEstimated lattice parameters:")
print(f"  BSO: c = {c_guess_BSO_multi:.4f} Å")
print(f"  SSO: c = {c_guess_SSO_multi:.4f} Å")

# Peak intensities for scaling (normalized to STO)
peak_intensities = [peak_int_BSO_multi, peak_int_SSO_multi]

# Calculate film scale factors
film_scale_BSO_multi = peak_int_BSO_multi / peak_int_STO
film_scale_SSO_multi = peak_int_SSO_multi / peak_int_STO
print(f"\nFilm/Substrate intensity ratios:")
print(f"  BSO/STO: {film_scale_BSO_multi:.4f}")
print(f"  SSO/STO: {film_scale_SSO_multi:.4f}")

# %%
# ========== Multi-Peak Configuration: Bounds and Grid Sizes ==========

# Fitting ranges for each peak (can overlap!)
fit_ranges_multi = [
    (43.0, 45.5),  # BSO range
    (41.5, 43.5)   # SSO range
]

# Grid sizes for each peak simulation
nx_fits_multi = [8, 8]  # BSO, SSO
ny_fits_multi = [8, 8]

# --- BSO Bounds ---
bounds_BSO_multi = [
    (c_guess_BSO_multi * 0.96, c_guess_BSO_multi * 1.04),  # 1. c_start (Interface)
    (c_guess_BSO_multi * 0.96, c_guess_BSO_multi * 1.04),  # 2. c_end (Surface)
    (15.0, 25.0),     # 3. Thickness (nm)
    (0.0, 1.0),       # 4. Spatial Var (%)
    (0.0, 1.0),       # 5. Roughness (nm)
    (0.0, 1.0),       # 6. Mosaicity (deg)
    (1.0, 50.0),      # 7. Relaxation Length (layers)
    (atten_STO * 0.97, atten_STO * 1.03),  # 8. Attenuation (nm) - constrained by STO
    (instr_STO * 0.97, instr_STO * 1.03)   # 9. Instrumental (deg) - constrained by STO
]

# --- SSO Bounds ---
bounds_SSO_multi = [
    (c_guess_SSO_multi * 0.96, c_guess_SSO_multi * 1.04),  # 1. c_start (Interface)
    (c_guess_SSO_multi * 0.96, c_guess_SSO_multi * 1.04),  # 2. c_end (Surface)
    (15.0, 25.0),     # 3. Thickness (nm)
    (0.0, 1.0),       # 4. Spatial Var (%)
    (0.0, 1.0),       # 5. Roughness (nm)
    (0.0, 1.0),       # 6. Mosaicity (deg)
    (1.0, 50.0),      # 7. Relaxation Length (layers)
    (atten_STO * 0.97, atten_STO * 1.03),  # 8. Attenuation (nm) - shared with BSO
    (instr_STO * 0.97, instr_STO * 1.03)   # 9. Instrumental (deg) - shared with BSO
]

bounds_list_multi = [bounds_BSO_multi, bounds_SSO_multi]

# Initial guesses (center of bounds)
p0_BSO_multi = np.mean(bounds_BSO_multi, axis=1)
p0_SSO_multi = np.mean(bounds_SSO_multi, axis=1)
p0_list_multi = [p0_BSO_multi, p0_SSO_multi]

print("Multi-peak fitting configuration:")
print(f"  Number of peaks: {len(peak_labels)}")
print(f"  Total parameters: {len(peak_labels) * 9}")
print(f"  Fitting ranges: {fit_ranges_multi}")
print(f"  Grid sizes: {list(zip(nx_fits_multi, ny_fits_multi))}")

# %%
# ========== Run Multi-Peak Optimization ==========

# Optimization settings
use_global_multi = True   # Use global search for robustness
de_maxiter_multi = 40     # DE iterations (will take longer with multiple peaks!)
de_popsize_multi = 10     # DE population multiplier
powell_tol_multi = 0.005  # Powell tolerance
powell_maxiter_multi = 300  # Powell max iterations

print("\n" + "="*70)
print("Starting Multi-Peak Fitting (BSO + SSO + STO Background)")
print("="*70)
print("\nWARNING: This will take significantly longer than single-peak fitting!")
print(f"Expected time: ~10-20 minutes with global search")
print("Consider reducing de_maxiter_multi or de_popsize_multi for faster results.\n")

# Run the multi-peak fitting
results_multi = run_multi_peak_xrd_fitting(
    exp_data, 
    peak_labels=peak_labels,
    peak_intensities=peak_intensities,
    wavelength=wavelength,
    fit_ranges=fit_ranges_multi,
    nx_fits=nx_fits_multi,
    ny_fits=ny_fits_multi,
    use_log_residual=True,
    p0_list=p0_list_multi,
    bounds_list=bounds_list_multi,
    use_global_search=use_global_multi,
    de_maxiter=de_maxiter_multi,
    de_popsize=de_popsize_multi,
    tol=powell_tol_multi,
    maxiter=powell_maxiter_multi,
    background_intensity=int_bg_STO_full,  # Add STO background
    normalization_peak_intensity=peak_int_STO
)

# Extract optimized parameters
params_BSO_opt = results_multi['params_per_peak'][0]
params_SSO_opt = results_multi['params_per_peak'][1]

print("\n" + "="*70)
print("BSO (Peak 1) Best Fit Parameters:")
print("="*70)
print(f"  c_start (Interface):  {params_BSO_opt[0]:.4f} Å (bounds: [{bounds_BSO_multi[0][0]:.4f}, {bounds_BSO_multi[0][1]:.4f}])")
print(f"  c_end (Surface):      {params_BSO_opt[1]:.4f} Å (bounds: [{bounds_BSO_multi[1][0]:.4f}, {bounds_BSO_multi[1][1]:.4f}])")
print(f"  Thickness:            {params_BSO_opt[2]:.2f} nm (bounds: [{bounds_BSO_multi[2][0]:.2f}, {bounds_BSO_multi[2][1]:.2f}])")
print(f"  Spatial Var:          {params_BSO_opt[3]:.4f} % (bounds: [{bounds_BSO_multi[3][0]:.4f}, {bounds_BSO_multi[3][1]:.4f}])")
print(f"  Roughness:            {params_BSO_opt[4]:.4f} nm (bounds: [{bounds_BSO_multi[4][0]:.4f}, {bounds_BSO_multi[4][1]:.4f}])")
print(f"  Mosaicity:            {params_BSO_opt[5]:.4f} deg (bounds: [{bounds_BSO_multi[5][0]:.4f}, {bounds_BSO_multi[5][1]:.4f}])")
print(f"  Relax Length:         {params_BSO_opt[6]:.2f} layers (bounds: [{bounds_BSO_multi[6][0]:.2f}, {bounds_BSO_multi[6][1]:.2f}])")
print(f"  Attenuation:          {params_BSO_opt[7]:.0f} nm (bounds: [{bounds_BSO_multi[7][0]:.0f}, {bounds_BSO_multi[7][1]:.0f}])")
print(f"  Instrumental:         {params_BSO_opt[8]:.4f} deg (bounds: [{bounds_BSO_multi[8][0]:.4f}, {bounds_BSO_multi[8][1]:.4f}])")

print("\n" + "="*70)
print("SSO (Peak 2) Best Fit Parameters:")
print("="*70)
print(f"  c_start (Interface):  {params_SSO_opt[0]:.4f} Å (bounds: [{bounds_SSO_multi[0][0]:.4f}, {bounds_SSO_multi[0][1]:.4f}])")
print(f"  c_end (Surface):      {params_SSO_opt[1]:.4f} Å (bounds: [{bounds_SSO_multi[1][0]:.4f}, {bounds_SSO_multi[1][1]:.4f}])")
print(f"  Thickness:            {params_SSO_opt[2]:.2f} nm (bounds: [{bounds_SSO_multi[2][0]:.2f}, {bounds_SSO_multi[2][1]:.2f}])")
print(f"  Spatial Var:          {params_SSO_opt[3]:.4f} % (bounds: [{bounds_SSO_multi[3][0]:.4f}, {bounds_SSO_multi[3][1]:.4f}])")
print(f"  Roughness:            {params_SSO_opt[4]:.4f} nm (bounds: [{bounds_SSO_multi[4][0]:.4f}, {bounds_SSO_multi[4][1]:.4f}])")
print(f"  Mosaicity:            {params_SSO_opt[5]:.4f} deg (bounds: [{bounds_SSO_multi[5][0]:.4f}, {bounds_SSO_multi[5][1]:.4f}])")
print(f"  Relax Length:         {params_SSO_opt[6]:.2f} layers (bounds: [{bounds_SSO_multi[6][0]:.2f}, {bounds_SSO_multi[6][1]:.2f}])")
print(f"  Attenuation:          {params_SSO_opt[7]:.0f} nm (bounds: [{bounds_SSO_multi[7][0]:.0f}, {bounds_SSO_multi[7][1]:.0f}])")
print(f"  Instrumental:         {params_SSO_opt[8]:.4f} deg (bounds: [{bounds_SSO_multi[8][0]:.4f}, {bounds_SSO_multi[8][1]:.4f}])")
print("="*70)

# %%
# ========== Plot Multi-Peak Fitting Results ==========

print("\nGenerating multi-peak fit plot...")

# Simulate each peak individually with optimized parameters
simulations = []

for i, (label, params) in enumerate(zip(peak_labels, [params_BSO_opt, params_SSO_opt])):
    # Unpack parameters
    c_start, c_end, t_nm, s_var, r_nm, mos, rel_len, att_len, instr = params
    
    # Derived parameters
    nz_fit = int((t_nm * 10) / c_end)
    r_layers = (r_nm * 10) / c_end
    
    # Generate system
    lat_arr, h_map, t_arr = create_crystal_system(
        nx_fits_multi[i], ny_fits_multi[i], nz_fit,
        c_end,
        [c_start, c_end],
        mode='full',
        gradient_type='exponential',
        spatial_var_percent=s_var,
        roughness_layers=r_layers,
        mosaicity_fwhm=mos,
        relaxation_length=rel_len
    )
    
    # Calculate XRD over full experimental range
    tt_sim, int_sim = calculate_xrd_vectorized(
        lat_arr, h_map, t_arr,
        two_theta_range=(x_exp.min(), x_exp.max()),
        wavelength=wavelength,
        attenuation_length_nm=att_len,
        instrumental_broadening=instr,
        n_points=3000,
        normalize=True
    )
    
    # Scale to experimental intensity ratio
    int_sim = int_sim * results_multi['film_scales'][i]
    
    simulations.append({
        'label': label,
        'two_theta': tt_sim,
        'intensity': int_sim
    })

# Calculate total signal: BSO + SSO + STO background
int_BSO_sim = np.interp(x_exp, simulations[0]['two_theta'], simulations[0]['intensity'])
int_SSO_sim = np.interp(x_exp, simulations[1]['two_theta'], simulations[1]['intensity'])
int_bg_STO_exp_range = np.interp(x_exp, tt_full, int_full_STO)
int_total_multi = int_BSO_sim + int_SSO_sim + int_bg_STO_exp_range

# Plot
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10), 
                                 gridspec_kw={'height_ratios': [3, 1]})

# Main plot
ax1.plot(x_exp, y_exp_norm, 'k-', label='Experiment', linewidth=2.5, alpha=0.6, zorder=10)
ax1.plot(x_exp, int_total_multi, 'r-', label='Total Fit (BSO+SSO+STO)', linewidth=2, alpha=0.9)
ax1.plot(x_exp, int_BSO_sim, 'b--', label='BSO Component', linewidth=1.5, alpha=0.7)
ax1.plot(x_exp, int_SSO_sim, 'g--', label='SSO Component', linewidth=1.5, alpha=0.7)
ax1.plot(x_exp, int_bg_STO_exp_range, 'm:', label='STO Background', linewidth=1.5, alpha=0.7)

# Mark fitting regions
ax1.axvspan(fit_ranges_multi[0][0], fit_ranges_multi[0][1], color='blue', alpha=0.05, label='BSO Fit Region')
ax1.axvspan(fit_ranges_multi[1][0], fit_ranges_multi[1][1], color='green', alpha=0.05, label='SSO Fit Region')

ax1.set_ylabel('Normalized Intensity (STO=1)', fontsize=12)
ax1.set_title('Multi-Peak Fit: BSO + SSO + STO Background', fontsize=14, fontweight='bold')
ax1.legend(fontsize=10, loc='best')
ax1.set_yscale('log')
ax1.set_ylim(1e-4, 2)
ax1.grid(True, alpha=0.3)
ax1.set_xticklabels([])  # Remove x labels from top plot

# Residual plot
residual = y_exp_norm - int_total_multi
ax2.plot(x_exp, residual, 'k-', linewidth=1, alpha=0.7)
ax2.axhline(0, color='red', linestyle='--', linewidth=1)
ax2.axvspan(fit_ranges_multi[0][0], fit_ranges_multi[0][1], color='blue', alpha=0.05)
ax2.axvspan(fit_ranges_multi[1][0], fit_ranges_multi[1][1], color='green', alpha=0.05)
ax2.set_xlabel(r'$2\theta$ (degrees)', fontsize=12)
ax2.set_ylabel('Residual', fontsize=11)
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("\nPlot complete!")

# %% [markdown]
# ### Understanding Multi-Peak Fitting
#
# **How It Works:**
#
# 1. **Parameter Space**: Each peak has 9 parameters → Total = 18 parameters for BSO+SSO
#    - BSO: [c_start, c_end, thickness, spatial_var, roughness, mosaicity, relax_len, atten, instr]
#    - SSO: [c_start, c_end, thickness, spatial_var, roughness, mosaicity, relax_len, atten, instr]
#
# 2. **Objective Function**:
#    ```
#    Simulated_Total = BSO_sim * scale_BSO + SSO_sim * scale_SSO + STO_background
#    Residual = Σ(log(Experiment) - log(Simulated_Total))²
#    ```
#
# 3. **Optimization Strategy**:
#    - **Stage 1 (DE)**: Population-based search explores all 18D parameter space simultaneously
#    - **Stage 2 (Powell)**: Refines the solution to high precision
#    - Both peaks are **coupled** through the shared experimental data
#
# **Key Advantages:**
# - Proper deconvolution of overlapping peaks
# - Shared instrumental parameters (attenuation, broadening) ensure physical consistency
# - Accounts for interference between peaks in overlapping regions
#
# **Tips for Success:**
# - Set reasonable bounds based on single-peak fits
# - Consider constraining attenuation/instrumental to be the same for both peaks
# - Start with wider fitting ranges that capture both peaks
# - Reduce `de_maxiter` or `de_popsize` for faster (but potentially less accurate) results

# %% [markdown]
# ### Extending to More Peaks (N-Peak Fitting)
#
# The `run_multi_peak_xrd_fitting()` function is fully generalized and can handle any number of peaks:
#
# ```python
# # Example: Fitting 3 peaks (BSO, SSO, LAO)
# peak_labels = ['BSO', 'SSO', 'LAO']
# peak_intensities = [peak_int_BSO, peak_int_SSO, peak_int_LAO]
# fit_ranges_multi = [(43.0, 45.5), (41.5, 43.5), (40.0, 42.0)]
# nx_fits_multi = [8, 8, 8]
# ny_fits_multi = [8, 8, 8]
# bounds_list_multi = [bounds_BSO, bounds_SSO, bounds_LAO]
# p0_list_multi = [p0_BSO, p0_SSO, p0_LAO]
#
# # Run with same function call
# results_multi = run_multi_peak_xrd_fitting(
#     exp_data, peak_labels, peak_intensities, wavelength,
#     fit_ranges_multi, nx_fits_multi, ny_fits_multi,
#     p0_list=p0_list_multi, bounds_list=bounds_list_multi,
#     use_global_search=True, ...
# )
# ```
#
# **Important Notes:**
# - Each additional peak adds 9 parameters → optimization time scales significantly
# - With 3 peaks (27 params), consider reducing DE iterations or using tighter bounds
# - Computational cost: ~O(N²) due to increased parameter space and simulation overhead

# %%
(4.116-3.905)/4.116*100
# Out:
# 5.1263362487852255
